# %% [markdown]
# Exercise 1: Basic Searching and Filtering

# %%
# !pip install pymongo --upgrade pymongo certifi
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (2024.8.30)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.4 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
 #Import necessary libraries
from pymongo import MongoClient
import pprint

#Replace with your MongoDB Atlas connection string
connection_string= ("mongodb+srv://norahczma:divisova@cluster0..v7p5b.mongodb.net/test"
    "?retryWrites=true&w=majority&ssl=true&tlsAllowInvalidCertificates=true")
client = MongoClient(connection_string)

#Access the sample-mflix database and the movies collection
db= client.sample_mflix
collection= db.movies
client = MongoClient(connection_string, serverSelectionTimeoutMS=30000)

#Access the sample-mflix database and the movies collection
db= client.sample_mflix
collection= db.movies

# %% [markdown]
# Exercise 1: Basic Searching and Filtering

# %%
#1. Write a query to find the first movie that has the genre "Action".
action_movie = collection.find_one({"genres": {"$regex": "Action", "$options": "i"}})
pprint.pprint(action_movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}

# %%
#2. Write a query to find all movies released after the year 2000 (Return the first 5 results).movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)
movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)
for movie in movies_after_2000:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a1398f29313caabceb1fe'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Crispin Glover', 'Vanessa Redgrave', 'John Hurt', 'Margot Kidder'],
#  'countries': ['USA', 'Poland', 'Russia'],
#  'directors': ['Menahem Golan'],
#  'fullplot': "A modern day adaptation of Dostoyevsky's classic novel about a "
#              'young student who is forever haunted by the murder he has '
#              'committed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 96056, 'rating': 6.4, 'votes': 463},
#  'languages': ['English', 'Polish'],
#  'lastupdated': '2015-08-13 00:34:02.303000000',
#  'num_mflix_comments': 0,
#  'plot': "A modern day adaptation of Dostoyevsky's classic novel about a young "
#          'student who is forever haunted by the murder he has committed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MDQ2MzEyOV5BMl5BanBnXkFtZTcwNzEwODUzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 6, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Crime and Punishment',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 22, 18, 45, 10),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Fyodor Dostoevsky (novel)',
#              'Menahem Golan (adaptation)',
#              'Menahem Golan (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0809'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Marcelo Games', 'Marc Pitman', 'Leslie Orr', 'Maureen Allisse'],
#  'countries': ['USA'],
#  'directors': ['Jim Van Bebber'],
#  'fullplot': 'If you think you know the story of the Manson Family, you are '
#              'dead wrong. On a ranch outside of Los Angeles, the dream of the '
#              '"Love Generation" is transforming into something evil. What was '
#              'once an oasis of free love and acid trips has become ground zero '
#              "for a madman's paranoid visions. An average group of kids, the "
#              '"Family," become engulfed in a delusional world where torment '
#              'and slaughter are considered the path to righteousness.Director '
#              'Jim VanBebber (Deadbeat at Dawn) delivers a dizzying, rapid-fire '
#              'vision of the sex and violence that unifies the misguided group, '
#              'a group hell-bent on executing the brutal vision of its leader, '
#              "Charles Manson. You've seen the story through the eyes of the "
#              'law. Now witness it through the eyes of THE MANSOSN FAMILY.',
#  'genres': ['Crime', 'Drama', 'History'],
#  'imdb': {'id': 118840, 'rating': 5.5, 'votes': 2565},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:23.867000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'If you think you know the story of the Manson Family, you are dead '
#          'wrong. On a ranch outside of Los Angeles, the dream of the "Love '
#          'Generation" is transforming into something evil. What was...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NDIzMjY3M15BMl5BanBnXkFtZTcwODE2ODYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2004, 7, 23, 0, 0),
#  'runtime': 95,
#  'title': 'The Manson Family',
#  'tomatoes': {'critic': {'meter': 68, 'numReviews': 31, 'rating': 6.0},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 7, 20, 18, 38, 35),
#               'production': 'Blue Underground',
#               'rotten': 10,
#               'viewer': {'meter': 48, 'numReviews': 7479, 'rating': 3.0},
#               'website': 'http://www2.themansonfamilymovie.com/'},
#  'type': 'movie',
#  'writers': ['Jim Van Bebber'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0869'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Javier Bardem',
#           'Juan Diego Botto',
#           'Laura Morante',
#           'Elvira Mènguez'],
#  'countries': ['Spain', 'USA'],
#  'directors': ['John Malkovich'],
#  'fullplot': 'The story of Detective Agustin Rejas, a man clinging to the hope '
#              'of an impossible love in an impossible world. Tracking Ezequiel, '
#              'a delusional anarchist who incites the downtrodden masses to '
#              'join in his brutal revolution against the fascist government in '
#              'their unnamed Latin American country, Rejas finds solace in his '
#              'sense of self-respect and the joy that his daughter and wife '
#              "bring him. Then he meets Yolanda--his daughter's soulfully "
#              'beautiful ballet teacher--a woman who sparks his long-forgotten '
#              'passions and represents all that is good and all that is corrupt '
#              'in their troubled country. But she, who appears to be a shelter '
#              "from the storm, may in actuality be the storm's eye. Ultimately, "
#              'as the revolution intensifies and the net closes around hunter '
#              "and hunted alike, the dancer's truth will prove as elusive as "
#              "the revolutionary's cause and the detective's peace.",
#  'genres': ['Drama', 'Thriller', 'Crime'],
#  'imdb': {'id': 118926, 'rating': 7.0, 'votes': 5359},
#  'languages': ['English', 'Quechua', 'Spanish'],
#  'lastupdated': '2015-09-07 01:12:12.077000000',
#  'metacritic': 64,
#  'num_mflix_comments': 0,
#  'plot': 'A police detective in a South American country is dedicated to '
#          'hunting down a revolutionary guerilla leader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BODE2ODA5OTE1OV5BMl5BanBnXkFtZTYwNzk1MTc2._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'The Dancer Upstairs',
#  'tomatoes': {'boxOffice': '$2.3M',
#               'consensus': 'Javier Bardem is compelling in the lead role as a '
#                            'police detective in search of a violent, '
#                            'mysterious politcal radical, and as a director, '
#                            'John Malkovich proves adept at crafting a '
#                            'suspenseful mood.',
#               'critic': {'meter': 64, 'numReviews': 114, 'rating': 6.4},
#               'dvd': datetime.datetime(2003, 9, 23, 0, 0),
#               'fresh': 73,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 10, 37, 43),
#               'production': 'Fox Searchlight Pictures',
#               'rotten': 41,
#               'viewer': {'meter': 77, 'numReviews': 4793, 'rating': 3.6},
#               'website': 'http://www.foxsearchlight.com/thedancerupstairs/'},
#  'type': 'movie',
#  'writers': ['Nicholas Shakespeare (novel)',
#              'Nicholas Shakespeare (screenplay)'],
#  'year': 2002}

# %%
# 3. Write a query to find all movies where the IMDb rating is greater than 8.5
# (Return the first 5 results).
high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)
for movie in high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd9600'),
#  'awards': {'nominations': 0, 'text': '3 wins.', 'wins': 3},
#  'cast': ['Virginia Cherrill',
#           'Florence Lee',
#           'Harry Myers',
#           'Al Ernest Garcia'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': 'A tramp falls in love with a beautiful blind girl. Her family is '
#              "in financial trouble. The tramp's on-and-off friendship with a "
#              "wealthy man allows him to be the girl's benefactor and suitor.",
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 21749, 'rating': 8.6, 'votes': 93912},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:10:05.493000000',
#  'num_mflix_comments': 0,
#  'plot': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has '
#          'fallen in love with a sightless flower girl accumulates money to be '
#          'able to help her medically.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1931, 3, 7, 0, 0),
#  'runtime': 87,
#  'title': 'City Lights',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 42, 'rating': 9.0},
#               'dvd': datetime.datetime(2000, 2, 8, 0, 0),
#               'fresh': 41,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 11),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 96, 'numReviews': 26133, 'rating': 4.4}},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1931}
# {'_id': ObjectId('573a1392f29313caabcdae3d'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Charles Chaplin',
#           'Paulette Goddard',
#           'Henry Bergman',
#           'Tiny Sandford'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': "Chaplins last 'silent' film, filled with sound effects, was made "
#              'when everyone else was making talkies. Charlie turns against '
#              'modern society, the machine age, (The use of sound in films ?) '
#              'and progress. Firstly we see him frantically trying to keep up '
#              'with a production line, tightening bolts. He is selected for an '
#              'experiment with an automatic feeding machine, but various '
#              'mishaps leads his boss to believe he has gone mad, and Charlie '
#              'is sent to a mental hospital... When he gets out, he is mistaken '
#              'for a communist while waving a red flag, sent to jail, foils a '
#              'jailbreak, and is let out again. We follow Charlie through many '
#              'more escapades before the film is out.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 27977, 'rating': 8.6, 'votes': 123603},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:06:38.867000000',
#  'metacritic': 96,
#  'num_mflix_comments': 1,
#  'plot': 'The Tramp struggles to live in modern industrial society with the '
#          'help of a young homeless woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'G',
#  'released': datetime.datetime(1936, 2, 25, 0, 0),
#  'runtime': 87,
#  'title': 'Modern Times',
#  'tomatoes': {'consensus': 'A slapstick skewering of industrialized America, '
#                            'Modern Times is as politically incisive as it is '
#                            'laugh-out-loud hilarious.',
#               'critic': {'meter': 100, 'numReviews': 53, 'rating': 9.0},
#               'dvd': datetime.datetime(2010, 8, 23, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 14),
#               'production': 'United Artists',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 38942, 'rating': 4.3},
#               'website': 'http://www.kino.com/moderntimes'},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1936}
# {'_id': ObjectId('573a1393f29313caabcdc810'),
#  'awards': {'nominations': 6,
#             'text': 'Won 3 Oscars. Another 6 wins & 6 nominations.',
#             'wins': 9},
#  'cast': ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid', 'Claude Rains'],
#  'countries': ['USA'],
#  'directors': ['Michael Curtiz'],
#  'fullplot': 'In World War II Casablanca, Rick Blaine, exiled American and '
#              'former freedom fighter, runs the most popular nightspot in town. '
#              'The cynical lone wolf Blaine comes into the possession of two '
#              'valuable letters of transit. When Nazi Major Strasser arrives in '
#              'Casablanca, the sycophantic police Captain Renault does what he '
#              'can to please him, including detaining a Czechoslovak '
#              "underground leader Victor Laszlo. Much to Rick's surprise, "
#              "Lazslo arrives with Ilsa, Rick's one time love. Rick is very "
#              'bitter towards Ilsa, who ran out on him in Paris, but when he '
#              'learns she had good reason to, they plan to run off together '
#              'again using the letters of transit. Well, that was their '
#              'original plan....',
#  'genres': ['Drama', 'Romance', 'War'],
#  'imdb': {'id': 34583, 'rating': 8.6, 'votes': 354005},
#  'languages': ['English', 'French', 'German', 'Italian'],
#  'lastupdated': '2015-09-04 00:22:54.600000000',
#  'num_mflix_comments': 0,
#  'plot': 'Set in Casablanca, Morocco during the early days of World War II: An '
#          'American expatriate meets a former lover, with unforeseen '
#          'complications.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1943, 1, 23, 0, 0),
#  'runtime': 102,
#  'title': 'Casablanca',
#  'tomatoes': {'consensus': "An undisputed masterpiece and perhaps Hollywood's "
#                            'quintessential statement on love and romance, '
#                            'Casablanca has only improved with age, boasting '
#                            'career-defining performances from Humphrey Bogart '
#                            'and Ingrid Bergman.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.3},
#               'dvd': datetime.datetime(2000, 2, 15, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 2, 29),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 95, 'numReviews': 354142, 'rating': 4.1},
#               'website': 'http://www.FathomEvents.com'},
#  'type': 'movie',
#  'writers': ['Julius J. Epstein (screenplay)',
#              'Philip G. Epstein (screenplay)',
#              'Howard Koch (screenplay)',
#              'Murray Burnett (play)',
#              'Joan Alison (play)'],
#  'year': 1942}
# {'_id': ObjectId('573a1393f29313caabcdd7d8'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 5 Oscars. Another 7 wins.',
#             'wins': 12},
#  'cast': ['James Stewart', 'Donna Reed', 'Lionel Barrymore', 'Thomas Mitchell'],
#  'countries': ['USA'],
#  'directors': ['Frank Capra'],
#  'fullplot': 'George Bailey has spent his entire life giving of himself to the '
#              'people of Bedford Falls. He has always longed to travel but '
#              'never had the opportunity in order to prevent rich skinflint Mr. '
#              'Potter from taking over the entire town. All that prevents him '
#              "from doing so is George's modest building and loan company, "
#              'which was founded by his generous father. But on Christmas Eve, '
#              "George's Uncle Billy loses the business's $8,000 while intending "
#              'to deposit it in the bank. Potter finds the misplaced money and '
#              'hides it from Billy. When the bank examiner discovers the '
#              'shortage later that night, George realizes that he will be held '
#              'responsible and sent to jail and the company will collapse, '
#              'finally allowing Potter to take over the town. Thinking of his '
#              'wife, their young children, and others he loves will be better '
#              'off with him dead, he contemplates suicide. But the prayers of '
#              'his loved ones result in a gentle angel named Clarence coming to '
#              'earth to help George, with the promise of earning his wings. He '
#              'shows George what things would have been like if he had never '
#              'been born. In a nightmarish vision in which the '
#              'Potter-controlled town is sunk in sex and sin, those George '
#              'loves are either dead, ruined, or miserable. He realizes that he '
#              'has touched many people in a positive way and that his life has '
#              'truly been a wonderful one.',
#  'genres': ['Drama', 'Family', 'Fantasy'],
#  'imdb': {'id': 38650, 'rating': 8.6, 'votes': 245046},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:01:34.393000000',
#  'num_mflix_comments': 1,
#  'plot': 'An angel helps a compassionate but despairingly frustrated '
#          'businessman by showing what life would have been like if he never '
#          'existed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1947, 1, 7, 0, 0),
#  'runtime': 130,
#  'title': "It's a Wonderful Life",
#  'tomatoes': {'consensus': 'The holiday classic to define all holiday '
#                            "classics, It's a Wonderful Life is one of a "
#                            'handful of films worth an annual viewing.',
#               'critic': {'meter': 94, 'numReviews': 68, 'rating': 8.9},
#               'dvd': datetime.datetime(1995, 9, 19, 0, 0),
#               'fresh': 64,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 10, 55),
#               'production': 'Liberty Films',
#               'rotten': 4,
#               'viewer': {'meter': 95, 'numReviews': 215785, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Frances Goodrich (screenplay)',
#              'Albert Hackett (screenplay)',
#              'Frank Capra (screenplay)',
#              'Jo Swerling (additional scenes)',
#              'Philip Van Doren Stern (story)'],
#  'year': 1946}
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}

# %%
#4.Write a query to find all movies where the genre contains both "Action" and "Adventure".
action_adventure_movies = collection.find({"genres": {"$all": ["Action", "Adventure"]}})
for movie in action_adventure_movies:
    pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'released': datetime.datetime(2011, 5, 26, 0, 0),
#  'runtime': 91,
#  'title': 'Kung Fu Panda 2',
#  'tomatoes': {'boxOffice': '$165.2M',
#               'consensus': 'The storyline arc may seem a tad familiar to fans '
#                            'of the original, but Kung Fu Panda 2 offers enough '
#                            'action, comedy, and visual sparkle to compensate.',
#               'critic': {'meter': 81, 'numReviews': 167, 'rating': 6.9},
#               'dvd': datetime.datetime(2011, 12, 13, 0, 0),
#               'fresh': 135,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 15, 47),
#               'production': 'Paramount Studios/Dreamworks',
#               'rotten': 32,
#               'viewer': {'meter': 74, 'numReviews': 143408, 'rating': 3.8},
#               'website': 'http://www.kungfupanda.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Aibel', 'Glenn Berger'],
#  'year': 2011}
# {'_id': ObjectId('573a13c3f29313caabd69c74'),
#  'awards': {'nominations': 47,
#             'text': 'Nominated for 1 Oscar. Another 22 wins & 47 nominations.',
#             'wins': 23},
#  'cast': ['Robert Downey Jr.', 'Gwyneth Paltrow', 'Don Cheadle', 'Guy Pearce'],
#  'countries': ['USA', 'China'],
#  'directors': ['Shane Black'],
#  'fullplot': 'Marvel\'s "Iron Man 3" pits brash-but-brilliant industrialist '
#              'Tony Stark/Iron Man against an enemy whose reach knows no '
#              'bounds. When Stark finds his personal world destroyed at his '
#              "enemy's hands, he embarks on a harrowing quest to find those "
#              'responsible. This journey, at every turn, will test his mettle. '
#              'With his back against the wall, Stark is left to survive by his '
#              'own devices, relying on his ingenuity and instincts to protect '
#              'those closest to him. As he fights his way back, Stark discovers '
#              'the answer to the question that has secretly haunted him: does '
#              'the man make the suit or does the suit make the man?',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1300854, 'rating': 7.3, 'votes': 493617},
#  'languages': ['English'],
#  'lastupdated': '2015-09-07 00:03:58.920000000',
#  'metacritic': 62,
#  'num_mflix_comments': 0,
#  'plot': "When Tony Stark's world is torn apart by a formidable terrorist "
#          'called the Mandarin, he starts an odyssey of rebuilding and '
#          'retribution.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE5MzcyNjk1M15BMl5BanBnXkFtZTcwMjQ4MjcxOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 5, 3, 0, 0),
#  'runtime': 130,
#  'title': 'Iron Man 3',
#  'tomatoes': {'boxOffice': '$409.0M',
#               'consensus': 'With the help of its charismatic lead, some '
#                            'impressive action sequences, and even a few '
#                            'surprises, Iron Man 3 is a witty, entertaining '
#                            'adventure and a strong addition to the Marvel '
#                            'canon.',
#               'critic': {'meter': 79, 'numReviews': 284, 'rating': 7.0},
#               'dvd': datetime.datetime(2013, 9, 24, 0, 0),
#               'fresh': 224,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 50, 40),
#               'production': 'Walt Disney Pictures',
#               'rotten': 60,
#               'viewer': {'meter': 79, 'numReviews': 477835, 'rating': 4.0},
#               'website': 'http://IronManMovie3.com'},
#  'type': 'movie',
#  'writers': ['Drew Pearce (screenplay)',
#              'Shane Black (screenplay)',
#              'Stan Lee (based on the Marvel comic book by)',
#              'Don Heck (based on the Marvel comic book by)',
#              'Larry Lieber (based on the Marvel comic book by)',
#              'Jack Kirby (based on the Marvel comic book by)',
#              'Warren Ellis (based on the "Extremis" mini-series written by)',
#              'Adi Granov (based on the "Extremis" mini-series illustrated by)'],
#  'year': 2013}
# {'_id': ObjectId('573a13c3f29313caabd6ae04'),
#  'awards': {'nominations': 5, 'text': '3 wins & 5 nominations.', 'wins': 3},
#  'cast': ['Sylvester Stallone', 'Jason Statham', 'Jet Li', 'Dolph Lundgren'],
#  'countries': ['USA'],
#  'directors': ['Sylvester Stallone'],
#  'fullplot': 'Barney Ross leads the "Expendables", a band of highly skilled '
#              'mercenaries including knife enthusiast Lee Christmas, martial '
#              'arts expert Yin Yang, heavy weapons specialist Hale Caesar, '
#              'demolitionist Toll Road and loose-cannon sniper Gunner Jensen. '
#              'When the group is commissioned by the mysterious Mr. Church to '
#              'assassinate the merciless dictator of a small South American '
#              'island, Barney and Lee head to the remote locale to scout out '
#              'their opposition. Once there, they meet with local rebel Sandra '
#              'and discover the true nature of the conflict engulfing the city. '
#              'When they escape the island and Sandra stays behind, Ross must '
#              'choose to either walk away and save his own life - or attempt a '
#              'suicidal rescue mission that might just save his soul.',
#  'genres': ['Action', 'Adventure', 'Thriller'],
#  'imdb': {'id': 1320253, 'rating': 6.5, 'votes': 248398},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-09-10 17:23:44.970000000',
#  'metacritic': 45,
#  'num_mflix_comments': 0,
#  'plot': 'A CIA operative hires a team of mercenaries to eliminate a Latin '
#          'dictator and a renegade CIA agent.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTUwODQyNjM0NF5BMl5BanBnXkFtZTcwNDMwMTU1Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 8, 13, 0, 0),
#  'runtime': 103,
#  'title': 'The Expendables',
#  'tomatoes': {'boxOffice': '$103.0M',
#               'consensus': 'It makes good on the old-school action it '
#                            'promises, but given all the talent on display, The '
#                            'Expendables should hit harder.',
#               'critic': {'meter': 41, 'numReviews': 198, 'rating': 5.2},
#               'dvd': datetime.datetime(2010, 11, 23, 0, 0),
#               'fresh': 82,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 23, 46),
#               'production': 'Lionsgate Films',
#               'rotten': 116,
#               'viewer': {'meter': 64, 'numReviews': 296436, 'rating': 3.6},
#               'website': 'http://expendablesthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Dave Callaham (screenplay)',
#              'Sylvester Stallone (screenplay)',
#              'Dave Callaham (story)'],
#  'year': 2010}
# {'_id': ObjectId('573a13c3f29313caabd6afe7'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Tomer Sisley',
#           'Sharon Stone',
#           'Ulrich Tukur',
#           'Napakpapha Nakprasitte'],
#  'countries': ['France', 'Belgium', 'Germany'],
#  'directors': ['Jèrème Salle'],
#  'fullplot': 'Propelled to the head of the W Group after the death of his '
#              "adoptive father, Largo Winch decides, to everyone's surprise, to "
#              'sell it, and use the proceeds to create an ambitious '
#              'humanitarian foundation. But on the very same day, he finds '
#              'himself accused of crimes against humanity by a mysterious '
#              'witness. To prove his innocence, Largo will have to retrace the '
#              'steps of his past life, in the heart of the Burmese jungle...',
#  'genres': ['Action', 'Adventure', 'Thriller'],
#  'imdb': {'id': 1322333, 'rating': 6.2, 'votes': 5755},
#  'languages': ['French', 'English', 'Thai', 'Serbian'],
#  'lastupdated': '2015-09-05 00:32:42.463000000',
#  'num_mflix_comments': 0,
#  'plot': 'Largo Winch, the newly appointed CEO of the W Group, is accused of '
#          'crimes against humanity on the very day he announces his intention '
#          'to sell his corporation and use the proceeds to create a '
#          'humanitarian foundation.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTMwNjg0NzU5NV5BMl5BanBnXkFtZTcwNDE1NjE2NA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2011, 2, 16, 0, 0),
#  'runtime': 119,
#  'title': 'The Burma Conspiracy',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 1, 19, 32, 28),
#               'production': 'Wild Bunch',
#               'viewer': {'numReviews': 616, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Julien Rappeneau (scenario)',
#              'Jèrème Salle (scenario)',
#              'Jean Van Hamme (graphic novels)',
#              'Philippe Francq (graphic novels)',
#              'Jean Van Hamme (collaboration)'],
#  'year': 2011}
# {'_id': ObjectId('573a13c3f29313caabd6b650'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Jay Chou', 'Chiling Lin', 'Eric Tsang', 'Daoming Chen'],
#  'countries': ['Taiwan'],
#  'directors': ['Yen-Ping Chu'],
#  'fullplot': 'A notorious international crime group chases after a young '
#              "chivalrous man, his mentor's daughter, and a famous "
#              'archaeologist, who possess a map leading to ancient treasure.',
#  'genres': ['Action', 'Adventure', 'Fantasy'],
#  'imdb': {'id': 1328865, 'rating': 3.9, 'votes': 895},
#  'languages': ['Mandarin'],
#  'lastupdated': '2015-08-15 01:02:16.363000000',
#  'num_mflix_comments': 0,
#  'plot': 'A notorious international crime group chases after a young '
#          "chivalrous man, his mentor's daughter, and a famous archaeologist, "
#          'who possess a map leading to ancient treasure.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI5NjMxNjUxMV5BMl5BanBnXkFtZTgwMzk5NTAzMTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2009, 12, 30, 0, 0),
#  'title': 'The Treasure Hunter',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 3, 19, 12, 48),
#               'production': 'Eleven Arts Films',
#               'viewer': {'meter': 9, 'numReviews': 394, 'rating': 2.0},
#               'website': 'http://www.cinemaasiareleasing.com/thetreasurehunter'},
#  'type': 'movie',
#  'writers': ['Tan Cheung'],
#  'year': 2009}
# {'_id': ObjectId('573a13c4f29313caabd6bcc0'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Abhishek Bachchan',
#           'Aishwarya Rai Bachchan',
#           'Govinda',
#           "'Chiyaan' Vikram"],
#  'countries': ['India'],
#  'directors': ['Mani Ratnam'],
#  'fullplot': 'Ragini re-locates to distant Lal Matti along with her '
#              'Superintendent of Police husband, Dev Pratap Sharma, in order to '
#              'enable him to apprehend a bandit, Beera Munda. Shortly '
#              'thereafter her life will be turned upside down when she will be '
#              'abducted by Beera and held captive. It is during this captivity '
#              'she will not only find out that her fate will be decided within '
#              '14 hours, but also the real reason behind her abduction.',
#  'genres': ['Action', 'Adventure', 'Crime'],
#  'imdb': {'id': 1334470, 'rating': 5.3, 'votes': 3201},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-09-13 00:42:42.843000000',
#  'num_mflix_comments': 2,
#  'plot': 'A bandit leader kidnaps the wife of the policeman who killed his '
#          'sister, but later falls in love with her.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMWQxYWJiNjMtOWIxMi00ODJhLTg4NjctOThlMDk4YmZkNTU5XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2010, 6, 18, 0, 0),
#  'runtime': 130,
#  'title': 'Raavan',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 1, 19, 8, 49),
#               'production': 'Big Cinemas',
#               'viewer': {'numReviews': 86, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Mani Ratnam (screenplay)', 'Vijay Krishna Acharya (dialogue)'],
#  'year': 2010}
# {'_id': ObjectId('573a13c4f29313caabd6bd45'),
#  'awards': {'nominations': 5, 'text': '5 nominations.', 'wins': 0},
#  'cast': ['Keanu Reeves', 'Hiroyuki Sanada', 'Ko Shibasaki', 'Tadanobu Asano'],
#  'countries': ['USA'],
#  'directors': ['Carl Rinsch'],
#  'fullplot': 'While hunting in the forest, Lord Asano of Ako and his samurai '
#              'find a young half-breed and take him with them to live in the '
#              'castle. Several years later, Lord Asano holds a tournament to '
#              'welcome the Shogun to Ako. The night after the tournament, Lord '
#              'Asano is bewitched into hurting Lord Kira of Nagato, and is '
#              'punished into committing seppuku by the Shogun. Realizing that '
#              "it was a Lord Kira's evil plot, the samurais and the half-breed "
#              "sets out for revenge against the Shogun's order.",
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 1335975, 'rating': 6.3, 'votes': 106539},
#  'languages': ['English', 'Japanese'],
#  'lastupdated': '2015-09-14 17:30:48.850000000',
#  'metacritic': 28,
#  'num_mflix_comments': 1,
#  'plot': 'A band of samurai set out to avenge the death and dishonor of their '
#          'master at the hands of a ruthless shogun.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc0MjE2NzE0OV5BMl5BanBnXkFtZTgwNTU5MjE1MDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': '47 Ronin',
#  'tomatoes': {'boxOffice': '$38.3M',
#               'consensus': '47 Ronin is a surprisingly dull fantasy adventure, '
#                            'one that leaves its talented international cast '
#                            'stranded within one dimensional roles.',
#               'critic': {'meter': 15, 'numReviews': 75, 'rating': 4.1},
#               'dvd': datetime.datetime(2014, 4, 1, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 9, 58),
#               'production': 'Universal Pictures',
#               'rotten': 64,
#               'viewer': {'meter': 48, 'numReviews': 61404, 'rating': 3.2},
#               'website': 'http://www.47roninmovie.com/'},
#  'type': 'movie',
#  'writers': ['Chris Morgan (screenplay)',
#              'Hossein Amini (screenplay)',
#              'Chris Morgan (screen story by)',
#              'Walter Hamada (screen story by)'],
#  'year': 2013}
# {'_id': ObjectId('573a13c4f29313caabd6c383'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Arnold Schwarzenegger',
#           'Jason Clarke',
#           'Emilia Clarke',
#           'Jai Courtney'],
#  'countries': ['USA'],
#  'directors': ['Alan Taylor'],
#  'fullplot': 'When John Connor (Jason Clarke), leader of the human resistance, '
#              'sends Sgt. Kyle Reese (Jai Courtney) back to 1984 to protect '
#              'Sarah Connor (Emilia Clarke) and safeguard the future, an '
#              'unexpected turn of events creates a fractured timeline. Now, '
#              'Sgt. Reese finds himself in a new and unfamiliar version of the '
#              'past, where he is faced with unlikely allies, including the '
#              'Guardian (Arnold Schwarzenegger), dangerous new enemies, and an '
#              'unexpected new mission: To reset the future...',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1340138, 'rating': 6.8, 'votes': 92953},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 05:01:01.933000000',
#  'metacritic': 38,
#  'num_mflix_comments': 2,
#  'plot': 'When John Connor, leader of the human resistance, sends Sgt. Kyle '
#          'Reese back to 1984 to protect Sarah Connor and safeguard the future, '
#          'an unexpected turn of events creates a fractured timeline.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjM1NTc0NzE4OF5BMl5BanBnXkFtZTgwNDkyNjQ1NTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 7, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Terminator Genisys',
#  'tomatoes': {'boxOffice': '$89.6M',
#               'consensus': 'Mired in its muddled mythology, Terminator: '
#                            'Genisys is a lurching retread that lacks the '
#                            'thematic depth, conceptual intelligence, or visual '
#                            'thrills that launched this once-mighty franchise.',
#               'critic': {'meter': 26, 'numReviews': 209, 'rating': 4.7},
#               'dvd': datetime.datetime(2015, 10, 13, 0, 0),
#               'fresh': 55,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 56, 40),
#               'production': 'Paramount Pictures',
#               'rotten': 154,
#               'viewer': {'meter': 61, 'numReviews': 73681, 'rating': 3.5},
#               'website': 'http://www.facebook.com/TerminatorGenisys'},
#  'type': 'movie',
#  'writers': ['Laeta Kalogridis',
#              'Patrick Lussier',
#              'James Cameron (characters)',
#              'Gale Anne Hurd (characters)'],
#  'year': 2015}
# {'_id': ObjectId('573a13c5f29313caabd6fb62'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Christopher Meloni',
#           'Victor Garber',
#           'Tricia Helfer',
#           'Michael Madsen'],
#  'countries': ['USA'],
#  'directors': ['Lauren Montgomery'],
#  'fullplot': 'When pilot Hal Jordan accepts a mysterious, powerful ring from a '
#              'dying alien creature, it transforms him into a Green Lantern - '
#              'one of an elite force of heroes. These heroes patrol the '
#              'universe to ensure peace and justice under the leadership of the '
#              'Guardians of the Universe. Unsure of their newest recruit, the '
#              'Guardians assign Hal to their most-honored Green Lantern '
#              'Sinestro for training, unaware that Sinestro wants to overthrow '
#              "the Guardians and create a new order he'll control. It's a "
#              'battle of might and willpower as Hall must prove his worth by '
#              'defeating Sinestro to save the Green Lantern Corps.',
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 1384590, 'rating': 7.2, 'votes': 9379},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-08-18 00:46:12.297000000',
#  'num_mflix_comments': 0,
#  'plot': 'Test pilot Hal Jordan finds himself recruited as the newest member '
#          'of the intergalactic police force, The Green Lantern Corps.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOWQ4ZGExZGMtYjZjNS00NWMyLThmZTUtZjM0N2UxMzU5MTk5L2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2009, 7, 28, 0, 0),
#  'runtime': 77,
#  'title': 'Green Lantern: First Flight',
#  'tomatoes': {'critic': {'meter': 50, 'numReviews': 6, 'rating': 5.6},
#               'dvd': datetime.datetime(2009, 7, 28, 0, 0),
#               'fresh': 3,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 18, 2, 58),
#               'production': 'Warner Home Video',
#               'rotten': 3,
#               'viewer': {'meter': 70, 'numReviews': 3823, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Alan Burnett'],
#  'year': 2009}
# {'_id': ObjectId('573a13c5f29313caabd70010'),
#  'awards': {'nominations': 5, 'text': '1 win & 5 nominations.', 'wins': 1},
#  'cast': ['Scott F. Evans', 'John T. Woods', 'Angela Rachelle', 'Tara Smoker'],
#  'countries': ['USA'],
#  'directors': ['Ray Karwel'],
#  'fullplot': 'A mysterious woman helps prevent a notorious underworld criminal '
#              'from getting his hands on a set of strange coins that can tip '
#              'the balance between life and death.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1388369, 'rating': 5.5, 'votes': 52},
#  'languages': ['English'],
#  'lastupdated': '2015-09-07 01:05:44.867000000',
#  'num_mflix_comments': 0,
#  'plot': 'A mysterious woman helps prevent a notorious underworld criminal '
#          'from getting his hands on a set of strange coins that can tip the '
#          'balance between life and death.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1NjkzNzA5Nl5BMl5BanBnXkFtZTcwOTgwODg4NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2011, 7, 26, 0, 0),
#  'runtime': 82,
#  'title': 'Time Again',
#  'tomatoes': {'dvd': datetime.datetime(2012, 8, 21, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 16, 47),
#               'viewer': {'meter': 0, 'numReviews': 5, 'rating': 1.8},
#               'website': 'http://nastystrangers.com/TimeAgain.html'},
#  'type': 'movie',
#  'writers': ['Ray Karwel (screenplay)',
#              'C.S. Hill (screenplay)',
#              'Debbie Glovin (screenplay)',
#              'Ray Karwel (story)'],
#  'year': 2011}
# {'_id': ObjectId('573a13c5f29313caabd6fe15'),
#  'awards': {'nominations': 5, 'text': '1 win & 5 nominations.', 'wins': 1},
#  'cast': ['Colin Farrell', 'Kate Beckinsale', 'Jessica Biel', 'Bryan Cranston'],
#  'countries': ['USA', 'Canada'],
#  'directors': ['Len Wiseman'],
#  'genres': ['Action', 'Adventure', 'Mystery'],
#  'imdb': {'id': 1386703, 'rating': 6.3, 'votes': 189741},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 08:26:36.510000000',
#  'metacritic': 43,
#  'num_mflix_comments': 0,
#  'plot': 'A factory worker, Douglas Quaid, begins to suspect that he is a spy '
#          'after visiting Rekall - a company that provides its clients with '
#          'implanted fake memories of a life they would like to have led - goes '
#          'wrong and he finds himself on the run.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2ZiMDMzYWItNDllZC00ZmRmLWI1YzktM2M5M2ZmZDg1OGNlXkEyXkFqcGdeQXVyNDQ2MTMzODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 8, 3, 0, 0),
#  'runtime': 118,
#  'title': 'Total Recall',
#  'tomatoes': {'boxOffice': '$58.9M',
#               'consensus': 'While it boasts some impressive action sequences, '
#                            'Total Recall lacks the intricate plotting, wry '
#                            'humor, and fleshed out characters that made the '
#                            'original a sci-fi classic.',
#               'critic': {'meter': 30, 'numReviews': 218, 'rating': 5.0},
#               'dvd': datetime.datetime(2012, 12, 18, 0, 0),
#               'fresh': 66,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 3, 48),
#               'production': 'Sony Pictures',
#               'rotten': 152,
#               'viewer': {'meter': 47, 'numReviews': 114761, 'rating': 3.2},
#               'website': 'http://www.welcometorecall.com/'},
#  'type': 'movie',
#  'writers': ['Kurt Wimmer (screenplay)',
#              'Mark Bomback (screenplay)',
#              'Ronald Shusett (screen story by)',
#              "Dan O'Bannon (screen story by)",
#              'Jon Povill (screen story by)',
#              'Kurt Wimmer (screen story by)',
#              'Ronald Shusett (based on the motion picture "Total Recall"',
#              ' screenplay by)',
#              'Dan O\'Bannon (based on the motion picture "Total Recall"',
#              ' screenplay by)',
#              'Gary Goldman (based on the motion picture "Total Recall"',
#              ' screenplay by)',
#              'Ronald Shusett (based on the motion picture "Total Recall"',
#              ' screen story by)',
#              'Dan O\'Bannon (based on the motion picture "Total Recall"',
#              ' screen story by)',
#              'Jon Povill (based on the motion picture "Total Recall"',
#              ' screen story by)'],
#  'year': 2012}
# {'_id': ObjectId('573a13c5f29313caabd70568'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Hugh Keays-Byrne'],
#  'countries': ['Australia', 'USA'],
#  'directors': ['George Miller'],
#  'fullplot': 'An apocalyptic story set in the furthest reaches of our planet, '
#              'in a stark desert landscape where humanity is broken, and almost '
#              'everyone is crazed fighting for the necessities of life. Within '
#              'this world exist two rebels on the run who just might be able to '
#              "restore order. There's Max, a man of action and a man of few "
#              'words, who seeks peace of mind following the loss of his wife '
#              'and child in the aftermath of the chaos. And Furiosa, a woman of '
#              'action and a woman who believes her path to survival may be '
#              'achieved if she can make it across the desert back to her '
#              'childhood homeland.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1392190, 'rating': 8.3, 'votes': 314071},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-10 17:05:45.723000000',
#  'metacritic': 89,
#  'num_mflix_comments': 1,
#  'plot': 'A woman rebels against a tyrannical ruler in post apocalyptic '
#          'Australia in search for her homeland with the help of a group of '
#          'female prisoners, a psychotic worshiper, and a drifter named Max.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2EwM2I5OWMtMGQyMi00Zjg1LWJkNTctZTdjYTA4OGUwZjMyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 5, 15, 0, 0),
#  'runtime': 120,
#  'title': 'Mad Max: Fury Road',
#  'tomatoes': {'boxOffice': '$153.1M',
#               'consensus': 'With exhilarating action and a surprising amount '
#                            'of narrative heft, Mad Max: Fury Road brings '
#                            "George Miller's post-apocalyptic franchise roaring "
#                            'vigorously back to life.',
#               'critic': {'meter': 97, 'numReviews': 301, 'rating': 8.7},
#               'dvd': datetime.datetime(2015, 9, 1, 0, 0),
#               'fresh': 292,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 9, 27),
#               'production': 'Warner Bros.',
#               'rotten': 9,
#               'viewer': {'meter': 88, 'numReviews': 103105, 'rating': 4.3},
#               'website': 'http://www.madmaxmovie.com/'},
#  'type': 'movie',
#  'writers': ['George Miller', 'Brendan McCarthy', 'Nick Lathouris'],
#  'year': 2015}
# {'_id': ObjectId('573a13c5f29313caabd70a97'),
#  'awards': {'nominations': 4, 'text': '3 wins & 4 nominations.', 'wins': 3},
#  'cast': ['Dwayne Johnson', 'Michael Caine', 'Josh Hutcherson', 'Luis Guzmèn'],
#  'countries': ['USA'],
#  'directors': ['Brad Peyton'],
#  'fullplot': 'The 17-year-old Sean Anderson receives a coded signal and his '
#              'stepfather Hank helps him to decipher the message. They find '
#              "that Sean's grandfather Alexander Anderson has found the "
#              'mysterious island in the Pacific described by Jules Verne and '
#              'two other writers in their novels. The stubborn Sean wants to '
#              'travel to the coordinates and Hank decides to buy the tickets '
#              'and travel with the teenager to a small island nearby the '
#              'location. They rent an old helicopter owned by the locals Gabato '
#              'and his teenage daughter Kailani and the group heads to the '
#              'unknown spot. Along their journey, they cross a hurricane and '
#              'crash on the island. They find a beautiful and dangerous place, '
#              'surrounded by forests, volcanoes with lava of gold and menacing '
#              'life forms. They also meet the old Alexander and Hank discovers '
#              'that the island is sinking. Now their only chance to survive is '
#              'to find the legendary Nautilus.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 1397514, 'rating': 5.8, 'votes': 61301},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:39:06.337000000',
#  'metacritic': 41,
#  'num_mflix_comments': 0,
#  'plot': "Sean Anderson partners with his mom's husband on a mission to find "
#          'his grandfather, who is thought to be missing on a mythical island.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA5MTE1MjQyNV5BMl5BanBnXkFtZTcwODI4NDMwNw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2012, 2, 10, 0, 0),
#  'runtime': 94,
#  'title': 'Journey 2: The Mysterious Island',
#  'tomatoes': {'boxOffice': '$103.8M',
#               'consensus': 'Aggressively unambitious, Journey 2 might thrill '
#                            'tween viewers, but most others will find it too '
#                            'intense for young audiences and too cartoonishly '
#                            'dull for adults.',
#               'critic': {'meter': 42, 'numReviews': 125, 'rating': 4.9},
#               'dvd': datetime.datetime(2012, 6, 5, 0, 0),
#               'fresh': 52,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 16, 21),
#               'production': 'New Line Cinema',
#               'rotten': 73,
#               'viewer': {'meter': 59, 'numReviews': 211926, 'rating': 3.6},
#               'website': 'http://www.themysteriousisland.com/'},
#  'type': 'movie',
#  'writers': ['Brian Gunn (screenplay)',
#              'Mark Gunn (screenplay)',
#              'Richard Outten (story)',
#              'Brian Gunn (story)',
#              'Mark Gunn (story)',
#              'Jules Verne (novel)'],
#  'year': 2012}
# {'_id': ObjectId('573a13c5f29313caabd70b63'),
#  'awards': {'nominations': 39,
#             'text': 'Nominated for 3 Oscars. Another 11 wins & 39 nominations.',
#             'wins': 14},
#  'cast': ['Shia LaBeouf',
#           'Rosie Huntington-Whiteley',
#           'Josh Duhamel',
#           'John Turturro'],
#  'countries': ['USA'],
#  'directors': ['Michael Bay'],
#  'fullplot': 'Autobots Bumblebee, Ratchet, Ironhide, Mirage (aka Dino), '
#              'Wheeljack (aka Que) and Sideswipe led by Optimus Prime, are back '
#              'in action taking on the evil Decepticons, who are eager to '
#              'avenge their recent defeat. The Autobots and Decepticons become '
#              'involved in a perilous space race between the United States and '
#              'Russia, to reach a hidden Cybertronian spacecraft on the moon '
#              'and learn its secrets, and once again Sam Witwicky has to come '
#              'to the aid of his robot friends. The new villain Shockwave is on '
#              'the scene while the Autobots and Decepticons continue to battle '
#              'it out on Earth.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1399103, 'rating': 6.3, 'votes': 301462},
#  'languages': ['English'],
#  'lastupdated': '2015-08-24 00:05:31.930000000',
#  'metacritic': 42,
#  'num_mflix_comments': 0,
#  'plot': 'The Autobots learn of a Cybertronian spacecraft hidden on the moon, '
#          'and race against the Decepticons to reach it and to learn its '
#          'secrets.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTkwOTY0MTc1NV5BMl5BanBnXkFtZTcwMDQwNjA2NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2011, 6, 29, 0, 0),
#  'runtime': 154,
#  'title': 'Transformers: Dark of the Moon',
#  'tomatoes': {'boxOffice': '$352.4M',
#               'consensus': 'Its special effects -- and 3D shots -- are '
#                            "undeniably impressive, but they aren't enough to "
#                            'fill up its loud, bloated running time, or mask '
#                            'its thin, indifferent script.',
#               'critic': {'meter': 35, 'numReviews': 246, 'rating': 4.9},
#               'dvd': datetime.datetime(2011, 9, 30, 0, 0),
#               'fresh': 87,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 25, 52),
#               'production': 'Paramount Studios',
#               'rotten': 159,
#               'viewer': {'meter': 56, 'numReviews': 255456, 'rating': 3.5},
#               'website': 'http://www.TransformersMovie.com/'},
#  'type': 'movie',
#  'writers': ['Ehren Kruger'],
#  'year': 2011}
# {'_id': ObjectId('573a13c5f29313caabd70ce6'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Vasiliy Stepanov',
#           'Yuliya Snigir',
#           'Pyotr Fyodorov',
#           'Sergey Garmash'],
#  'countries': ['Russia'],
#  'directors': ['Fedor Bondarchuk'],
#  'fullplot': 'Maxim Kammerer fights for his love and freedom. He leads a rebel '
#              'movement challenging the five greedy rulers. One of the rulers, '
#              'Strannik, knows how dangerous Maxim can be. He makes up his mind '
#              'to stop the young man at any cost. The last close fight will '
#              'decide everything.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1399952, 'rating': 5.1, 'votes': 1889},
#  'languages': ['Russian'],
#  'lastupdated': '2015-09-13 00:11:58.657000000',
#  'num_mflix_comments': 3,
#  'plot': 'Maxim Kammerer fights for his love and freedom. He leads a rebel '
#          'movement challenging the five greedy rulers. One of the rulers, '
#          'Strannik, knows how dangerous Maxim can be. He makes up his ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOWY2ODZiMjQtY2JlMC00YmUzLWExNjQtZjQ2YzA5NTIxMmU1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2009, 4, 23, 0, 0),
#  'runtime': 105,
#  'title': 'Obitaemyy ostrov. Skhvatka',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 20, 18, 55, 53),
#               'viewer': {'meter': 50, 'numReviews': 59, 'rating': 3.2}},
#  'type': 'movie',
#  'writers': ['Marina Dyachenko (screenplay)',
#              'Sergey Dyachenko (screenplay)',
#              'Arkadiy Strugatskiy (original book "Obitaemyy ostrov")',
#              'Boris Strugatskiy (original book "Obitaemyy ostrov")',
#              'Eduard Volodarskiy (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c5f29313caabd70d59'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Corey Feldman',
#           'Casey B. Dolan',
#           'Tanit Phoenix',
#           'Jamison Newlander'],
#  'countries': ['South Africa', 'USA', 'Germany'],
#  'directors': ['Dario Piana'],
#  'fullplot': 'In San Cazador, California, the clumsy vampire hunter Edgar Frog '
#              'is evicted from his trailer. But the best-seller writer Gwen '
#              'Lieber offers him a job to destroy the head vampire DJ X that '
#              'promotes worldwide raves to increase his army of undead. Gwen '
#              'tells that her brother Peter disappeared in Ibiza two years ago '
#              'in an X-Party promoted by the alpha-vampire. Now DJ X is coming '
#              'to San Cazador to promote a sacrifice during a party in the '
#              'blood moon on the next Friday, and Edgar discovers that the rave '
#              'will take place in a slaughterhouse on an island. Gwen hires '
#              'also the Hollywood participant of reality show Lars von Goetz '
#              'that comes with the cameraman Claus. Edgar invites his brother '
#              'Alan to join the team but he declines, and he teams up with his '
#              'friend Zoe. When the group finds DJ X, Edgar discloses a secret '
#              'about the head-vampire.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 1400526, 'rating': 5.3, 'votes': 2975},
#  'languages': ['English'],
#  'lastupdated': '2015-08-26 01:31:37.587000000',
#  'num_mflix_comments': 0,
#  'plot': 'In San Cazador, California, the clumsy vampire hunter Edgar Frog is '
#          'evicted from his trailer. But the best-seller writer Gwen Lieber '
#          'offers him a job to destroy the head vampire DJ X that ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGMyZTEwMWItN2FlYy00YzUxLWI2OTktNmZkN2Y0MjI4MGE0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 10, 12, 0, 0),
#  'runtime': 81,
#  'title': 'Lost Boys: The Thirst',
#  'tomatoes': {'critic': {'meter': 0, 'numReviews': 6, 'rating': 4.1},
#               'dvd': datetime.datetime(2010, 10, 12, 0, 0),
#               'fresh': 0,
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 9, 28),
#               'production': 'Warner Home Video',
#               'rotten': 6,
#               'viewer': {'meter': 34, 'numReviews': 1537, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Evan Charnov (teleplay)',
#              'Hans Rodionoff (teleplay)',
#              'Evan Charnov (story)'],
#  'year': 2010}
# {'_id': ObjectId('573a13c5f29313caabd714a6'),
#  'awards': {'nominations': 42,
#             'text': 'Nominated for 1 Oscar. Another 8 wins & 42 nominations.',
#             'wins': 9},
#  'cast': ['Chris Pine', 'Zachary Quinto', 'Zoe Saldana', 'Karl Urban'],
#  'countries': ['USA'],
#  'directors': ['J.J. Abrams'],
#  'fullplot': 'When the crew of the Enterprise is called back home, they find '
#              'an unstoppable force of terror from within their own '
#              'organization has detonated the fleet and everything it stands '
#              'for, leaving our world in a state of crisis. With a personal '
#              'score to settle, Captain Kirk leads a manhunt to a war-zone '
#              'world to capture a one-man weapon of mass destruction. As our '
#              'heroes are propelled into an epic chess game of life and death, '
#              'love will be challenged, friendships will be torn apart, and '
#              'sacrifices must be made for the only family Kirk has left: his '
#              'crew.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1408101, 'rating': 7.8, 'votes': 361747},
#  'languages': ['English', 'Klingon'],
#  'lastupdated': '2015-09-10 17:46:02.550000000',
#  'metacritic': 72,
#  'num_mflix_comments': 1,
#  'plot': 'After the crew of the Enterprise find an unstoppable force of terror '
#          'from within their own organization, Captain Kirk leads a manhunt to '
#          'a war-zone world to capture a one-man weapon of mass destruction.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk2NzczOTgxNF5BMl5BanBnXkFtZTcwODQ5ODczOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 5, 16, 0, 0),
#  'runtime': 132,
#  'title': 'Star Trek Into Darkness',
#  'tomatoes': {'boxOffice': '$228.8M',
#               'consensus': 'Visually spectacular and suitably action packed, '
#                            'Star Trek Into Darkness is a rock-solid '
#                            'installment in the venerable sci-fi franchise, '
#                            "even if it's not as fresh as its predecessor.",
#               'critic': {'meter': 87, 'numReviews': 249, 'rating': 7.6},
#               'dvd': datetime.datetime(2013, 9, 10, 0, 0),
#               'fresh': 216,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 20, 7),
#               'production': 'Paramount',
#               'rotten': 33,
#               'viewer': {'meter': 90, 'numReviews': 308990, 'rating': 4.2},
#               'website': 'http://www.startrekmovie.com/'},
#  'type': 'movie',
#  'writers': ['Roberto Orci',
#              'Alex Kurtzman',
#              'Damon Lindelof',
#              'Gene Roddenberry (television series "Star Trek")'],
#  'year': 2013}
# {'_id': ObjectId('573a13c6f29313caabd7264b'),
#  'awards': {'nominations': 2, 'text': '6 wins & 2 nominations.', 'wins': 6},
#  'cast': ['Alec Newman', 'Ed Speleers', 'Melissa George', 'Kate Magowan'],
#  'countries': ['UK'],
#  'directors': ['Julian Gilbey'],
#  'fullplot': 'A group of five mountaineers are hiking and climbing in the '
#              'Scottish Highlands when they discover a young Serbian girl '
#              'buried in a small chamber in the wilderness. They become caught '
#              'up in a terrifying game of cat and mouse with the kidnappers as '
#              'they try to get the girl to safety.',
#  'genres': ['Action', 'Adventure', 'Crime'],
#  'imdb': {'id': 1422136, 'rating': 6.3, 'votes': 20771},
#  'languages': ['English', 'Serbian'],
#  'lastupdated': '2015-09-17 02:12:19.210000000',
#  'num_mflix_comments': 1,
#  'plot': 'A group of mountaineers in the Scottish Highlands discover a '
#          'kidnapped girl and are pursued by her captors.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTM5OTA2MTc2N15BMl5BanBnXkFtZTcwMjI3NDQyNg@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2011, 11, 2, 0, 0),
#  'runtime': 99,
#  'title': 'A Lonely Place to Die',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 1, 19, 11, 10),
#               'viewer': {'numReviews': 71, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Julian Gilbey', 'Will Gilbey'],
#  'year': 2011}
# {'_id': ObjectId('573a13c6f29313caabd71d68'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Ray Winstone',
#           'Temuera Morrison',
#           'Gareth Reeves',
#           'Mark Mitchinson'],
#  'countries': ['New Zealand', 'UK'],
#  'directors': ['Ian Sharp'],
#  'fullplot': 'An Afrikaner veteran of the Boer War has just immigrated to New '
#              'Zealand and is hired to track a man accused of killing a '
#              'soldier. While hunting through the countryside he captures his '
#              "fugitive, only to learn that he's innocent of the crime. When "
#              'faced with the life changing decision to turn him in or set him '
#              'free only one man will walk away alive.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 1414378, 'rating': 6.5, 'votes': 2714},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:41:07.507000000',
#  'num_mflix_comments': 1,
#  'plot': 'An Afrikaner veteran of the Boer War has just immigrated to New '
#          'Zealand and is hired to track a man accused of killing a soldier. '
#          'While hunting through the countryside he captures his ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTcwNDMxNTc1N15BMl5BanBnXkFtZTcwOTE1MTIwNA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2011, 4, 29, 0, 0),
#  'runtime': 102,
#  'title': 'Tracker',
#  'tomatoes': {'critic': {'meter': 85, 'numReviews': 13, 'rating': 6.0},
#               'dvd': datetime.datetime(2011, 8, 23, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 18, 12, 23),
#               'production': 'Kaleidoscope',
#               'rotten': 2,
#               'viewer': {'meter': 51, 'numReviews': 1107, 'rating': 3.3},
#               'website': 'http://www.trackerthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Nicolas van Pallandt'],
#  'year': 2010}
# {'_id': ObjectId('573a13c6f29313caabd729ad'),
#  'awards': {'nominations': 4, 'text': '2 wins & 4 nominations.', 'wins': 2},
#  'cast': ['Adrien Brody', 'Topher Grace', 'Alice Braga', 'Walton Goggins'],
#  'countries': ['USA'],
#  'directors': ['Nimrèd Antal'],
#  'fullplot': 'The mercenary Royce; the military Isabelle; the Russian soldier '
#              'Nikolai; the San Quentin criminal Stans; the Sierra Leone '
#              'militia Mombasa; the drug lord Cuchillo; the Yakuza Hanzo; and '
#              'the Doctor Edwin awake in free fall but they succeed to open '
#              'their parachutes landing in a jungle. Soon they discover that '
#              'they are on another planet and they are prey of aliens in a '
#              'deadly hunting game, and they need to join forces to destroy '
#              'their predators and survive.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1424381, 'rating': 6.4, 'votes': 160806},
#  'languages': ['English', 'Spanish', 'Russian'],
#  'lastupdated': '2015-08-31 00:32:45.217000000',
#  'metacritic': 51,
#  'num_mflix_comments': 0,
#  'plot': 'A group of elite warriors are hunted by members of a merciless alien '
#          'race known as Predators.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjFmNDNlMGItMDQxMS00ZWMxLTg4MmQtMTBiNWU3ZDU1Nzk1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 7, 9, 0, 0),
#  'runtime': 107,
#  'title': 'Predators',
#  'tomatoes': {'boxOffice': '$52.0M',
#               'consensus': 'After a string of subpar sequels, this bloody, '
#                            'action-packed reboot takes the Predator franchise '
#                            'back to its testosterone-fueled roots.',
#               'critic': {'meter': 64, 'numReviews': 187, 'rating': 5.8},
#               'dvd': datetime.datetime(2010, 10, 19, 0, 0),
#               'fresh': 119,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 18, 20, 16),
#               'production': '20th Century Fox',
#               'rotten': 68,
#               'viewer': {'meter': 52, 'numReviews': 158760, 'rating': 3.2},
#               'website': 'http://www.predators-movie.com/'},
#  'type': 'movie',
#  'writers': ['Alex Litvak',
#              'Michael Finch',
#              'Jim Thomas (characters)',
#              'John Thomas (characters)'],
#  'year': 2010}
# {'_id': ObjectId('573a13c6f29313caabd72978'),
#  'awards': {'nominations': 7, 'text': '3 wins & 7 nominations.', 'wins': 3},
#  'cast': ['Nathan Boyd', 'Jackie Chan', 'Terry Hackett', 'Sang-Woo Kwon'],
#  'countries': ['Hong Kong', 'China'],
#  'directors': ['Jackie Chan'],
#  'fullplot': 'Asian Hawk (Jackie Chan) leads a mercenary team to recover '
#              'several lost artifacts from the Old Summer Palace, the bronze '
#              'heads of the 12 Chinese Zodiac animals which was looted by '
#              'foreigners in the 1800s. Assisted by a Chinese student and a '
#              'Parisian lady, Hawk stops at nothing to accomplish the mission.',
#  'genres': ['Action', 'Adventure'],
#  'imdb': {'id': 1424310, 'rating': 6.2, 'votes': 13746},
#  'languages': ['English', 'Mandarin', 'French', 'Spanish', 'Russian'],
#  'lastupdated': '2015-08-27 00:30:46.167000000',
#  'metacritic': 29,
#  'num_mflix_comments': 0,
#  'plot': 'A man searches the world for a set of mystic artifacts - 12 bronze '
#          'heads of the animals from the Chinese zodiac.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMDZjODAzMmQtNGNkZC00MmYzLWEzNDUtNGY1ZjhmMTM1MTFhXkEyXkFqcGdeQXVyNTQxMzIzMDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 10, 18, 0, 0),
#  'runtime': 109,
#  'title': 'Chinese Zodiac',
#  'tomatoes': {'critic': {'meter': 38, 'numReviews': 8, 'rating': 5.2},
#               'dvd': datetime.datetime(2014, 3, 25, 0, 0),
#               'fresh': 3,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 50, 38),
#               'production': 'WAMCR',
#               'rotten': 5,
#               'viewer': {'meter': 46, 'numReviews': 2349, 'rating': 3.2}},
#  'type': 'movie',
#  'writers': ['Frankie Chan', 'Jackie Chan', 'Edward Tang', 'Stanley Tong'],
#  'year': 2012}
# {'_id': ObjectId('573a13c6f29313caabd73041'),
#  'awards': {'nominations': 9, 'text': '3 wins & 9 nominations.', 'wins': 3},
#  'cast': ['Hugh Jackman', 'Tao Okamoto', 'Rila Fukushima', 'Hiroyuki Sanada'],
#  'countries': ['USA', 'UK'],
#  'directors': ['James Mangold'],
#  'fullplot': 'In modern day Japan, Wolverine is out of his depth in an unknown '
#              'world as he faces his ultimate nemesis in a life-or-death battle '
#              'that will leave him forever changed. Vulnerable for the first '
#              'time and pushed to his physical and emotional limits, he '
#              'confronts not only lethal samurai steel but also his inner '
#              'struggle against his own immortality, emerging more powerful '
#              'than we have ever seen him before.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1430132, 'rating': 6.7, 'votes': 288624},
#  'languages': ['English', 'Japanese'],
#  'lastupdated': '2015-08-31 00:02:23.327000000',
#  'metacritic': 60,
#  'num_mflix_comments': 0,
#  'plot': 'When Wolverine is summoned to Japan by an old acquaintance, he is '
#          'embroiled in a conflict that forces him to confront his own demons.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzg1MDQxMTQ2OF5BMl5BanBnXkFtZTcwMTk3MjAzOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 7, 26, 0, 0),
#  'runtime': 126,
#  'title': 'The Wolverine',
#  'tomatoes': {'boxOffice': '$132.6M',
#               'consensus': 'Although its final act succumbs to the usual '
#                            'cartoonish antics, The Wolverine is one superhero '
#                            'movie that manages to stay true to the comics '
#                            'while keeping casual viewers entertained.',
#               'critic': {'meter': 70, 'numReviews': 232, 'rating': 6.3},
#               'dvd': datetime.datetime(2013, 12, 3, 0, 0),
#               'fresh': 162,
# ...
#              'the boy to meet his father. Half a world away a trail of '
#              'chemical plant heists finds the Batman catching the culprit in '
#              'the very act. The thief is Killer Croc, but Croc has changed '
#              'mutated by some unseen hand. With the shocking appearance of the '
#              'lovely but deadly Talia, Croc is quickly taken down. Back at '
#              "Gotham harbor Talia gives the Detective the news of Ra's fate "
#              'along with the surprise of introducing him to Damien, their son. '
#              'Talia sets out to handle Slade while Damien falls under the '
#              'guardianship of Batman. The young man possess great fighting '
#              'prowess but his cocky self confidence creates friction back at '
#              "Wayne Manor. Batman's investigation into Croc's actions leads "
#              'him to the home of Dr. Kirk Langstrom, creator of the Man-bat '
#              'formula. But Langstrom is merely another pawn serving the '
#              'ambitions of the League of Assassins and their new leader '
#              "Deathstroke. Deathstroke takes Langstrom's family hostage moving "
#              'up the time-table for product delivery. Meanwhile Damien using '
#              "the Batcave's resources conducts his own manhunt. One of Slade's "
#              "lieutenant's likes to spend his off time in Gotham. Damien "
#              'combats the traitor but before he can deliver the final blow, is '
#              "stopped by Nightwing. Batman impressed by Damien's ability and "
#              'drive allows him to take up the mantel of Robin. Soon the two '
#              'are hot on the trail of Deathstroke who is aiming to amass an '
#              'army of ninja Man-bats. Can Batman teach his new sidekick what '
#              'it takes to be a hero, leaving behind his murderous past? Or '
#              'will his greatest challenge yet prove to be for the very soul of '
#              'the son of Batman.',
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 3139072, 'rating': 6.6, 'votes': 9084},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:48:58.057000000',
#  'num_mflix_comments': 0,
#  'plot': 'Batman learns he has a violent, unruly pre-teen son, secretly raised '
#          'by the terrorist group the League of Assassins.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjdkZWFhNzctYmNhNy00NGM5LTg0Y2YtZWM4NmU2MWQ3ODVkXkEyXkFqcGdeQXVyNTA0OTU0OTQ@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 5, 6, 0, 0),
#  'runtime': 74,
#  'title': 'Son of Batman',
#  'tomatoes': {'dvd': datetime.datetime(2014, 8, 12, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 16, 21),
#               'production': 'WARNER BROTHERS PICTURES',
#               'viewer': {'meter': 86, 'numReviews': 2589, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Bob Kane (characters)',
#              'Grant Morrison (comic book)',
#              'Andy Kubert (graphic novel illustrator)',
#              'James Robinson (story)',
#              'Joe R. Lansdale (screenplay)'],
#  'year': 2014}
# {'_id': ObjectId('573a13e8f29313caabdca5f7'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Alexander Karim',
#           'Jens Hultèn',
#           'Torkel Petersson',
#           'Simon J. Berger'],
#  'countries': ['Sweden'],
#  'directors': ['Alain Darborg'],
#  'fullplot': 'Charles Ingvar Jènsson gathers three criminals to take vengeance '
#              'upon the people who killed his uncle.',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 3220192, 'rating': 5.7, 'votes': 885},
#  'languages': ['Swedish'],
#  'lastupdated': '2015-09-01 00:52:41.943000000',
#  'num_mflix_comments': 1,
#  'plot': 'Charles Ingvar Jènsson gathers three criminals to take vengeance '
#          'upon the people who killed his uncle.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NzQzMTcwM15BMl5BanBnXkFtZTgwNjY3NjI1MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 1, 16, 0, 0),
#  'runtime': 91,
#  'title': 'The Master Plan',
#  'type': 'movie',
#  'writers': ['Piotr Marciniak', 'Alain Darborg'],
#  'year': 2015}
# {'_id': ObjectId('573a13ebf29313caabdcfe3e'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Melanie Stone', 'Adam Johnson', 'Jake Stormoen', 'Nicola Posener'],
#  'countries': ['USA'],
#  'directors': ['Anne K. Black'],
#  'fullplot': 'Stuck in a life of indentured servitude, Marek dreams of '
#              'becoming a wizard. When she meets a beautiful priestess, Teela, '
#              'in need of help, Marek escapes her master and puts together a '
#              "team of adventurers and embarks on an epic quest to free Teela's "
#              'sister from a vicious ogre.',
#  'genres': ['Action', 'Adventure', 'Fantasy'],
#  'imdb': {'id': 3405714, 'rating': 4.9, 'votes': 779},
#  'languages': ['English'],
#  'lastupdated': '2015-09-07 00:35:06.910000000',
#  'num_mflix_comments': 0,
#  'plot': 'The young magician Marek dreams of exciting adventures. When she '
#          'meets the help-seeking priestess Teela she offers her assistance and '
#          "provides a motley troupe. Together they go in search of Teela's "
#          'sister, who was kidnapped by a wild ogre.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTYwMzkwMjg3Ml5BMl5BanBnXkFtZTgwNzUwMjQxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 12, 8, 0, 0),
#  'runtime': 93,
#  'title': 'Mythica: A Quest for Heroes',
#  'type': 'movie',
#  'writers': ['Anne K. Black', 'Jason Faller', 'Kynan Griffin'],
#  'year': 2014}
# {'_id': ObjectId('573a13eff29313caabdd88e1'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Jackie Chan', 'John Cusack', 'Adrien Brody', 'Si Won Choi'],
#  'countries': ['China'],
#  'directors': ['Daniel Lee'],
#  'fullplot': 'A massive success this year in its native China, "Dragon Blade" '
#              'brings action spectacle on a grand scale to US audiences. '
#              'Featuring an international cast led by Jackie Chan, John Cusack '
#              'and Academy Awardè winner Adrien Brody, the film features the '
#              'fight for the Silk Road when East and West collide. When corrupt '
#              'Roman leader Tiberius (Adrien Brody) arrives with a giant army '
#              'to claim the Silk Road, Huo An (Jackie Chan) and his group of '
#              'trained warriors teams up with an elite legion of defected Roman '
#              'soldiers led by General Lucius (John Cusack) to maintain the '
#              'delicate balance of power in the region. To protect his country '
#              'and his new friends, Huo An gathers the warriors of thirty-six '
#              'ethnic nations together to fight Tiberius in an incredible epic '
#              'battle. The film is written and directed by Daniel Lee ("Black '
#              'Mask") and produced by Jackie Chan and Susanna Tsang.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 3672840, 'rating': 6.3, 'votes': 5948},
#  'languages': ['Mandarin', 'English'],
#  'lastupdated': '2015-08-25 00:08:03.197000000',
#  'num_mflix_comments': 0,
#  'plot': 'When corrupt Roman leader Tiberius arrives with a giant army to '
#          'claim the Silk Road, Huo An teams up his army with an elite Legion '
#          'of defected Roman soldiers led by General Lucius to protect his '
#          'country and his new friends.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk0MjgxOTQ5MF5BMl5BanBnXkFtZTgwODA3NTUwNjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 4, 0, 0),
#  'runtime': 127,
#  'title': 'Dragon Blade',
#  'type': 'movie',
#  'writers': ['Daniel Lee'],
#  'year': 2015}
# {'_id': ObjectId('573a13f1f29313caabddbae3'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['David Maler',
#           'Paula Sanchez Ferry',
#           'Hèctor Anèbal',
#           'Nashla Bogaert'],
#  'countries': ['Dominican Republic'],
#  'directors': ['Pedro Urrutia'],
#  'fullplot': 'Pedro Ruiz, is a Dominican real estate broker by day and a savvy '
#              'but out-of-luck thief by night. Desperate to look for respect '
#              'climbing the money ladder the easy way, and avoiding years of '
#              'boredom as an employee, he gets in the wrong mansion at the '
#              'wrong time. Caught in the middle of a twisted plot of power '
#              'shift, two heavily armed gangs clashed full force, sweeping '
#              'Pedro and Paz -the daughter of a feared drug trafficker '
#              'assassinated while Pedro were robbing the mansion-, into the red '
#              'waters of a bloodbath. A final turn of events put the worlds of '
#              'everybody involved, upside down.',
#  'genres': ['Action', 'Adventure', 'Crime'],
#  'imdb': {'id': 3782876, 'rating': 7.3, 'votes': 202},
#  'languages': ['Spanish'],
#  'lastupdated': '2015-08-25 01:09:17.570000000',
#  'num_mflix_comments': 0,
#  'plot': 'Pedro Ruiz, is a Dominican real estate broker by day and a savvy but '
#          'out-of-luck thief by night. Desperate to look for respect climbing '
#          'the money ladder the easy way, he gets in the wrong mansion at the '
#          'wrong time.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI4MTI5OTUzMV5BMl5BanBnXkFtZTgwODI3MzY1MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 9, 18, 0, 0),
#  'runtime': 101,
#  'title': 'Cèdigo Paz',
#  'type': 'movie',
#  'writers': ['Luis Arambilet (screenplay)',
#              'Luis Arambilet',
#              'Pedro Urrutia',
#              'Pedro Urrutia (creator)',
#              'Pedro Urrutia (story)'],
#  'year': 2014}
# {'_id': ObjectId('573a13f1f29313caabddc14c'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Aadil Chahal', 'Aaran Chaudhary', 'Pranay Dixit', 'Subrat Dutta'],
#  'countries': ['India'],
#  'directors': ['Kamal Sadanah'],
#  'fullplot': 'After his photojournalist brother gets killed by a white tigress '
#              'in the jungles of the Sundarbans, Pandit and his team of '
#              'commandos enter the prohibited core area of the forest to avenge '
#              'his death.',
#  'genres': ['Action', 'Adventure', 'Thriller'],
#  'imdb': {'id': 3796006, 'rating': 5.7, 'votes': 521},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-09 00:45:26.710000000',
#  'num_mflix_comments': 0,
#  'plot': 'After his photojournalist brother gets killed by a white tigress in '
#          'the jungles of the Sundarbans, Pandit and his team of commandos '
#          'enter the prohibited core area of the forest to avenge his death.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk5OTkzNDc1NV5BMl5BanBnXkFtZTgwODg4NDExMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 10, 31, 0, 0),
#  'runtime': 123,
#  'title': 'Roar',
#  'type': 'movie',
#  'writers': ['Aanand Goradiya (dialogue)',
#              'Aanand Goradiya (screenplay)',
#              'Swati Goradiya (dialogue)',
#              'Swati Goradiya (screenplay)',
#              'Abis Rizvi (story)',
#              'Kamal Sadanah (screenplay)',
#              'Kamal Sadanah (story)'],
#  'year': 2014}
# {'_id': ObjectId('573a13f1f29313caabddc613'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Steven Waddington',
#           'Siennah Buck',
#           'Mike Colter',
#           'Christian Contreras'],
#  'fullplot': 'In the 28th Century, the prolonged war between humanity and the '
#              'fanatical alien alliance the Covenant has ended with a tenuous '
#              "treaty. Despite the ceasefire, Earth's outer colonies remain "
#              "vulnerable to the Covenant's covert intrusions. The ONI - Office "
#              'of Naval Intelligence has been tasked with counterintelligence '
#              'to beat the Covenant. In Planet Sedra, Commander Jameson Locke '
#              "and his team witness a Covenant's spacecraft and a Zealot Elite "
#              'warrior disembarks with a bomb. They unsuccessfully try to stop '
#              'the alien that explodes the bomb in a mall. They realize that it '
#              'is a biological attack with an element fatal to humans. Sedran '
#              'Commander Aiken captures the middleman Axl that tells that the '
#              'element is obtained from Alpha Halo, where the day longs 16 h '
#              'and the temperature in the sunlight reaches 482o C. Aiken, Locke '
#              'and his team head to Halo in the spacecraft Condor with pilot '
#              'Macer carrying a Havoc weapon to destroy the place. On the '
#              'arrival, they find two terrorists but are trapped in Halo by '
#              'weird worms that are attracted by technology. And in five hours '
#              'the sun will rise.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 3804114, 'rating': 5.7, 'votes': 2640},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 00:40:26.313000000',
#  'num_mflix_comments': 0,
#  'plot': 'While investigating terrorist activity on the distant colony world '
#          'of Sedra, Jameson Locke and his team are caught in a horrific '
#          'biological attack that exposes them to a much deeper danger.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NTQwNzU2OV5BMl5BanBnXkFtZTgwNzkxOTQ0MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 11, 11, 0, 0),
#  'runtime': 30,
#  'title': 'Halo: Nightfall',
#  'type': 'series',
#  'year': '2014è'}
# {'_id': ObjectId('573a13f3f29313caabddf066'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Ikue Ohtani', 'Sarah Natochenny', 'Haven Paschall', 'Mike Liscio'],
#  'countries': ['Japan'],
#  'directors': ['Kunihiko Yuyama'],
#  'fullplot': 'When Diancie a Pokèmon said to create diamond travels to find '
#              'Xerneas to help her make a heart diamond to save her home, Ash, '
#              'Serena, Clemont and Bonnie help her to be safe on the way from '
#              'thieves.',
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 3918368, 'rating': 5.5, 'votes': 187},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-31 00:49:15.373000000',
#  'num_mflix_comments': 0,
#  'plot': 'When Diancie a Pokèmon said to create diamond travels to find '
#          'Xerneas to help her make a heart diamond to save her home, Ash, '
#          'Serena, Clemont and Bonnie help her to be safe on the way from '
#          'thieves.',
#  'released': datetime.datetime(2014, 11, 8, 0, 0),
#  'runtime': 76,
#  'title': 'Pokèmon the Movie: Diancie and the Cocoon of Destruction',
#  'type': 'movie',
#  'writers': ['Hideki Sonoda (screenplay)',
#              'Satoshi Tajiri (original concept)',
#              'Junichi Masuda (original concept)',
#              'Ken Sugimori (original concept)'],
#  'year': 2014}
# {'_id': ObjectId('573a13f6f29313caabde50df'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Kumiko Asè', 'Rirè Furankè', 'Suzu Hirose', 'Haru Kuroki'],
#  'countries': ['Japan'],
#  'directors': ['Mamoru Hosoda'],
#  'fullplot': 'Kyuta, a boy living in Shibuya, and Kumatetsu, a lonesome beast '
#              'from Jutengai, an imaginary world. One day, Kyuta forays into '
#              "the imaginary world and, as he's looking for his way back, meets "
#              'Kumatetsu who becomes his spirit guide. That encounter leads '
#              'them to many adventures.',
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 4272866, 'rating': 7.4, 'votes': 92},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-29 00:53:10.563000000',
#  'num_mflix_comments': 0,
#  'plot': 'Kyuta, a boy living in Shibuya, and Kumatetsu, a lonesome beast from '
#          'Jutengai, an imaginary world. One day, Kyuta forays into the '
#          "imaginary world and, as he's looking for his way back, ...",
#  'released': datetime.datetime(2015, 7, 11, 0, 0),
#  'runtime': 119,
#  'title': 'The Boy and the Beast',
#  'type': 'movie',
#  'writers': ['Mamoru Hosoda'],
#  'year': 2015}

# %% [markdown]
# Exercise 2: Sorting Results

# %%
# 1. Write a query to find all movies where the genre is "Comedy" and sort them by IMDb rating in descending order (Return the first 5 results)
sorted_comedy_movies = collection.find({"genres": "Comedy"}).sort("imdb.rating", -1).limit(5)
for movie in sorted_comedy_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13dcf29313caabdb2dec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Jennifer Jason Leigh', 'David Thewlis', 'Tom Noonan'],
#  'countries': ['USA'],
#  'directors': ['Duke Johnson', 'Charlie Kaufman'],
#  'fullplot': "Charlie Kaufman's first stop-motion film about a man crippled by "
#              'the mundanity of his life.',
#  'genres': ['Animation', 'Comedy', 'Fantasy'],
#  'imdb': {'id': 2401878, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:00:23.967000000',
#  'num_mflix_comments': 0,
#  'plot': "Charlie Kaufman's first stop-motion film about a man crippled by the "
#          'mundanity of his life.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Anomalisa',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 26, 18, 15, 38),
#               'production': 'Walt Disney Pictures International',
#               'viewer': {'numReviews': 12, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Charlie Kaufman'],
#  'year': 2015}
# {'_id': ObjectId('573a13d9f29313caabdaa62d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ray Panthaki', 'Vicky McClure', 'Adeel Akhtar', 'Jenny Bede'],
#  'countries': ['UK'],
#  'directors': ['Keri Collins'],
#  'fullplot': 'Two convenience store robbers mess up the crime and end up '
#              'working there for the rest of the night.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2263210, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 17:30:41.583000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two convenience store robbers mess up the crime and end up working '
#          'there for the rest of the night.',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'title': 'Convenience',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 9, 52, 44),
#               'viewer': {'numReviews': 3, 'rating': 4.0},
#               'website': 'http://www.convenience-movie.com'},
#  'type': 'movie',
#  'writers': ['Simon Fantauzzo'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb909e'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jessie Barr',
#           'Louis Cancelmi',
#           'Margaret Daly',
#           'Caitlin FitzGerald'],
#  'countries': ['USA'],
#  'directors': ["Tom O'Brien"],
#  'fullplot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#              'finish his film, a study on relationship while navigating the '
#              'relationships in his own life. Will he continue to chase the '
#              'unattainable Theresa a hippy new age dancer(Caitlin Fitzgerald) '
#              "or will he finally admit he's in love with his best friend Carla "
#              '(Katherine Waterston) who is in an unfulfilling relationship '
#              'with a political strategist(Gaby Hoffman). Manhattan Romance is '
#              'a funny insightful look at contemporary life in Manhattan. It '
#              'explores new age ideas and open relationship as well as true '
#              'friendship and connection.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 2608324, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:17:01.610000000',
#  'num_mflix_comments': 0,
#  'plot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#          'finish his film, a study on relationship while navigating the '
#          'relationships in his own life. Will he continue to chase the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'runtime': 94,
#  'title': 'Manhattan Romance',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 57, 41),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ["Tom O'Brien"],
#  'year': 2015}
# {'_id': ObjectId('573a13def29313caabdb627d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Gracie Mei Huntsman',
#           'Jon Huntsman',
#           'Jerome A. Cohen',
#           'Chen Guangcheng'],
#  'countries': ['China', 'USA'],
#  'directors': ['Vanessa Hope'],
#  'genres': ['Documentary', 'Comedy', 'History'],
#  'imdb': {'id': 2505376, 'rating': '', 'votes': ''},
#  'languages': ['English', 'Chinese'],
#  'lastupdated': '2015-08-26 01:05:17.383000000',
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNzYzNzIyM15BMl5BanBnXkFtZTgwMjA4ODgxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 20, 0, 0),
#  'runtime': 90,
#  'title': 'All Eyes and Ears',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 18, 3, 5),
#               'viewer': {'numReviews': 1, 'rating': 1.5}},
#  'type': 'movie',
#  'writers': ['Vanessa Hope'],
#  'year': 2015}
# {'_id': ObjectId('573a13cff29313caabd88f5b'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Halston Sage',
#           'Tye Sheridan',
#           'Patrick Schwarzenegger',
#           'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Christopher Landon'],
#  'fullplot': 'Three scouts, on the eve of their last camp-out, discover the '
#              'true meaning of friendship when they attempt to save their town '
#              'from a zombie outbreak.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 1727776, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:00:19.697000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three scouts, on the eve of their last camp-out, discover the true '
#          'meaning of friendship when they attempt to save their town from a '
#          'zombie outbreak.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'runtime': 93,
#  'title': 'Scouts Guide to the Zombie Apocalypse',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8),
#               'production': 'Paramount Pictures',
#               'viewer': {'numReviews': 91, 'rating': 2.8},
#               'website': 'http://www.scoutsandzombiesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Emi Mochizuki (screenplay)',
#              'Carrie Lee Wilson (screenplay)',
#              'Christopher Landon (screenplay)',
#              'Lona Williams (screenplay)'],
#  'year': 2015}

# %%
#2. Write a query to find all movies where the genre is "Drama" and sort them by release year in ascending order (Return the first 5 results).**Example Code**:
sorted_drama_movies = collection.find({"genres": "Drama"}).sort("year", 1).limit(5)
for movie in sorted_drama_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd446f'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Frank Powell',
#           'Grace Henderson',
#           'James Kirkwood',
#           'Linda Arvidson'],
#  'countries': ['USA'],
#  'directors': ['D.W. Griffith'],
#  'fullplot': 'A greedy tycoon decides, on a whim, to corner the world market '
#              "in wheat. This doubles the price of bread, forcing the grain's "
#              'producers into charity lines and further into poverty. The film '
#              'continues to contrast the ironic differences between the lives '
#              'of those who work to grow the wheat and the life of the man who '
#              'dabbles in its sale for profit.',
#  'genres': ['Short', 'Drama'],
#  'imdb': {'id': 832, 'rating': 6.6, 'votes': 1375},
#  'languages': ['English'],
#  'lastupdated': '2015-08-13 00:46:30.660000000',
#  'num_mflix_comments': 1,
#  'plot': 'A greedy tycoon decides, on a whim, to corner the world market in '
#          "wheat. This doubles the price of bread, forcing the grain's "
#          'producers into charity lines and further into poverty. The film...',
#  'rated': 'G',
#  'released': datetime.datetime(1909, 12, 13, 0, 0),
#  'runtime': 14,
#  'title': 'A Corner in Wheat',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 11, 18, 36, 53),
#               'viewer': {'meter': 73, 'numReviews': 109, 'rating': 3.6}},
#  'type': 'movie',
#  'year': 1909}
# {'_id': ObjectId('573a1390f29313caabcd4eaf'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#  'countries': ['USA'],
#  'directors': ['George Loane Tucker'],
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 3471, 'rating': 6.0, 'votes': 371},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 02:07:14.247000000',
#  'num_mflix_comments': 1,
#  'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to '
#          'uncover the prostitution ring that has kidnapped her sister, and the '
#          'philanthropist who secretly runs it.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(1913, 11, 24, 0, 0),
#  'runtime': 88,
#  'title': 'Traffic in Souls',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 10, 18, 33, 55),
#               'viewer': {'meter': 57, 'numReviews': 85, 'rating': 3.0}},
#  'type': 'movie',
#  'year': 1913}
# {'_id': ObjectId('573a1390f29313caabcd516c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Stanley Hunt',
#           'Sarah Constance Smith Hunt',
#           'Mrs. George Walkus',
#           "Paddy 'Malid"],
#  'countries': ['USA'],
#  'directors': ['Edward S. Curtis'],
#  'genres': ['Drama', 'History'],
#  'imdb': {'id': 4150, 'rating': 5.8, 'votes': 223},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 12:11:37.770000000',
#  'num_mflix_comments': 1,
#  'plot': 'Original advertising for the film describes it as a drama of '
#          'primitive life on the shores of the North Pacific...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1914, 12, 7, 0, 0),
#  'runtime': 65,
#  'title': 'In the Land of the Head Hunters',
#  'tomatoes': {'dvd': datetime.datetime(2000, 8, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 19, 21, 12),
#               'production': 'World Film Corporation',
#               'viewer': {'meter': 18, 'numReviews': 64, 'rating': 2.7},
#               'website': 'http://www.milestonefilms.com/'},
#  'type': 'movie',
#  'writers': ['Edward S. Curtis (story)'],
#  'year': 1914}
# {'_id': ObjectId('573a1390f29313caabcd587d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'],
#  'countries': ['USA'],
#  'directors': ['Raoul Walsh'],
#  'fullplot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#              'mother dies. The Conways, who are next door neighbors, take Owen '
#              'in, but the constant drinking by Jim soon puts Owen on the '
#              'street. By 17, Owen learns that might is right. By 25, Owen is '
#              'the leader of his own gang who spend most of their time gambling '
#              'and drinking. But Marie comes into the gangster area of town and '
#              'everything changes for Owen as he falls for Marie. But he cannot '
#              'tell her so, so he comes to her settlement to find education and '
#              'inspiration. But soon, his old way of life will rise to confront '
#              'him again.',
#  'genres': ['Biography', 'Crime', 'Drama'],
#  'imdb': {'id': 5960, 'rating': 6.8, 'votes': 626},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 01:28:18.957000000',
#  'num_mflix_comments': 1,
#  'plot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#          'mother dies. The Conways, who are next door neighbors, take Owen in, '
#          'but the constant drinking by Jim soon puts Owen on the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 9, 13, 0, 0),
#  'runtime': 72,
#  'title': 'Regeneration',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 5, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 11, 27, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 22, 42),
#               'production': 'Fox Film Corporation',
#               'rotten': 0,
#               'viewer': {'meter': 70, 'numReviews': 395, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Owen Frawley Kildare (book)',
#              'Raoul Walsh (adapted from the book: "My Mamie Rose")',
#              'Carl Harbaugh (adapted from the book: "My Mamie Rose")'],
#  'year': 1915}
# {'_id': ObjectId('573a1390f29313caabcd56df'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'],
#  'countries': ['USA'],
#  'directors': ['Reginald Barker'],
#  'fullplot': 'An immigrant leaves his sweetheart in Italy to find a better '
#              'life across the sea in the grimy slums of New York. They are '
#              'eventually reunited and marry. But life in New York is hard and '
#              'tragedy tarnishes their dream of a better life in the new world.',
#  'genres': ['Drama'],
#  'imdb': {'id': 5557, 'rating': 6.4, 'votes': 175},
#  'languages': ['English'],
#  'lastupdated': '2015-07-27 00:07:43.230000000',
#  'num_mflix_comments': 0,
#  'plot': 'An immigrant leaves his sweetheart in Italy to find a better life '
#          'across the sea in the grimy slums of New York. They are eventually '
#          'reunited and marry. But life in New York is hard and ...',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 1, 1, 0, 0),
#  'runtime': 78,
#  'title': 'The Italian',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 24, 19, 30, 2),
#               'viewer': {'meter': 60, 'numReviews': 204, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'],
#  'year': 1915}

# %% [markdown]
# Exercise 3: Aggregation Pipeline

# %%
# 1. Write an aggregation pipeline that calculates the average IMDb rating for each genre (Return the top 5 genres)
avg_rating_by_genre = collection.aggregate([
    {"$unwind": "$genres"},
    {"$group": {"_id": "$genres", "average_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"average_rating": -1}},
    {"$limit": 5}
])
for genre in avg_rating_by_genre:
    pprint.pprint(genre)
# Out:
# {'_id': 'Film-Noir', 'average_rating': 7.396774193548388}
# {'_id': 'Short', 'average_rating': 7.390625}
# {'_id': 'Documentary', 'average_rating': 7.365130483064964}
# {'_id': 'News', 'average_rating': 7.252272727272728}
# {'_id': 'History', 'average_rating': 7.171942446043165}

# %%
#2. Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of their movies
top_directors = collection.aggregate([
    {"$group": {"_id": "$director", "average_rating": {"$avg": "$imdb.rating"}}},
    {"$sort": {"average_rating": -1}},
    {"$limit": 5}
])
for director in top_directors:
    pprint.pprint(director)
# Out:
# {'_id': None, 'average_rating': 6.645295171679017}

# %%
# 3. Write an aggregation pipeline to calculate the total number of movies released in each year (Sort the results by the year).
movies_per_year = collection.aggregate([
    {"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
    {"$sort": {"_id": 1}}
])
for year in movies_per_year:
    pprint.pprint(year)
# Out:
# {'_id': 1896, 'total_movies': 2}
# {'_id': 1903, 'total_movies': 1}
# {'_id': 1909, 'total_movies': 1}
# {'_id': 1911, 'total_movies': 2}
# {'_id': 1913, 'total_movies': 1}
# {'_id': 1914, 'total_movies': 3}
# {'_id': 1915, 'total_movies': 2}
# {'_id': 1916, 'total_movies': 2}
# {'_id': 1917, 'total_movies': 2}
# {'_id': 1918, 'total_movies': 1}
# {'_id': 1919, 'total_movies': 1}
# {'_id': 1920, 'total_movies': 4}
# {'_id': 1921, 'total_movies': 5}
# {'_id': 1922, 'total_movies': 3}
# {'_id': 1923, 'total_movies': 2}
# {'_id': 1924, 'total_movies': 6}
# {'_id': 1925, 'total_movies': 3}
# {'_id': 1926, 'total_movies': 6}
# {'_id': 1927, 'total_movies': 4}
# {'_id': 1928, 'total_movies': 8}
# {'_id': 1929, 'total_movies': 7}
# {'_id': 1930, 'total_movies': 10}
# {'_id': 1931, 'total_movies': 20}
# {'_id': 1932, 'total_movies': 18}
# {'_id': 1933, 'total_movies': 20}
# {'_id': 1934, 'total_movies': 23}
# {'_id': 1935, 'total_movies': 31}
# {'_id': 1936, 'total_movies': 30}
# {'_id': 1937, 'total_movies': 31}
# {'_id': 1938, 'total_movies': 38}
# {'_id': 1939, 'total_movies': 20}
# {'_id': 1940, 'total_movies': 24}
# {'_id': 1941, 'total_movies': 24}
# {'_id': 1942, 'total_movies': 30}
# {'_id': 1943, 'total_movies': 32}
# {'_id': 1944, 'total_movies': 23}
# {'_id': 1945, 'total_movies': 29}
# {'_id': 1946, 'total_movies': 34}
# {'_id': 1947, 'total_movies': 29}
# {'_id': 1948, 'total_movies': 56}
# {'_id': 1949, 'total_movies': 52}
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %%
#3. Write an aggregation pipeline to calculate the total number of movies released in each  year (Sort the results by the year)
movies_per_year = collection.aggregate([
    {"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
    {"$sort": {"_id": 1}}
])

for year in movies_per_year:
    pprint.pprint(year)
# Out:
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %% [markdown]
# Exercise 4: Updating and Deleting Documents

# %%
# 1. Write a query to update the IMDb rating of a movie with the title "The Godfather" to 9.5.
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.5}})

updated_godfather_movie = collection.find_one({"title": "The Godfather"})
pprint.pprint(updated_godfather_movie)
# Out:
# {'_id': ObjectId('573a1396f29313caabce4a9a'),
#  'awards': {'nominations': 19,
#             'text': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#             'wins': 33},
#  'cast': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'When the aging head of a famous crime family decides to transfer '
#              'his position to one of his subalterns, a series of unfortunate '
#              'events start happening to the family, and a war begins between '
#              'all the well-known families leading to insolence, deportation, '
#              'murder and revenge, and ends with the favorable successor being '
#              'finally chosen.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 68646, 'rating': 9.5, 'votes': 1038358},
#  'languages': ['English', 'Italian', 'Latin'],
#  'lastupdated': '2015-09-02 00:08:23.680000000',
#  'metacritic': 100,
#  'num_mflix_comments': 131,
#  'plot': 'The aging patriarch of an organized crime dynasty transfers control '
#          'of his clandestine empire to his reluctant son.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1972, 3, 24, 0, 0),
#  'runtime': 175,
#  'title': 'The Godfather',
#  'tomatoes': {'consensus': "One of Hollywood's greatest critical and "
#                            'commercial successes, The Godfather gets '
#                            'everything right; not only did the movie transcend '
#                            'expectations, it established new benchmarks for '
#                            'American cinema.',
#               'critic': {'meter': 99, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 10, 9, 0, 0),
#               'fresh': 83,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 13),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 98, 'numReviews': 725773, 'rating': 4.4},
#               'website': 'http://www.thegodfather.com'},
#  'type': 'movie',
#  'writers': ['Mario Puzo (screenplay)',
#              'Francis Ford Coppola (screenplay)',
#              'Mario Puzo (novel)'],
#  'year': 1972}

# %%
# 2. Write a query to update all movies where the genre is "Horror" and set their IMDb rating to 6.0 if it is currently null.
collection.update_many({"genres": "Horror", "imdb.rating": {"$exists": False}}, {"$set": {"imdb.rating": 6.0}})

updated_horror_movies = collection.find({"genres": "Horror"})
for movie in updated_horror_movies:
    pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 10, 9, 0, 0),
#  'runtime': 88,
#  'title': 'The Final Girls',
#  'tomatoes': {'critic': {'meter': 78, 'numReviews': 9, 'rating': 6.2},
#               'fresh': 7,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 18, 59, 30),
#               'production': 'Stage 6 Films',
#               'rotten': 2,
#               'viewer': {'numReviews': 570, 'rating': 4.1},
#               'website': 'http://https://www.facebook.com/TheFinalGirls'},
#  'type': 'movie',
#  'writers': ['M.A. Fortin (screenplay)', 'Joshua John Miller (screenplay)'],
#  'year': 2015}
# {'_id': ObjectId('573a13d7f29313caabda231d'),
#  'awards': {'nominations': 0, 'text': '4 wins.', 'wins': 4},
#  'cast': ['Erin McGrane', 'Meg Saricks', 'Emily Boresow', 'Sally Spurgeon'],
#  'countries': ['USA'],
#  'directors': ['Patrick Rea'],
#  'fullplot': 'This movie is about a mother (Alice Maguire) and her three '
#              'daughters who are trying to get to the airport to pick up Mr '
#              "Maguire, the daughter's father. But on the way there is a "
#              'tornado warning and the trip starts to get too dangerous so they '
#              'stop on the highway and run to a house to take shelter. Nobody '
#              'answers the door so they all get in to the cellar to wait out '
#              'the storm. But then they discover that there is somebody in the '
#              'house above them, and then they become trapped in the cellar. '
#              "But there's more to worry about than the impending storm, and "
#              "their lives become endangered, by something that's not normal.",
#  'genres': ['Horror'],
#  'imdb': {'id': 2122424, 'rating': 4.3, 'votes': 1628},
#  'languages': ['English'],
#  'lastupdated': '2015-09-02 00:07:57.977000000',
#  'num_mflix_comments': 1,
#  'plot': 'The Maguire family is forced to take sudden refuge in a seemingly '
#          'abandoned storm cellar from a deadly tornado.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgzNzY0ODk1MV5BMl5BanBnXkFtZTcwMDM0MzE2OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 5, 28, 0, 0),
#  'runtime': 82,
#  'title': 'Nailbiter',
#  'tomatoes': {'dvd': datetime.datetime(2013, 5, 27, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 23, 18, 25, 7),
#               'production': 'LionsGate Entertainment',
#               'viewer': {'meter': 21, 'numReviews': 182, 'rating': 2.2}},
#  'type': 'movie',
#  'writers': ['Patrick Rea', 'Kendal Sinn'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda1b36'),
#  'awards': {'nominations': 4, 'text': '1 win & 4 nominations.', 'wins': 1},
#  'cast': ['Silje Reinèmo',
#           'Erlend Nervold',
#           'Jon Sigve Skard',
#           'Morten Andresen'],
#  'countries': ['Norway'],
#  'directors': ['Aleksander Nordaas'],
#  'fullplot': 'Norwegian folklore turns out to be real when Leo and Elvis '
#              'encounter Thale in a basement. A regular cleaning job turns into '
#              "a struggle for survival, while they're trying to figure out what "
#              'or who Thale is.',
#  'genres': ['Fantasy', 'Horror', 'Mystery'],
#  'imdb': {'id': 2112287, 'rating': 5.6, 'votes': 4322},
#  'languages': ['Norwegian', 'Swedish'],
#  'lastupdated': '2015-08-19 00:03:15.233000000',
#  'num_mflix_comments': 0,
#  'plot': 'Norwegian folklore turns out to be real when Leo and Elvis encounter '
#          'Thale in a basement. A regular cleaning job turns into a struggle '
#          "for survival, while they're trying to figure out what ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQyMzE5NjE1MF5BMl5BanBnXkFtZTcwOTEyNzAxOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 2, 17, 0, 0),
#  'runtime': 76,
#  'title': 'Thale',
#  'tomatoes': {'critic': {'meter': 55, 'numReviews': 11, 'rating': 6.2},
#               'dvd': datetime.datetime(2013, 4, 23, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 54, 32),
#               'production': 'XLrator Films',
#               'rotten': 5,
#               'viewer': {'meter': 33, 'numReviews': 1389, 'rating': 2.8},
#               'website': 'http://www.facebook.com/thalemovie'},
#  'type': 'movie',
#  'writers': ['Aleksander Nordaas'],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda2738'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Ross Noble',
#           'Tommy Knight',
#           'Shane Murray-Corcoran',
#           'Gemma-Leah Devereux'],
#  'countries': ['Ireland'],
#  'directors': ['Conor McMahon'],
#  'fullplot': 'The clumsy and unfunny clown Richard "Stitches" Grindle goes to '
#              'the birthday party of little Tom and the boy and his friends '
#              'play a prank with Stitches, tying his shoelaces. Stitches slips, '
#              'falls and dies. Six years later, Tom gives a birthday party for '
#              'his friends at home and the clown revives to haunt the teenagers '
#              'and revenge his death.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 2126362, 'rating': 5.7, 'votes': 5728},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:01:20.553000000',
#  'num_mflix_comments': 1,
#  'plot': 'A clown comes back from the dead to haunt those who took his life '
#          'during a fatal party mishap.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTliYzkyZDktZjEwZS00OTEzLWFjNDAtZjA4NjQ0Y2ZkZGU2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 10, 26, 0, 0),
#  'runtime': 86,
#  'title': 'Stitches',
#  'tomatoes': {'critic': {'meter': 44, 'numReviews': 18, 'rating': 5.3},
#               'dvd': datetime.datetime(2013, 4, 2, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 4, 23),
#               'production': 'MPI Media Group/Dark Sky Films',
#               'rotten': 10,
#               'viewer': {'meter': 43, 'numReviews': 1202, 'rating': 3.0},
#               'website': 'http://www.stitchesmovie.com/index.html'},
#  'type': 'movie',
#  'writers': ['Conor McMahon', "David O'Brien"],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda3782'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Iain P.F. McDonald', 'Kate Henderson', 'Steve Lynch', 'Libby Ashby'],
#  'countries': ['Australia'],
#  'directors': ['Tanzeal Rahim'],
#  'fullplot': 'In 2007 author Phillip Muirhouse was left alone in a haunted '
#              "homestead called 'Monte Cristo'. He was there making a "
#              'documentary that was to accompany his latest book. He also broke '
#              'the rule of all ghost hunters.... Never Be Alone. The following '
#              'is video documentation leading to he is arrest.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 2146834, 'rating': 4.5, 'votes': 294},
#  'languages': ['English'],
#  'lastupdated': '2015-08-02 00:42:42.717000000',
#  'num_mflix_comments': 0,
#  'plot': 'In 2007 author Phillip Muirhouse was left alone in a haunted '
#          "homestead called 'Monte Cristo'. He was there making a documentary "
#          'that was to accompany his latest book. He also broke the rule...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE4MTM1MTIyMl5BMl5BanBnXkFtZTcwMjI3MTExOA@@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 75,
#  'title': 'Muirhouse',
#  'type': 'movie',
#  'writers': ['Tanzeal Rahim'],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda382c'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Kiko Mizuhara', 'Kaori Momoi', 'Erika Sawajiri', 'Anne Suzuki'],
#  'countries': ['Japan'],
#  'directors': ['Mika Ninagawa'],
#  'fullplot': 'Top star Ririko undergoes multiple cosmetic surgeries to her '
#              'entire body. As her surgeries show side effect, Ririko makes the '
#              'lives of those around her miserable as she tries to deal with '
#              'her career and her personal problems.',
#  'genres': ['Drama', 'Horror'],
#  'imdb': {'id': 2147319, 'rating': 6.3, 'votes': 845},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-14 00:28:43.943000000',
#  'num_mflix_comments': 2,
#  'plot': 'Top star Ririko undergoes multiple cosmetic surgeries to her entire '
#          'body. As her surgeries show side effect, Ririko makes the lives of '
#          'those around her miserable as she tries to deal with her career and '
#          'her personal problems.',
#  'released': datetime.datetime(2012, 7, 14, 0, 0),
#  'runtime': 127,
#  'title': 'Helter Skelter',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 3, 18, 28, 25),
#               'viewer': {'numReviews': 89, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Kyèko Okazaki (manga)', 'Arisa Kaneko (screenplay)'],
#  'year': 2012}
# {'_id': ObjectId('573a13d7f29313caabda31c8'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Dan Palmer', 'Antonia Bernath', 'Tamaryn Payne', 'Mark Holden'],
#  'countries': ['UK'],
#  'directors': ['Christian James'],
#  'fullplot': "A janitor gets trapped in a women's restroom and encounters an "
#              'all-out attack by a horde of zombies.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 2140429, 'rating': 4.7, 'votes': 1189},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:58:57.797000000',
#  'num_mflix_comments': 1,
#  'plot': "A janitor gets trapped in a women's restroom and encounters an "
#          'all-out attack by a horde of zombies.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM5MTQ4ODE2NV5BMl5BanBnXkFtZTgwNTgwNTQyMDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 3, 25, 0, 0),
#  'runtime': 84,
#  'title': 'Stalled',
#  'tomatoes': {'dvd': datetime.datetime(2014, 3, 3, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 27, 19, 15, 58),
#               'production': "Uncork'd Entertainment",
#               'viewer': {'meter': 29, 'numReviews': 101, 'rating': 2.6},
#               'website': 'http://www.phase4films.com/'},
#  'type': 'movie',
#  'writers': ['Dan Palmer (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda4a87'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Iain De Caestecker', 'Alice Englert', 'Allen Leech'],
#  'countries': ['UK'],
#  'directors': ['Jeremy Lovering'],
#  'fullplot': 'Tom and Lucy are both happy young adults eager to set out on '
#              'their first weekend getaway as a couple. They set off for a '
#              'planned stay at a remote hotel but quickly find themselves '
#              'getting lost in a maze of backwoods roads. However they soon '
#              'discover that they are at the mercies of an unknown tormentor '
#              'that is eager to take advantage of their vulnerability and '
#              'distance from civilization.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2165859, 'rating': 5.5, 'votes': 5355},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:29:04.970000000',
#  'metacritic': 66,
#  'num_mflix_comments': 1,
#  'plot': 'Driving to a music festival in Ireland, a new couple become lost and '
#          'are then set upon by a tormentor with an unknown motive.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc3MzQ5NTA3OV5BMl5BanBnXkFtZTgwNjI4MTYwMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 11, 15, 0, 0),
#  'runtime': 85,
#  'title': 'In Fear',
#  'tomatoes': {'consensus': 'Compact and effective, In Fear offers discerning '
#                            'horror fans a smart and disturbing plunge into the '
#                            'depths of cinematic anxiety.',
#               'critic': {'meter': 83, 'numReviews': 52, 'rating': 6.8},
#               'dvd': datetime.datetime(2014, 3, 11, 0, 0),
#               'fresh': 43,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 40, 16),
#               'production': 'Anchor Bay/Freestyle Releasing',
#               'rotten': 9,
#               'viewer': {'meter': 41, 'numReviews': 8368, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Jeremy Lovering'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda4a63'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Robert Englund',
#           'Fiona Dourif',
#           'Felisha Terrell',
#           'Cleopatra Coleman'],
#  'countries': ['USA'],
#  'directors': ['Robert Hall'],
#  'fullplot': 'A doctor works to cure patients suffering from crippling phobias '
#              'by placing them inside his invention which induces and controls '
#              'hallucinations.',
#  'genres': ['Horror'],
#  'imdb': {'id': 2165765, 'rating': 5.6, 'votes': 5946},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:05:08.780000000',
#  'num_mflix_comments': 0,
#  'plot': 'A doctor works to cure patients suffering from crippling phobias by '
#          'placing them inside his invention which induces and controls '
#          'hallucinations.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NjA5MTA3NF5BMl5BanBnXkFtZTgwNDk1MDExMzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 1, 30, 0, 0),
#  'runtime': 95,
#  'title': 'Fear Clinic',
#  'tomatoes': {'dvd': datetime.datetime(2015, 2, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 7, 36),
#               'production': 'Anchor Bay Entertainment',
#               'viewer': {'meter': 19, 'numReviews': 173, 'rating': 2.3},
#               'website': 'http://fearclinicmovie.com/'},
#  'type': 'movie',
#  'writers': ['Aaron Drane', 'Robert Hall'],
#  'year': 2014}
# {'_id': ObjectId('573a13d7f29313caabda5079'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Pernilla August', 'Aliette Opheim', 'Vera Vitali', 'Isaka Sawadogo'],
#  'countries': ['Sweden'],
#  'directors': ['Lisa Aschan'],
#  'fullplot': 'The plot is undisclosed.',
#  'genres': ['Horror'],
#  'imdb': {'id': 2172095, 'rating': '', 'votes': ''},
#  'languages': ['Swedish'],
#  'lastupdated': '2015-07-31 01:10:29.393000000',
#  'num_mflix_comments': 0,
#  'plot': 'The plot is undisclosed.',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'title': 'The Deposit',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 1, 4, 22, 39, 8),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Johannes Anyuru (play)',
#              'Lisa Aschan (screenplay)',
#              'Aleksander Motturi (play)'],
#  'year': 2015}
# {'_id': ObjectId('573a13d8f29313caabda5858'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Mittita Barber',
#           'Aslam Husain',
#           'Victor Zinck Jr.',
#           'Chelsey Reist'],
#  'countries': ['Canada'],
#  'directors': ['Brenton Spencer'],
#  'fullplot': "This is a 'found-footage' movie from Canada about five young "
#              'friends who go on a trip to a cabin back in 2011, but on the way '
#              '(while filming it) they head off the beaten track to a place '
#              'called Crowsnest where they have heard that you can buy beer for '
#              'half price! They get the beer but at the same time they receive '
#              'a warning to head back where they came from or they will die. '
#              "But they don't take the warning too seriously and keep driving "
#              'in to the forest. But they seem to be lost, then an RV hits one '
#              "of them and all hell breaks loose. There's something about the "
#              'people in the RV. Will the friends survive?',
#  'genres': ['Action', 'Horror', 'Mystery'],
#  'imdb': {'id': 2180333, 'rating': 3.8, 'votes': 1111},
#  'languages': ['English'],
#  'lastupdated': '2015-08-26 01:34:24.540000000',
#  'num_mflix_comments': 1,
#  'plot': 'In late summer of 2011, five young friends on a road trip went '
#          'missing after being attacked by nomadic cannibals in a huge RV. '
#          'Video was recorded by the victims & recovered by police as evidence '
#          'in their still-unsolved murders.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1ODU0NzkwNl5BMl5BanBnXkFtZTgwNTY1NjA2MDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 9, 7, 0, 0),
#  'runtime': 84,
#  'title': 'Crowsnest',
#  'tomatoes': {'dvd': datetime.datetime(2013, 1, 22, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 4, 48),
#               'production': 'IFC Films',
#               'viewer': {'meter': 16, 'numReviews': 127, 'rating': 2.2}},
#  'type': 'movie',
#  'writers': ['John Sheppard'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda571a'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Mischa Barton', 'Ryan Eggold', 'Leah Pipes', 'Frank Ashmore'],
#  'countries': ['USA'],
#  'directors': ['Mark Edwin Robinson'],
#  'fullplot': 'Story follows Sophia, who is severely depressed after the deaths '
#              'of both her parents within six months. Convinced that the '
#              'Afterlife is mere oblivion, and that this life is meaningless, '
#              'she retreats within herself, only to be drawn out of her '
#              'depressive funk by an unexpected romance with a man named Adam. '
#              'After Adam disappears mysteriously into the depths of a haunted '
#              'apartment building, Sophia vows to pursue him, even if it means '
#              'walking over the threshold into the realm of death.',
#  'genres': ['Drama', 'Horror', 'Romance'],
#  'imdb': {'id': 2179087, 'rating': 4.5, 'votes': 898},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:18:02.627000000',
#  'metacritic': 12,
#  'num_mflix_comments': 1,
#  'plot': 'A woman reeling from the death of her parents becomes attached to an '
#          'alluring man whose sudden disappearance sends her and her friends '
#          'into a haunted high-rise to find him',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNzY1MzU5MV5BMl5BanBnXkFtZTgwODQ5MTIzMDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 11, 0, 0),
#  'runtime': 112,
#  'title': 'I Will Follow You Into the Dark',
#  'tomatoes': {'critic': {'meter': 11, 'numReviews': 9, 'rating': 2.6},
#               'dvd': datetime.datetime(2014, 1, 27, 0, 0),
#               'fresh': 1,
#               'lastUpdated': datetime.datetime(2015, 8, 17, 19, 28, 26),
#               'production': 'Epic Pictures Releasing',
#               'rotten': 8,
#               'viewer': {'meter': 24, 'numReviews': 167, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Mark Edwin Robinson'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda56fb'),
#  'awards': {'nominations': 0, 'text': '4 wins.', 'wins': 4},
#  'cast': ['Sam Scarber', 'Dahlia Salem', 'David Banks', 'David Rountree'],
#  'countries': ['USA'],
#  'directors': ['David Rountree'],
#  'fullplot': 'Nothing is as it seems as an ex-con and aspirant filmmaker set '
#              'out to manufacture a horror film by scaring real people; '
#              'however, when it goes too far and someone actually dies, the '
#              'pair decide that killing for real on film is the way to make a '
#              'truly terrifying movie.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2179007, 'rating': 6.4, 'votes': 1132},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 01:02:17.080000000',
#  'num_mflix_comments': 1,
#  'plot': 'Nothing is as it seems as an ex-con and aspirant filmmaker set out '
#          'to manufacture a horror film by scaring real people; however, when '
#          'it goes too far and someone actually dies, the pair ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM3MjI1NTE1Nl5BMl5BanBnXkFtZTcwOTIyMjIzOA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 2, 1, 0, 0),
#  'runtime': 101,
#  'title': 'Cut!',
#  'tomatoes': {'dvd': datetime.datetime(2015, 2, 24, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 7, 20, 9, 22),
#               'production': 'Psycho Rock Productions',
#               'viewer': {'meter': 67, 'numReviews': 78, 'rating': 3.9},
#               'website': 'http://www.thecutmovie.com/'},
#  'type': 'movie',
#  'writers': ['David Banks', 'David Rountree'],
#  'year': 2014}
# {'_id': ObjectId('573a13d8f29313caabda59dd'),
#  'awards': {'nominations': 4, 'text': '4 nominations.', 'wins': 0},
#  'cast': ['Helgi Bjèrnsson',
#           'Einar Dagbjartsson',
#           'Valur Freyr Einarsson',
#           'Elma Lèsa Gunnarsdèttir'],
#  'countries': ['Iceland', 'Finland'],
#  'directors': ['Reynir Lyngdal'],
#  'fullplot': 'A young couple, physiologist Agla and filmmaker Gunnar wake up '
#              'at a glacier camp to find the camp mysteriously abandoned and '
#              'their co-workers gone. When searching for the lost team they '
#              "realize they're up against an unknown deadly force.",
#  'genres': ['Horror', 'Sci-Fi', 'Thriller'],
#  'imdb': {'id': 2181953, 'rating': 3.7, 'votes': 317},
#  'languages': ['Icelandic'],
#  'lastupdated': '2015-07-31 00:41:33.707000000',
#  'num_mflix_comments': 0,
#  'plot': 'A young couple, physiologist Agla and filmmaker Gunnar wake up at a '
#          'glacier camp to find the camp mysteriously abandoned and their '
#          'co-workers gone. When searching for the lost team they realize '
#          "they're up against an unknown deadly force.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxMjg0MzI3NF5BMl5BanBnXkFtZTcwOTUzMzUyOA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 10, 0, 0),
#  'runtime': 79,
#  'title': 'Frost',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 12, 18, 6, 34),
#               'production': 'Kisi',
#               'viewer': {'numReviews': 5, 'rating': 1.0}},
#  'type': 'movie',
#  'writers': ['Jèn Atli Jènasson'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda612d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Christopher Boeres Hipp',
#           'Michael Brown',
#           'Charles Cantrell',
#           'Patrick Sean Clark'],
#  'countries': ['USA'],
#  'directors': ['David Schmoeller'],
#  'fullplot': 'James and Carl were only 10 years old when they kidnapped and '
#              'murdered 3 year old David McClendon. They were caught, tried, '
#              'convicted and placed in separate juvenile facilities. At '
#              '18-years old, both are given new names and released back into '
#              'society - much to the horror of the nation. They can have no '
#              'contact with each other or with their past friends or relatives. '
#              'The story follows the lives of these two boys as they try to '
#              'start over, escape the past and survive the growing outcry '
#              'following their release.',
#  'genres': ['Crime', 'Drama', 'Horror'],
#  'imdb': {'id': 2189714, 'rating': 4.7, 'votes': 120},
#  'languages': ['English'],
#  'lastupdated': '2015-05-07 01:24:18.800000000',
#  'num_mflix_comments': 0,
#  'plot': 'James and Carl were only 10 years old when they kidnapped and '
#          'murdered 3 year old David McClendon. They were caught, tried, '
#          'convicted and placed in separate juvenile facilities. At 18-years...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjcyODg4ODI1Ml5BMl5BanBnXkFtZTcwNDAzMzM5Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 5, 1, 0, 0),
#  'runtime': 107,
#  'title': 'Little Monsters',
#  'tomatoes': {'dvd': datetime.datetime(2014, 4, 1, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 6, 8, 18, 35, 5),
#               'production': 'VCI Entertainment',
#               'viewer': {'meter': 75, 'numReviews': 9, 'rating': 3.8},
#               'website': 'http://www.vcientertainment.com/Film-Categories/2-Little-Monsters'},
#  'type': 'movie',
#  'writers': ['David Schmoeller'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda5c08'),
#  'awards': {'nominations': 6, 'text': '1 win & 6 nominations.', 'wins': 1},
#  'cast': ['Ethan Hawke', 'Lena Headey', 'Max Burkholder', 'Adelaide Kane'],
#  'countries': ['USA', 'France'],
#  'directors': ['James DeMonaco'],
#  'fullplot': 'In an America wracked by crime and overcrowded prisons, the '
#              'government has sanctioned an annual 12-hour period in which any '
#              'and all criminal activity-including murder-becomes legal. The '
#              "police can't be called. Hospitals suspend help. It's one night "
#              'when the citizenry regulates itself without thought of '
#              'punishment. On this night plagued by violence and an epidemic of '
#              'crime, one family wrestles with the decision of who they will '
#              'become when a stranger comes knocking. When an intruder breaks '
#              "into James Sandin's (Ethan Hawke) gated community during the "
#              'yearly lockdown, he begins a sequence of events that threatens '
#              'to tear a family apart. Now, it is up to James, his wife, Mary '
#              '(Lena Headey), and their kids to make it through the night '
#              'without turning into the monsters from whom they hide.',
#  'genres': ['Horror', 'Sci-Fi', 'Thriller'],
#  'imdb': {'id': 2184339, 'rating': 5.6, 'votes': 118028},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:20:47.107000000',
#  'metacritic': 41,
#  'num_mflix_comments': 0,
#  'plot': 'In the future, a wealthy family is held hostage for harboring the '
#          'target of a murderous syndicate during the Purge, a 12-hour period '
#          'in which any and all crime is legalized.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNTcwODEyM15BMl5BanBnXkFtZTcwMjM1MDI0OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 6, 7, 0, 0),
#  'runtime': 85,
#  'title': 'The Purge',
#  'tomatoes': {'boxOffice': '$64.4M',
#               'consensus': 'Half social allegory, half home-invasion thriller, '
#                            'The Purge attempts to make an intelligent point, '
#                            'but ultimately devolves into numbing violence and '
#                            'tired clichès.',
#               'critic': {'meter': 38, 'numReviews': 137, 'rating': 5.1},
#               'dvd': datetime.datetime(2013, 10, 8, 0, 0),
#               'fresh': 52,
#               'lastUpdated': datetime.datetime(2015, 8, 25, 18, 1, 26),
#               'production': 'Universal Pictures',
#               'rotten': 85,
#               'viewer': {'meter': 36, 'numReviews': 94008, 'rating': 2.9},
#               'website': 'http://www.facebook.com/thepurgemovie'},
#  'type': 'movie',
#  'writers': ['James DeMonaco'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda5f31'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Ciara Hanna',
#           "Emily O'Brien",
#           'Jackie Moore',
#           'Russell Geoffrey Banks'],
#  'countries': ['USA', 'Thailand'],
#  'directors': ['James Cullen Bressack'],
#  'fullplot': 'Three young, beautiful girls arrive in Thailand to teach English '
#              'for the summer, some with noble intentions and some just wanting '
#              'an adventure, but none were prepared for the massacre that '
#              'awaited them. The nightmare begins when their new friends go '
#              'missing, vivid bloody dreams haunt their sleep and a stolen '
#              'statue leads them down a dark path into Thai folklore and magic '
#              'that has been long forgotten. Their situation continues to '
#              "become worse once they realize it's not WHAT that is haunting "
#              'them but WHO: an eight-year girl, brutally murdered and '
#              'sacrificed by her family decades ago who wants nothing more than '
#              'to watch them bleed. This is not a story about redemption. This '
#              'is not a story about good versus evil. This is not a story about '
#              'the will to survive. This is a story about Vanida - a child '
#              'viciously tortured by her own family, who will stop at nothing '
#              'for revenge - one appendage at a time.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2187444, 'rating': 5.8, 'votes': 1630},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:12:33.883000000',
#  'num_mflix_comments': 1,
#  'plot': 'It was supposed to be an adventure of a lifetime as three young '
#          'girls spend the summer in Thailand. But their adventure quickly '
#          'becomes a nightmare when the trio unleashes the spirit of a murdered '
#          'child with only one thing on her mind - revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTFhZWM2MzYtZGQyZi00MGQ3LTllZjctNTk4YzU2YTM3ZjAxXkEyXkFqcGdeQXVyMjUxOTAxNzI@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 20, 0, 0),
#  'runtime': 90,
#  'title': 'Pernicious',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 12, 19, 32, 38),
#               'production': 'Benetone Films',
#               'viewer': {'meter': 92, 'numReviews': 292, 'rating': 4.8},
#               'website': 'http://www.perniciousmovie.com/'},
#  'type': 'movie',
#  'writers': ['James Cullen Bressack (story)',
#              'James Cullen Bressack',
#              'Taryn Hillin'],
#  'year': 2014}
# {'_id': ObjectId('573a13d8f29313caabda628a'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Minnie Driver', 'Meat Loaf', 'Allie MacDonald', 'Douglas Smith'],
#  'countries': ['Canada'],
#  'directors': ['Jerome Sable'],
#  'fullplot': 'A snobby musical theater camp is terrorized by a blood-thirsty '
#              'killer who hates musical theater.',
#  'genres': ['Horror', 'Musical'],
#  'imdb': {'id': 2190838, 'rating': 5.2, 'votes': 2902},
#  'languages': ['English'],
#  'lastupdated': '2015-08-19 00:21:56.017000000',
#  'metacritic': 39,
#  'num_mflix_comments': 0,
#  'plot': 'A snobby musical theater camp is terrorized by a blood-thirsty '
#          'killer who hates musical theater.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU0ODEwNjQ4Ml5BMl5BanBnXkFtZTgwMDQ4OTMzMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2014, 4, 3, 0, 0),
#  'runtime': 89,
#  'title': 'Stage Fright',
#  'tomatoes': {'boxOffice': '$7.1k',
#               'consensus': 'There might be a good movie to be made from '
#                            'mashing up the slasher and musical genres; '
#                            "unfortunately, Stage Fright isn't quite it.",
#               'critic': {'meter': 34, 'numReviews': 47, 'rating': 4.9},
#               'dvd': datetime.datetime(2014, 7, 8, 0, 0),
#               'fresh': 16,
#               'lastUpdated': datetime.datetime(2015, 8, 30, 20, 11, 30),
#               'production': 'Entertainment One',
#               'rotten': 31,
#               'viewer': {'meter': 27, 'numReviews': 775, 'rating': 2.7},
#               'website': 'http://magnetreleasing.com/stagefright/'},
#  'type': 'movie',
#  'writers': ['Jerome Sable (screenplay)',
#              'Jerome Sable (music and lyrics)',
#              'Eli Batalion (music and lyrics)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d8f29313caabda6f65'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Sean Patrick Flanery',
#           'Briana Evigan',
#           'Jessica Lowndes',
#           'Terrance Zdunich'],
#  'countries': ['USA'],
#  'directors': ['Darren Lynn Bousman'],
#  'fullplot': 'Three individuals have, somehow, found their way to a carnival, '
#              'set in hell, and run by the devil. The trio is made up of a '
#              'kleptomaniac, an obsessed father, and a gullible teenager, all '
#              'of whom are doomed to repeat the very sins that delivered them '
#              "to the carnival's doorsteps.",
#  'genres': ['Horror', 'Musical'],
#  'imdb': {'id': 2204379, 'rating': 6.5, 'votes': 3024},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 01:18:42.093000000',
#  'num_mflix_comments': 0,
#  'plot': "Lost souls enter The Devil's Carnival where they are each faced with "
#          'the sins they committed in life.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc0Nzg1MTg2N15BMl5BanBnXkFtZTcwNTk2OTk2Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 3, 30, 0, 0),
#  'runtime': 56,
#  'title': "The Devil's Carnival",
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 7, 20, 1, 1),
#               'production': 'House of International Media',
#               'viewer': {'meter': 67, 'numReviews': 36, 'rating': 4.3},
#               'website': 'http://www.thetimeisnowmovie.com/'},
#  'type': 'movie',
#  'writers': ['Terrance Zdunich'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda778d'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Billi Baker', 'Michael Thomson', 'Allira Jaques', 'Holly Phillips'],
#  'countries': ['Australia'],
#  'directors': ['Chris Sun'],
#  'fullplot': 'In a time when stranger danger is ever present, a single father '
#              "learns that it's the ones you trust most who have to be watched "
#              'the closest.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2214941, 'rating': 5.7, 'votes': 794},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:34:52.160000000',
#  'num_mflix_comments': 0,
#  'plot': 'In a time when stranger danger is ever present, a single father '
#          "learns that it's the ones you trust most who have to be watched the "
#          'closest.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI4NjkzNjI2NF5BMl5BanBnXkFtZTgwMzI0MDkzMTE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 107,
#  'title': "Daddy's Little Girl",
#  'tomatoes': {'dvd': datetime.datetime(2014, 5, 12, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 44, 5),
#               'viewer': {'meter': 54, 'numReviews': 50, 'rating': 3.1},
#               'website': 'http://www.daddyslittlegirl.com.au/'},
#  'type': 'movie',
#  'writers': ['Chris Sun'],
#  'year': 2012}
# {'_id': ObjectId('573a13d8f29313caabda820a'),
#  'awards': {'nominations': 13, 'text': '2 wins & 13 nominations.', 'wins': 2},
#  'cast': ['Patrick Wilson', 'Rose Byrne', 'Ty Simpkins', 'Lin Shaye'],
#  'countries': ['USA', 'Canada'],
#  'directors': ['James Wan'],
#  'fullplot': 'Renai is interrogated by a police detective about the '
#              'supernatural events in the house. While the police investigate '
#              'the house, the Lambert family temporarily moves to the old house '
#              'of Lorraine Lambert. Renai is haunted by a woman in white and '
#              'Josh has a strange behavior at home. Meanwhile Lorraine seeks '
#              "out Elise's partners Specs and Tucker expecting to find answers.",
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 2226417, 'rating': 6.6, 'votes': 91135},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:34:24.923000000',
#  'metacritic': 40,
#  'num_mflix_comments': 0,
#  'plot': 'The haunted Lambert family seeks to uncover the mysterious childhood '
#          'secret that has left them dangerously connected to the spirit world.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0OTA5ODIxNF5BMl5BanBnXkFtZTcwNTUzNDg4OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 9, 13, 0, 0),
#  'runtime': 106,
#  'title': 'Insidious: Chapter 2',
#  'tomatoes': {'boxOffice': '$83.6M',
#               'consensus': 'Insidious: Chapter 2 is decidedly short on the '
#                            'tension and surprises that made its predecessor so '
#                            'chilling.',
#               'critic': {'meter': 38, 'numReviews': 108, 'rating': 4.7},
#               'dvd': datetime.datetime(2013, 12, 24, 0, 0),
#               'fresh': 41,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 18, 13),
#               'production': 'FilmDistrict',
#               'rotten': 67,
#               'viewer': {'meter': 57, 'numReviews': 90063, 'rating': 3.5},
#               'website': 'http://www.facebook.com/InsidiousMovie'},
#  'type': 'movie',
#  'writers': ['Leigh Whannell (based on characters created by)',
#              'James Wan (story)',
#              'Leigh Whannell (story)',
#              'Leigh Whannell (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda854c'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Chantal Quesnelle',
#           'Fiona Dourif',
#           'Jordan Gavaris',
#           'Danielle Bisutti'],
#  'countries': ['USA'],
#  'directors': ['Don Mancini'],
#  'fullplot': 'After the events of Seed of Chucky, Nica, a young woman forced '
#              'to a wheelchair since birth, has to regroup her sister, Barb and '
#              'her brother-in-law, Ian for a funeral after the death of her '
#              'mother. While dealing with Barb, Ian, along with their '
#              '5-year-old daughter, Alice; Nica receives an odd package - a '
#              'creepy doll. After people start showing up dead, the fearless '
#              'Nica soon suspects that the creepy doll is much more than just a '
#              'doll.',
#  'genres': ['Crime', 'Horror'],
#  'imdb': {'id': 2230358, 'rating': 5.6, 'votes': 20229},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:14:29.433000000',
#  'num_mflix_comments': 0,
#  'plot': "After her mother's mysterious death, Nica begins to suspect that the "
#          'talking, red-haired doll her visiting niece has been playing with '
#          'may be the key to recent bloodshed and chaos.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOGY1NTMxNzAtMTM4NS00NDMxLWEzZWUtOWVmYWY2MzQyZDQwXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 9, 24, 0, 0),
#  'runtime': 97,
#  'title': 'Curse of Chucky',
#  'tomatoes': {'critic': {'numReviews': 4},
#               'dvd': datetime.datetime(2013, 10, 8, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2013, 9, 5, 0, 0),
#               'production': 'Universal Studios Home Entertainment',
#               'rotten': 0,
#               'viewer': {'meter': 96, 'numReviews': 492}},
#  'type': 'movie',
#  'writers': ['Don Mancini (characters)', 'Don Mancini'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda84a9'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['A.J. Cook', 'Sebastian Rochè', 'Vik Sahay', 'Stephanie Lemelin'],
#  'countries': ['USA'],
#  'directors': ['William Brent Bell'],
#  'fullplot': 'In France, the Porter family is slaughtered while camping in the '
#              'woods and only Claire Porter survives seriously wounded. She '
#              'reports that her husband Henry and her son Peter have been eaten '
#              'alive by a strong man. The eremite Talan Gwynek that lives in '
#              'the woods with his mother is arrested by the police accused of '
#              'being the killer. The defense attorney Kate Moore is assigned to '
#              'defend Talan and she comes to the police station with her '
#              'investigator Eric Sarin and the animal expert Gavin Flemyng to '
#              'interview Talan. The unwilling police inspector Klaus Pistor is '
#              'sure that Talan is the murderer but has to let Kate and her team '
#              'work. There is turmoil in the precinct and Gavin is scratched by '
#              "Talan. Then they visit Talan's mother Mrs. Gwynek and they learn "
#              'that Talan has a rare disease. Further, the government wants her '
#              'lands to dispose nuclear waste and her husband has recently died '
#              'in car accident. Soon Eric discloses that the death of Mr. '
#              'Gwynek was suspicious and Pistor was in charge of the '
#              'investigation. When Kate succeeds in sending Talan to a hospital '
#              "for examination, she discovers the effects of Talan's disease "
#              'and is the responsible for the next events.',
#  'genres': ['Action', 'Horror', 'Mystery'],
#  'imdb': {'id': 2229511, 'rating': 5.9, 'votes': 4762},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-21 00:40:55.437000000',
#  'num_mflix_comments': 1,
#  'plot': 'A defense attorney begins to suspect that there might be more to her '
#          'client, who is charged with the murders of a vacationing family, '
#          'than meets the eye.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDM2MDYxODE2Ml5BMl5BanBnXkFtZTgwMjcxMjc3MTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2014, 8, 19, 0, 0),
#  'runtime': 89,
#  'title': 'Wer',
#  'tomatoes': {'dvd': datetime.datetime(2014, 9, 23, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 19, 27, 54),
#               'production': 'Universal Pictures',
#               'viewer': {'meter': 39, 'numReviews': 362, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['William Brent Bell (screenplay)',
#              'Matthew Peterman (screenplay)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d9f29313caabda8be3'),
#  'awards': {'nominations': 5, 'text': '1 win & 5 nominations.', 'wins': 1},
#  'cast': ['Jared Harris', 'Sam Claflin', 'Erin Richards', 'Rory Fleck-Byrne'],
#  'countries': ['USA', 'UK'],
#  'directors': ['John Pogue'],
#  'fullplot': 'In 1974, in Oxford, Professor Joseph Coupland invites his '
#              'introspective student Brian McNeil to film his research about '
#              'the supernatural with his two assistants, Krissi Dalton and '
#              'Harry Abrams, and the subject Jane Harper. Jane is a young woman '
#              'with no memory from the past that has been abandoned that '
#              'believes she is possessed by a doll named Evey that gives '
#              'telekinetic power to her. She is kept awake in an isolated house '
#              'with a doll, where Prof. Coupland intends that she puts her evil '
#              'energy in and then destroy the doll to healing Jane. Strange '
#              'things happen in the house and Brian feels sorry for Jane and he '
#              'researches her tattoo, learning an evil secret about the past of '
#              'Jane.',
#  'genres': ['Horror'],
#  'imdb': {'id': 2235779, 'rating': 5.1, 'votes': 13318},
#  'languages': ['English'],
#  'lastupdated': '2015-08-17 00:10:16.703000000',
#  'metacritic': 41,
#  'num_mflix_comments': 0,
#  'plot': 'A university professor and a team of students conduct an experiment '
#          'on a young woman, uncovering terrifyingly dark, unexpected forces in '
#          'the process.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzM5OTQxNTQwNV5BMl5BanBnXkFtZTgwNjE4NzMxMTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 4, 25, 0, 0),
#  'runtime': 98,
#  'title': 'The Quiet Ones',
#  'tomatoes': {'boxOffice': '$8.5M',
#               'consensus': 'While it definitely sports a few palpable scares, '
#                            'The Quiet Ones finds Hammer Films trading too '
#                            'heavily on past glories.',
#               'critic': {'meter': 36, 'numReviews': 70, 'rating': 4.8},
#               'dvd': datetime.datetime(2014, 8, 19, 0, 0),
#               'fresh': 25,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 20, 39),
#               'production': 'Lionsgate/Summit',
#               'rotten': 45,
#               'viewer': {'meter': 25, 'numReviews': 13070, 'rating': 2.6},
#               'website': 'http://www.thequietonesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Craig Rosenberg (screenplay)',
#              'Oren Moverman (screenplay)',
#              'John Pogue (screenplay)',
#              'Tom de Ville (based on the screenplay by)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d9f29313caabda8725'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Anta Aizupe', 'Maxim Lazarev', 'Aris Rozentals'],
#  'countries': ['Latvia', 'Estonia'],
#  'directors': ['Aik Karapetian'],
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 2231646, 'rating': 5.5, 'votes': 167},
#  'languages': ['Latvian'],
#  'lastupdated': '2015-08-08 00:22:42.570000000',
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU3OTc3NjMzN15BMl5BanBnXkFtZTgwNzI4OTY2MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 27, 0, 0),
#  'runtime': 71,
#  'title': 'The Man in the Orange Jacket',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 4, 19, 18, 34),
#               'viewer': {'numReviews': 3, 'rating': 5.0}},
#  'type': 'movie',
#  'writers': ['Aik Karapetian'],
#  'year': 2014}
# {'_id': ObjectId('573a13d9f29313caabda9432'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Ingrid Bolsè Berdal',
#           'Dimitri Diatchenko',
#           'Olivia Taylor Dudley',
#           'Devin Kelley'],
#  'countries': ['USA'],
#  'directors': ['Bradley Parker'],
#  'fullplot': 'Americans Chris, his girlfriend Natalie and their friend Amanda '
#              "travel to Europe on vacation. They meet up with Chris' brother "
#              'Paul living in Kiev, Ukraine. Chris wants to travel to Moscow to '
#              'propose to Natalie, but Paul convinces the group to first visit '
#              'Chernobyl with an extreme tourism guide. They meet the guide Uri '
#              'and another couple who are also going on the tour. Uri explains '
#              'that because of the radiation levels he can only take them to '
#              'Pripyat, a deserted city very near Chernobyl. They travel by '
#              'van, but are stopped by a military checkpoint that makes them '
#              'turn back. Not giving up, Uri finds an alternative route to the '
#              'town. The group spends the day taking photographs and exploring '
#              "abandoned buildings. Uri becomes nervous and decides it's time "
#              "to head home. However, the van won't start and they discover the "
#              'engine was sabotaged. Soon they discover that they are stranded, '
#              'no one knows they are there and that they are definitely not '
#              'alone.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 1991245, 'rating': 5.0, 'votes': 49647},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 12:30:49.527000000',
#  'num_mflix_comments': 1,
#  'plot': 'Six tourists hire an extreme tour guide who takes them to the '
#          'abandoned city Pripyat, the former home to the workers of the '
#          'Chernobyl nuclear reactor. During their exploration, they soon '
#          'discover they are not alone.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzkwNDkyNTUxNV5BMl5BanBnXkFtZTcwODY1NTE3Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 5, 25, 0, 0),
#  'runtime': 86,
#  'title': 'Chernobyl Diaries',
#  'type': 'movie',
#  'writers': ['Oren Peli (screenplay)',
#              'Carey Van Dyke (screenplay)',
#              'Shane Van Dyke (screenplay)',
#              'Oren Peli (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13d9f29313caabda92c0'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Marlon Wayans', 'Marlene Forte', 'Essence Atkins', 'David Koechner'],
#  'countries': ['USA'],
#  'directors': ['Michael Tiddes'],
#  'fullplot': 'In October 2012 a video footage is found at the home of Malcolm '
#              'Johnson and the recordings are still unexplained. Past this '
#              'prologue a story in flashback form unfolds. During the summer of '
#              '2012, Malcolm and Kisha move in together and start a happy life. '
#              'One night Kisha notices a few unexplained phenomena that '
#              'convince her their house is haunted by ghosts. To allay her '
#              'fears Malcom hires a camera crew to film inside the house day '
#              'and night. A few nights later Malcom and Keisha have sex on '
#              "camera, despite Keisha's protests at being filmed. Upon "
#              'reviewing the sex tape the next day, Malcom and Keisha notice a '
#              'few paranormal phenomena caught on tape. Malcom wants to sell '
#              'the house but the housing market is slow. Therefore, Malcom '
#              'decides to hire a psychic to come to the house and investigate. '
#              'After Kisha confesses to making a deal with the devil for a pair '
#              "of shoes things start to make sense but it doesn't solve the "
# ...
#  'released': datetime.datetime(2015, 8, 28, 0, 0),
#  'runtime': 90,
#  'title': 'Deathgasm',
#  'type': 'movie',
#  'writers': ['Jason Lei Howden'],
#  'year': 2015}
# {'_id': ObjectId('573a13f0f29313caabdd9e82'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Salil Acharya', 'Kavin Dave', 'Anindita Nayar', 'Rannvijay Singh'],
#  'countries': ['India'],
#  'directors': ['Vishal Mahadkar'],
#  'fullplot': 'The story of the movie revolves around three friends who are '
#              'going to make a reality show on the existence of ghosts in the '
#              'world.',
#  'genres': ['Horror', 'Romance'],
#  'imdb': {'id': 3720634, 'rating': 4.2, 'votes': 130},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-31 00:44:47.763000000',
#  'num_mflix_comments': 1,
#  'plot': 'The story of the movie revolves around three friends who are going '
#          'to make a reality show on the existence of ghosts in the world.',
#  'released': datetime.datetime(2014, 9, 26, 0, 0),
#  'title': '3 AM: A Paranormal Experience',
#  'type': 'movie',
#  'writers': ['Vishal Mahadkar (story)',
#              'Vishal Mahadkar',
#              'Sanjay Masoom (dialogue)'],
#  'year': 2014}
# {'_id': ObjectId('573a13f0f29313caabdd9a72'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Heather Sossaman',
#           'Matthew Bohrer',
#           'Courtney Halverson',
#           'Shelley Hennig'],
#  'countries': ['USA'],
#  'directors': ['Levan Gabriadze'],
#  'fullplot': 'While video chatting one night, six high school friends receive '
#              'a Skype message from a classmate who killed herself exactly one '
#              "year ago. At first they think it's a prank, but when the girl "
#              "starts revealing the friends' darkest secrets, they realize they "
#              'are dealing with something out of this world, something that '
#              'wants them dead.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 3713166, 'rating': 5.8, 'votes': 25815},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 08:37:23.933000000',
#  'metacritic': 59,
#  'num_mflix_comments': 0,
#  'plot': 'A group of online chat room friends find themselves haunted by a '
#          'mysterious, supernatural force using the account of their dead '
#          'friend.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzdlNWI2MjYtMWY3ZC00N2EzLWIzNTgtZDY2NGI4OTY3Yzc5XkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 4, 17, 0, 0),
#  'runtime': 83,
#  'title': 'Unfriended',
#  'type': 'movie',
#  'writers': ['Nelson Greaves'],
#  'year': 2014}
# {'_id': ObjectId('573a13f1f29313caabddbdbe'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Chutavuth Pattarakampol',
#           'Supassra Thanachat',
#           'Thanapob Leeratanakajorn',
#           'Violette Wautier'],
#  'countries': ['Thailand'],
#  'directors': ['Sophon Sakdaphisit'],
#  'fullplot': "After falling pregnant to Perth, her boyfriend's best friend, "
#              'Ice commits suicide. She returns to haunt Perth while Tan seeks '
#              'out the person who made her kill herself for his own revenge.',
#  'genres': ['Drama', 'Horror'],
#  'imdb': {'id': 3788392, 'rating': 6.0, 'votes': 237},
#  'languages': ['Thai'],
#  'lastupdated': '2015-08-02 00:34:26.467000000',
#  'num_mflix_comments': 0,
#  'plot': "After falling pregnant to Perth, her boyfriend's best friend, Ice "
#          'commits suicide. She returns to haunt Perth while Tan seeks out the '
#          'person who made her kill herself for his own revenge.',
#  'released': datetime.datetime(2014, 8, 7, 0, 0),
#  'title': 'The Swimmers',
#  'type': 'movie',
#  'year': 2014}
# {'_id': ObjectId('573a13f3f29313caabdde5a7'),
#  'awards': {'nominations': 2, 'text': '2 wins & 2 nominations.', 'wins': 2},
#  'cast': ['Hye-Lin Han', 'Haneul Kang', 'So-eun Kim', 'Doo-Sik Park'],
#  'countries': ['South Korea'],
#  'directors': ['In-chun Oh'],
#  'fullplot': 'In-Su, a high school student, can see ghosts. After being '
#              'plagued by them everywhere he goes and harassed by his '
#              'classmates because of it, he returns to his hometown to live '
#              'with his uncle and to finally put to rest the past. No sooner '
#              'had he arrived when he sees his first ghost there, a pretty '
#              "girl. But just like before, it's not just the ghosts that affect "
#              'his life - the school bullies in the high school in his hometown '
#              'are still a problem. Then one day, the bullies start being '
#              'attacked by a vengeful ghost wearing a bloody mask. And In-Su '
#              'starts to think that his new friend, the pretty ghost, may have '
#              'something to do with it.',
#  'genres': ['Comedy', 'Horror', 'Romance'],
#  'imdb': {'id': 3892620, 'rating': 6.1, 'votes': 311},
#  'languages': ['Korean'],
#  'lastupdated': '2015-09-14 17:29:04.413000000',
#  'num_mflix_comments': 1,
#  'plot': 'A teenager, with the ability to see ghosts, returns to his hometown '
#          'to face his demons.',
#  'released': datetime.datetime(2014, 7, 2, 0, 0),
#  'runtime': 90,
#  'title': 'Sonyeogoedam',
#  'type': 'movie',
#  'writers': ['Jong-ho Lee'],
#  'year': 2014}
# {'_id': ObjectId('573a13f3f29313caabddf5a5'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Francisco Barreiro',
#           'Daniela Soto Vell',
#           'Jorge Molina',
#           'Milena Pezzi'],
#  'countries': ['Mexico', 'USA'],
#  'directors': ['Adrièn Garcèa Bogliano'],
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 3951730, 'rating': 6.2, 'votes': 41},
#  'languages': ['Spanish'],
#  'lastupdated': '2015-08-14 00:13:02.740000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(2015, 4, 17, 0, 0),
#  'runtime': 91,
#  'title': 'Scherzo Diabolico',
#  'type': 'movie',
#  'writers': ['Adrièn Garcèa Bogliano'],
#  'year': 2015}
# {'_id': ObjectId('573a13f3f29313caabde067d'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Polina Davydova', 'Lyubov Ignatushko', 'Evgeniy Gagarin'],
#  'countries': ['Germany', 'Russia'],
#  'directors': ['Pavel Khvaleev'],
#  'fullplot': 'A small European town, where sisters Ayia and Mirra live, gets '
#              'struck down by an unknown disease which takes many lives. '
#              "Following their mother's death, the younger sister falls ill. "
#              'Having realized that conventional medicine is useless in the '
#              "face of the sister's disease, Ayia seeks help from Father "
#              'Herman, a parish priest and a close family friend. In his house '
#              'she finds books that are very far from the conventional '
#              "religion. She gets to know that only penetration into Mirra's "
#              'sick subconscious mind and discovery of the true cause of her '
#              'disease will give her a chance to save her sister. Ayia is ready '
#              'to go through this terrifying ritual, dive into the depths of '
#              'the subconscious mind, and face the demons residing there.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 3993732, 'rating': 6.7, 'votes': 249},
#  'languages': ['Russian'],
#  'lastupdated': '2015-08-20 00:58:42.127000000',
#  'num_mflix_comments': 0,
#  'plot': 'A small European town, where sisters Ayia and Mirra live, gets '
#          'struck down by an unknown disease which takes many lives. Following '
#          "their mother's death, the younger sister falls ill. Having...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjM4NzE0MDAzN15BMl5BanBnXkFtZTgwMjk0MzYwNzE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 80,
#  'title': 'III',
#  'type': 'movie',
#  'writers': ['Aleksandra Khvaleeva (story)',
#              'Aleksandra Khvaleeva',
#              'Aleksandra Khvaleeva',
#              'Oleg Mustafin (story)',
#              'Evgeniya Mustafina (story)'],
#  'year': 2015}
# {'_id': ObjectId('573a13f4f29313caabde0bfd'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Rory Culkin', 'Leticia Jimenez', 'Jack Kesy', 'Timothy T. McKinney'],
#  'countries': ['USA'],
#  'directors': ['Adam Schindler'],
#  'fullplot': 'Anna suffers from agoraphobia so crippling that when a trio of '
#              'criminals break into her house, she cannot bring herself to '
#              "flee. But what the intruders don't realize is that agoraphobia "
#              'is not her only psychosis.',
#  'genres': ['Drama', 'Horror', 'Thriller'],
#  'imdb': {'id': 4009278, 'rating': 7.1, 'votes': 79},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 02:00:44.673000000',
#  'num_mflix_comments': 0,
#  'plot': 'Anna suffers from agoraphobia so crippling that when a trio of '
#          'criminals break into her house, she cannot bring herself to flee. '
#          "But what the intruders don't realize is that agoraphobia is not her "
#          'only psychosis.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY5MzE0MjUwNV5BMl5BanBnXkFtZTgwNjQxNzM2NzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2016, 2, 19, 0, 0),
#  'runtime': 90,
#  'title': 'Shut In',
#  'type': 'movie',
#  'writers': ['T.J. Cimfel', 'David White'],
#  'year': 2015}
# {'_id': ObjectId('573a13f4f29313caabde1834'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Kristian Fjord',
#           'Jacob Wagner Guldager',
#           'Casper Sloth',
#           'Signe Mathilde Sèrensen'],
#  'countries': ['Denmark', 'Sweden'],
#  'directors': ['Anders Johannes Bukh'],
#  'fullplot': 'November 18th 2011 a small Danish film crew disappeared in the '
#              'woods of northern Sweden without a trace. One year later, their '
#              'footage was leaked by a hacker group now known as Pandoras. This '
#              "is the crew's unsettling and disturbing footage.",
#  'genres': ['Horror', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 4047752, 'rating': 6.9, 'votes': 77},
#  'languages': ['Danish'],
#  'lastupdated': '2015-09-06 00:16:10.650000000',
#  'num_mflix_comments': 0,
#  'plot': 'Encounters - The woods have secrets.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzQxODQ2OTg3MV5BMl5BanBnXkFtZTgwMDE3MDMxMzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 10, 30, 0, 0),
#  'runtime': 95,
#  'title': 'Encounters',
#  'type': 'movie',
#  'writers': ['Anders Johannes Bukh', 'Anders Johannes Bukh'],
#  'year': 2014}
# {'_id': ObjectId('573a13f4f29313caabde1d9a'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Imogen Poots', 'Patrick Stewart', 'Alia Shawkat', 'Anton Yelchin'],
#  'countries': ['USA'],
#  'directors': ['Jeremy Saulnier'],
#  'fullplot': 'A band straying into a secluded part of the Pacific Northwest, '
#              'stumbles on to a horrific act of violence. Because they are the '
#              'only witnesses, they become the targets of a terrifying gang of '
#              'white power skinheads who want to make sure all the evidence is '
#              'eliminated.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 4062536, 'rating': 7.4, 'votes': 124},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:23:02.447000000',
#  'metacritic': 78,
#  'num_mflix_comments': 1,
#  'plot': 'A young punk rock band find themselves trapped in a secluded venue '
#          'after stumbling upon a horrific act of violence.',
#  'released': datetime.datetime(2015, 5, 17, 0, 0),
#  'runtime': 94,
#  'title': 'Green Room',
#  'type': 'movie',
#  'writers': ['Jeremy Saulnier'],
#  'year': 2015}
# {'_id': ObjectId('573a13f4f29313caabde254c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Carrie-Anne Moss', 'Xavier Samuel', 'Danny Huston', 'Tony Todd'],
#  'countries': ['USA', 'Germany'],
#  'directors': ['Bernard Rose'],
#  'fullplot': 'A married couple of scientists create a modern-day monster.',
#  'genres': ['Horror', 'Thriller'],
#  'imdb': {'id': 4086032, 'rating': 6.2, 'votes': 106},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:11:27.633000000',
#  'num_mflix_comments': 0,
#  'plot': 'A married couple of scientists create a modern-day monster.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 25, 0, 0),
#  'runtime': 89,
#  'title': 'Frankenstein',
#  'type': 'movie',
#  'writers': ['Bernard Rose'],
#  'year': 2015}
# {'_id': ObjectId('573a13f5f29313caabde3411'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Katie Savoy', 'Chris Riedell', 'Lincoln Hoppe', 'Chris Dinh'],
#  'countries': ['USA'],
#  'directors': ['Viet Nguyen'],
#  'fullplot': 'A couple of master thieves find themselves trapped within a '
#              "house they intended to rob, only to discover they've "
#              'inadvertently wandered into the lair of a deranged serial '
#              'killer.',
#  'genres': ['Comedy', 'Horror', 'Thriller'],
#  'imdb': {'id': 4149732, 'rating': 6.4, 'votes': 19},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 08:37:46.063000000',
#  'num_mflix_comments': 0,
#  'plot': 'A couple of master thieves find themselves trapped within a house '
#          "they intended to rob, only to discover they've inadvertently "
#          'wandered into the lair of a deranged serial killer.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNDg4OTAxNl5BMl5BanBnXkFtZTgwNDI1MjAwNjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 6, 11, 0, 0),
#  'runtime': 80,
#  'title': 'Crush the Skull',
#  'type': 'movie',
#  'writers': ['Chris Dinh', 'Viet Nguyen'],
#  'year': 2015}
# {'_id': ObjectId('573a13f6f29313caabde4e7e'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Anya Taylor-Joy', 'Ralph Ineson', 'Kate Dickie', 'Harvey Scrimshaw'],
#  'countries': ['Canada', 'USA'],
#  'directors': ['Robert Eggers'],
#  'fullplot': 'New England, 1630: William and Katherine lead a devout Christian '
#              'life, homesteading on the edge of an impassible wilderness, with '
#              'five children. When their newborn son mysteriously vanishes and '
#              "their crops fail, the family begins to turn on one another. 'The "
#              "Witch' is a chilling portrait of a family unraveling within "
#              'their own fears and anxieties, leaving them prey for an '
#              'inescapable evil.',
#  'genres': ['Horror'],
#  'imdb': {'id': 4263482, 'rating': 7.5, 'votes': 612},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:47.413000000',
#  'metacritic': 90,
#  'num_mflix_comments': 1,
#  'plot': 'The age-old concepts of witchcraft, black magic and possession are '
#          "innovatively brought together to tell the story of one family's "
#          'frightful unraveling.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUyNzkwMzAxOF5BMl5BanBnXkFtZTgwMzc1OTk1NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'runtime': 90,
#  'title': 'The Witch',
#  'type': 'movie',
#  'writers': ['Robert Eggers'],
#  'year': 2015}
# {'_id': ObjectId('573a13f9f29313caabde9c7b'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Yael Grobglas',
#           'Yon Tumarkin',
#           'Danielle Jadelyn',
#           'Dibi Ben-Yosef'],
#  'countries': ['Israel'],
#  'directors': ['Doron Paz', 'Yoav Paz'],
#  'fullplot': 'When a couple of American young adults fly to Israel to visit '
#              'the city of Jerusalem, a biblical nightmare falls upon the city',
#  'genres': ['Horror'],
#  'imdb': {'id': 4552524, 'rating': 6.3, 'votes': 34},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 00:11:46.537000000',
#  'num_mflix_comments': 0,
#  'plot': 'When a couple of American young adults fly to Israel to visit the '
#          'city of Jerusalem, a biblical nightmare falls upon the city',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc2MjU2ODY3M15BMl5BanBnXkFtZTgwMTg5OTc3NTE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 87,
#  'title': 'Jeruzalem',
#  'type': 'movie',
#  'writers': ['Doron Paz (paz brothers)', 'Yoav Paz (paz brothers)'],
#  'year': 2015}

# %%
#3. Write a query to delete all movies that were released before the year 1950.
collection.delete_many({"year": {"$lt": 1950}})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff00000000000001d7'), 'opTime': {'ts': Timestamp(1730748694, 45), 't': 471}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1730748694, 45), 'signature': {'hash': b'):\xdeT\xa1g\xd2/}\xb2\x9c\x98m\xf7\x0e\x12a\xa0\xe3?', 'keyId': 7389295562647928840}}, 'operationTime': Timestamp(1730748694, 45)}, acknowledged=True)

# %% [markdown]
# Exercise 5: Text Search

# %%
#1. Ensure the title field is indexed for text search in MongoDB and write a query to search for movies that contain the word "love" in their title.
love_movies = collection.find({"$text": {"$search": "love"}})
for movie in love_movies:
    pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'countries': ['Australia'],
#  'directors': ['David Michèd'],
#  'fullplot': 'Despite being no saint herself, Julia Cody has shielded her '
#              'seventeen year old son, Joshua "J" Cody, from her '
#              'Melbourne-based criminal relatives who they have not seen in '
#              "years. After Julia dies in front of J's eyes from a "
#              'self-inflicted heroin overdose, J, who is slightly detached from '
#              'life, feels he has no choice but to contact his maternal '
#              'grandmother, Janine "Smurf" Cody, the family matriarch, for a '
#              'place to live. Smurf rules the family with a borderline '
#              'incestuous love over her three sons, the quietly menacing Andrew '
#              '"Pope" Cody, the hyperactive Craig Cody, and the barely of age '
#              'Darren Cody. Pope and his best friend, Barry "Baz" Brown, are '
#              'armed robbers, with Darren their up and coming apprentice, while '
#              "Craig is a mid level drug dealer. Melbourne's Armed Robbery "
#              'Squad is after specifically Pope, who is hiding out. But when '
#              'the standoff between the Codys and the Armed Robbery Squad is '
#              'brought up a notch, an all out war ensues, with some casualties '
#              "and J caught in the middle. The only grounding in J's life is "
#              'his girlfriend, Nicky Henry. With those casualties comes an '
#              'investigation by Homicide Detective Senior Sergeant Nathan '
#              'Leckie, who knows the Codys are involved in some of those '
#              'deaths. As Leckie tries to get J on his side, J has to figure '
#              'out how best to get himself out from the middle, where he trusts '
#              'neither side. J also wants to figure out how to exact what he '
#              'considers justice in an all around bad situation.',
#  'genres': ['Crime', 'Drama', 'Thriller'],
#  'imdb': {'id': 1313092, 'rating': 7.3, 'votes': 42423},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:39:45.797000000',
#  'metacritic': 83,
#  'num_mflix_comments': 0,
#  'plot': 'A seventeen year-old navigates his survival amongst an explosive '
#          'criminal family and the detective who thinks he can save him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NjcwNjE4NV5BMl5BanBnXkFtZTcwNDU2NDg1Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 6, 3, 0, 0),
#  'runtime': 113,
#  'title': 'Animal Kingdom',
#  'tomatoes': {'boxOffice': '$1.0M',
#               'consensus': 'With confident pacing, a smart script, and a '
#                            'top-notch cast, Animal Kingdom represents the best '
#                            'the Australian film industry has to offer.',
#               'critic': {'meter': 96, 'numReviews': 152, 'rating': 8.0},
#               'dvd': datetime.datetime(2011, 1, 18, 0, 0),
#               'fresh': 146,
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 53, 45),
#               'production': 'Sony Pictures Classics',
#               'rotten': 6,
#               'viewer': {'meter': 83, 'numReviews': 28922, 'rating': 3.9},
#               'website': 'http://www.sonyclassics.com/animalkingdom'},
#  'type': 'movie',
#  'writers': ['David Michèd'],
#  'year': 2010}
# {'_id': ObjectId('573a13b6f29313caabd47009'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Jerry Banks', 'Jill Bennett', 'Jamie Blake', 'Emily A. Burton'],
#  'countries': ['USA'],
#  'directors': ['Lee Friedlander'],
#  'fullplot': 'Ever have an identity crisis? Tell a little white lie here and '
#              'there, just to make everyone happy? Well, Alex Houston has got '
#              'you beat, hands down. After telling her fiancè, Dana, that her '
#              'entire family is dead, Manhattanite Alex whisks off to her '
#              'childhood home in South Carolina to serve as bridesmaid at her '
#              "high-maintenance, estranged sister Jeannie's wedding. As she "
#              "tries not to steal Jeannie's thunder by telling her family that "
#              "a) she's engaged, and b) the man she's going to marry is a "
#              'Jewish African American, things get a little mixed up. For '
#              "starters, Alex's sharp-tongued, mischievous best friend Jonathan "
#              'unwittingly starts a rumor at the wedding that Alex is gay and '
#              'Dana is a woman. When her family reacts in a surprisingly '
#              "supportive way, Alex decides to go with it. It's easier than "
#              'telling the truth, right? But when Alex and Jonathan decide to '
#              'hire sexy lesbian Risa to act as her lover when Jeannie comes to '
#              'visit Alex in New York, things really start to get out of hand. '
#              'Director Lee Friedlander follows up her award-winning 2004 film '
#              '"Girl Play" with this witty, farcical romp that explores the '
#              'sometimes comically bumbling way in which we come out to the '
#              "people we love - whether we're gay or straight. As she becomes "
#              'increasingly entangled in her web of lies, Alex struggles to '
#              'come to terms with her fiancè, her family and most of all '
#              'herself along the way.',
#  'genres': ['Comedy', 'Romance'],
#  'imdb': {'id': 488023, 'rating': 6.2, 'votes': 636},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:46:16.023000000',
#  'num_mflix_comments': 0,
#  'plot': 'Ever have an identity crisis? Tell a little white lie here and '
#          'there, just to make everyone happy? Well, Alex Houston has got you '
#          'beat, hands down. After telling her fiancè, Dana, that her ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI1OTc5ODY0MV5BMl5BanBnXkFtZTcwMzYzNTg0MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 96,
#  'title': 'Out at the Wedding',
#  'tomatoes': {'dvd': datetime.datetime(2009, 2, 17, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 2, 36),
#               'production': 'Goff-Kellam Productions',
#               'viewer': {'meter': 51, 'numReviews': 498, 'rating': 3.3},
#               'website': 'http://www.outatthewedding.com/'},
#  'type': 'movie',
#  'writers': ['Paula Goldberg'],
#  'year': 2007}
# {'_id': ObjectId('573a13abf29313caabd25ad2'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Zayed Khan', 'Esha Deol', 'Gulshan Grover', 'Rakhi Sawant'],
#  'countries': ['India'],
#  'directors': ['Sangeeth Sivan'],
#  'fullplot': 'A beautiful, captive young woman name Tina Khanna and her '
#              'friends Riya, and Coco, based in India, are invited to a wedding '
#              'in Bangkok, Thailand. All three travel to Bangkok to attend the '
#              'wedding. On residing there, one day on a mishap Tina manages to '
#              'reach up with super-star Vijay Chouhan and after a couple of ups '
#              'and downs both fell in love with each other. Then Tina finds out '
#              'that her Uncle Tony has been killed in an accident. She is given '
#              'his belongings, and there after thrust into a nightmare by a '
#              'gang of people who is terrorizing her for a 100 million that was '
#              "said to her uncle's money but was passed onto her after her "
#              "uncle's death. These people will stop at nothing but to get that "
#              '100 million and so they keep on threatening her with death if '
#              'she does not pay up that 100 million. This is too much to take '
#              'for Tina and she turns to Vijay for help, only to find out that '
#              'he is Prakash Yogi, the brother of a criminal who belonged to '
#              'the same gang as Tony, who were successful in robbing an '
#              'armoured vehicle in India, three years ago. The only person who '
#              'can now help Tina is in the Indian Embassy, Deepak Chopra, but '
#              'he too has an ulterior motive. Vijay however manages to convince '
#              'Tina that Deepak Chopra is not what he claims to be but a fraud '
#              'and that he himself is Prakash Yogi. But Tina disbelieves this '
#              'and headed towards Deepak with the 100 million fearing Vijay. '
#              'Her eyes are open when she is trapped by Deepak but Vijay '
#              'manages to reach in the nick of time and destroy Deepak alias '
#              'Prakash Yogi and saves Tina.',
#  'genres': ['Action', 'Drama', 'Mystery'],
#  'imdb': {'id': 345043, 'rating': 3.9, 'votes': 390},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-21 01:03:29.733000000',
#  'num_mflix_comments': 0,
#  'plot': 'A beautiful, captive young woman name Tina Khanna and her friends '
#          'Riya, and Coco, based in India, are invited to a wedding in Bangkok, '
#          'Thailand. All three travel to Bangkok to attend the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY5OTg1ODk0MV5BMl5BanBnXkFtZTcwMTEwMjU1MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2003, 3, 21, 0, 0),
#  'runtime': 143,
#  'title': 'Chura Liyaa Hai Tumne',
#  'tomatoes': {'critic': {'meter': 51, 'numReviews': 97, 'rating': 6.0},
#               'dvd': datetime.datetime(2004, 12, 28, 0, 0),
#               'fresh': 49,
#               'lastUpdated': datetime.datetime(2015, 8, 17, 18, 23, 18),
#               'production': 'MGM',
#               'rotten': 48,
#               'viewer': {'meter': 59, 'numReviews': 8545, 'rating': 3.3},
#               'website': 'http://www.mgm.com/ua/code46/'},
#  'type': 'movie',
#  'writers': ['Venita Coelho (screenplay)',
#              'Sanjay Masoom (additional dialogue)',
#              'Vibha Singh (dialogue)'],
#  'year': 2003}
# {'_id': ObjectId('573a13a0f29313caabd028c8'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Chris Klein', 'Leelee Sobieski', 'Josh Hartnett', 'Michael Rooker'],
#  'countries': ['USA'],
#  'directors': ['Mark Piznarski'],
#  'fullplot': 'The lives of three young people - a rich student, a girl from '
#              'the "wrong side of the tracks" and her boyfriend - unexpectedly '
#              'intersect during one fateful summer in the romantic drama "Here '
#              'on Earth." Kelley Morse (Chris Klein), who is cocky and brash, '
#              'normally would never have crossed paths with the residents of a '
#              'small town near his posh private school. But when he takes his '
#              'shiny new Mercedes out for a drive, he locks horns with some of '
#              "the locals, including Jasper (Josh Hartnett). As Jasper's "
#              'willful girlfriend Samantha (Leelee Sobieski) looks on, Kelley '
#              'and Jasper engage in a dangerous car race that turns disastrous, '
#              "leaving a popular diner owned by Samantha's mother in ruins. "
#              'Kelley and Jasper are sentenced to a creatively ironic but '
#              'fitting punishment: They must help rebuild the diner. Not only '
#              "does this ruin Kelley's summer plans, he also must board at the "
#              'home of his rival, Jasper. Kelley begins to fulfill his '
#              '"sentence," but refuses to have anything to do with Jasper and '
#              'his parents. When Kelley again encounters Samantha, the '
#              'attraction is immediate and strong. First love blossoms in the '
#              'Berkshire woods ("a little bit of heaven, here on earth," '
#              'Samantha calls the pastoral setting), angering Jasper, who has '
#              'known Samantha practically his entire life. These new feelings '
#              'and the romantic triangle that develops are only the beginning '
#              'of a new journey for Kelley, Samantha and Jasper, as they '
#              'ultimately make life-changing discoveries about themselves and '
#              'each other.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 195778, 'rating': 5.0, 'votes': 7044},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:19:06.733000000',
#  'metacritic': 25,
#  'num_mflix_comments': 0,
#  'plot': 'A rich college kid is taught a lesson after a joy ride ends up '
#          'destroying a country restaurant.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYmViZTk5YzUtMjQzZi00MGZkLWE1N2UtMzY3MDJmNjBiM2U1XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2000, 3, 24, 0, 0),
#  'runtime': 96,
#  'title': 'Here on Earth',
#  'tomatoes': {'consensus': "Critics say Here on Earth's weakness comes from "
#                            'its script. The story may appeal to young teenage '
#                            'girls, but it suffers from being overly '
#                            'sentimental and formulaic. The cinematography, '
#                            'however, is lovely in how it captures its '
#                            'Minnesota setting.',
#               'critic': {'meter': 17, 'numReviews': 69, 'rating': 3.8},
#               'dvd': datetime.datetime(2001, 1, 9, 0, 0),
#               'fresh': 12,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 16, 53),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'rotten': 57,
#               'viewer': {'meter': 62, 'numReviews': 20187, 'rating': 3.1},
#               'website': 'http://www.hereonearthmovie.com'},
#  'type': 'movie',
#  'writers': ['Michael Seitzman'],
#  'year': 2000}
# {'_id': ObjectId('573a139af29313caabcf0f45'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['James Caan', 'Jacob Tierney', 'Colm Meaney', 'Moira Deady'],
#  'countries': ['Ireland', 'Canada'],
#  'directors': ['Paul Quinn'],
#  'fullplot': 'Widowed Kieran Johnson is a lonely, middle-aged, Chicago-based '
#              'high school history teacher who feels disconnected to his life. '
#              "He decides to take a trip to his mother's small old hometown of "
#              'Kilronan, County Galway, Ireland after he discovers an old '
#              'photograph of her, she who now cannot speak due to a stroke, '
#              'with a man he has never seen. He suspects this man may be his '
#              'biological father. On the urging of his sister, Kieran takes his '
#              'teen-aged nephew Jack on the trip. In Kilronan, Mrs. Kearney, '
#              "the innkeeper's mother and a bit of a gypsy woman who has lived "
#              'in the area for the better part of her life, tells Kieran and '
#              'Jack about life in the town in 1939 when a high-spirited Fiona '
#              "Flynn, Kieran's mother, started seeing a peat farmer named "
#              'Kieran O\'Day. Kieran O\'Day grew up a "poorhouse bastard", and '
#              'as such he was always shy and considered an outsider amongst the '
#              'townsfolk. Because of his standing in the community and the '
#              'differences in their ages (she being only seventeen, he in his '
#              "thirties), Fiona and Kieran's relationship was looked down upon "
#              "by those considered the upstanding in town, including Fiona's "
#              'widowed mother, Mary Flynn, and those associated with the '
#              'church. Mrs. Kearney slowly tells the entire story of Kieran and '
#              "Fiona's relationship, the tragedy that prevented their love for "
#              'not being enough to endure the scrutiny, the stories of the '
#              '"curses" that befell the Flynn family, and the truth behind the '
#              'person Kieran Johnson knew as his father.',
#  'genres': ['Romance', 'Drama'],
#  'imdb': {'id': 120865, 'rating': 7.1, 'votes': 1492},
#  'languages': ['English'],
#  'lastupdated': '2015-08-01 00:07:50.687000000',
#  'num_mflix_comments': 1,
#  'plot': 'Widowed Kieran Johnson is a lonely, middle-aged, Chicago-based high '
#          'school history teacher who feels disconnected to his life. He '
#          "decides to take a trip to his mother's small old hometown ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzEyNjQ3MDY0NV5BMl5BanBnXkFtZTcwODgxMDIyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1999, 5, 7, 0, 0),
#  'runtime': 119,
#  'title': 'This Is My Father',
#  'tomatoes': {'critic': {'meter': 75, 'numReviews': 28, 'rating': 6.7},
#               'dvd': datetime.datetime(1999, 10, 5, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 28, 29),
#               'production': 'Sony Pictures Classics',
#               'rotten': 7,
#               'viewer': {'meter': 82, 'numReviews': 1375, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Paul Quinn'],
#  'year': 1998}
# {'_id': ObjectId('573a1397f29313caabce5fac'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Lino Capolicchio',
#           'Francesca Marciano',
#           'Gianni Cavina',
#           'Giulio Pizzirani'],
#  'countries': ['Italy'],
#  'directors': ['Pupi Avati'],
#  'fullplot': 'The restorer Stefano is hired by the Mayor Solmi of a small '
#              'village nearby Ferrara to restore a painting of St. Sebastian, '
#              'made by the mentally disturbed painter Buono Legnani in the '
#              'local church. Stefano was recommended by his friend, Dr. Antonio '
#              'Mazza, and he learns that Legnani was known as "The Painter of '
#              'the Agony", since he used to paint near-death people. Further, '
#              'he was presumed dead many years ago but his body has never been '
#              'found. Stefano works in the church, where he meets the weirdo '
#              'Lidio, and he has one night stand with the local nymphomaniac '
#              'teacher that is leaving the village. Meanwhile Antonio '
#              'investigates the life of Buono Legnani and tells Stefano that he '
#              'had found a dark secret about the painter and the villagers. '
#              'However, Antonio dies before meeting Stefano and the police '
#              'conclude that he committed suicide. Stefano is intrigued by the '
#              'mystery surrounds Legnani and decides to investigate more about '
#              'the deranged painter. However, he in evicted of his hotel room '
#              'and Lidio brings him to the isolated house of a paraplegic woman '
#              "where he lives. Meanwhile, he meets the teacher's substitute "
#              'Francesca and they have a love affair. Francesca moves to '
#              "Stefano's room and they are affected by the strange atmosphere "
#              'of the place. When the restoration is damaged by acid, Stefano '
#              'decides to leave the village with Francesca. However, he meets '
#              'the alcoholic driver Coppola that decides to disclose to him the '
#              'secret of the house of the laughing windows. But now it seems to '
#              'be too late to move out of the mysterious village.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 74287, 'rating': 7.1, 'votes': 3036},
#  'languages': ['Italian'],
#  'lastupdated': '2015-09-11 00:39:27.400000000',
#  'num_mflix_comments': 0,
#  'plot': 'The restorer Stefano is hired by the Mayor Solmi of a small village '
#          'nearby Ferrara to restore a painting of St. Sebastian, made by the '
#          'mentally disturbed painter Buono Legnani in the local ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYmM5Zjk2NDMtMGJhMC00NjA3LWIxODAtNjU3MzIwM2ViMzM5XkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1976, 8, 16, 0, 0),
#  'runtime': 110,
#  'title': 'The House of the Laughing Windows',
#  'tomatoes': {'dvd': datetime.datetime(2003, 3, 11, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 16, 18, 25, 25),
#               'production': 'A.M.A. Film',
#               'viewer': {'meter': 72, 'numReviews': 749, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Antonio Avati (screenplay)',
#              'Antonio Avati (story)',
#              'Pupi Avati (screenplay)',
#              'Pupi Avati (story)',
#              'Gianni Cavina',
#              'Maurizio Costanzo'],
#  'year': 1976}
# {'_id': ObjectId('573a13ecf29313caabdd1fc2'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Charles Martin Garcia',
#           'Davina Reid',
#           'Leon Salem',
#           'Marion Blount'],
#  'countries': ['USA'],
#  'directors': ['Mounir Chakor'],
#  'fullplot': 'Terrorists. Kidnapping. A plot gone wrong. American Hostage '
#              'tells the story of four terrorists coming together to create '
#              'change within the American government and affect their stance on '
#              'Guantanamo Bay. With tensions high, emotions between the '
#              'terrorists collide, which sets the story into a downward spiral. '
#              'American Hostage unveils the story of Asad, Hamal, Shahin and '
#              'Fahdah, who each has their own motive for joining the war in '
#              'terror. Asad, the appointed leader of the group, manages the '
#              'team with strict and clear direction, taking orders behind the '
#              'scenes from Al-Saqri whose motives are unclear. Asad shows one '
#              'weakness, the affection for fellow terrorist Fahdah, a soft '
#              'spoken young Arab woman. Asad and Fahdah develop an adoration '
#              "for each other, despite the disapproval from Fahdah's brother "
#              'Hamal whose anger from the overall situation escalates '
#              'throughout the story. Meanwhile Shahin, the fourth terrorist, '
#              'and prisoner Sergeant Donald Young begin to form a bond as they '
#              'share stories about family, faith and love. Although the plan of '
#              'gaining explicit media coverage after leaking the hostage tapes, '
#              'the U.S. government shows no cooperation in response to the '
#              'demands on Guantanamo Bay. The terrorists go through extreme '
#              'measures in attempts to persuade the government one final time. '
#              'But before their plan is executed, unforeseen circumstances '
#              'arise that force them to think and act in a different '
#              'direction...',
#  'genres': ['Crime', 'Drama', 'Thriller'],
#  'imdb': {'id': 3468612, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-24 00:19:40.167000000',
#  'num_mflix_comments': 0,
#  'plot': 'American Hostage pulls back the curtains on a terrorist plot '
#          'centered on a group of terrorists holding two American soldiers '
#          'hostage on U.S. soil. They demand the release of all prisoners of '
#          'Guantanamo Bay or they will kill the soldiers.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTA4NTcyMzQ0NTBeQTJeQWpwZ15BbWU4MDYwMTAwMDUx._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 3, 26, 0, 0),
#  'runtime': 100,
#  'title': 'American Hostage',
#  'type': 'movie',
#  'writers': ['Mounir Chakor'],
#  'year': 2015}
# {'_id': ObjectId('573a13c7f29313caabd756f0'),
#  'awards': {'nominations': 4, 'text': '5 wins & 4 nominations.', 'wins': 5},
#  'cast': ['Samira Maas', 'Coosje Smid', 'Dragan Bakema', 'Sharon Schouten'],
#  'countries': ['Netherlands'],
#  'directors': ['Mijke de Jong'],
#  'fullplot': 'Joy is an emotionally damaged young woman of eighteen, who was '
#              'given up at birth, to grow up in homes and with foster families. '
#              'She lives on the fringes of society, getting by on benefits and '
#              'earning a little extra by playing the accordion in the subway. '
#              'In addition, she is a skilled shoplifter and has never been '
#              'caught. The film follows her closely during her dogged search '
#              'for her unknown biological mother. Joy has a rather distant '
#              'quality and the only times we see her animated is during her '
#              'obsessive attempts to discover the identity and address of her '
#              'mother. She clings to her conviction that she was the product of '
#              'a loving relationship and that is why her mother called her Joy. '
#              'This belief is all she has to hang onto in life. Her other '
#              'activities revolve around her friend, Denise (16), who has got '
#              'pregnant on purpose and is living in the home from which Joy was '
#              'expelled because of bad behaviour, and her boyfriend Momo (21), '
#              'a second-generation immigrant who was born and bred in Holland. '
#              "Joy's search for her biological mother, have led her to an old "
#              'address; on the basis of a vague physical resemblance, she '
#              'assumes that the woman she finds there is her mother. She starts '
#              'to follow the woman on her way to work and during shopping '
#              'trips, and watches the house where she lives with her teenage '
#              'daughter. Joy becomes more cheerful and more alert, and begins '
#              'to develop an eye for the world around her - giving us a glimpse '
#              'of the young woman she could have become if she had had a bit '
#              'more luck. Then she hears someone call the woman by her name - a '
#              'different name from that of her biological mother. She is '
#              'profoundly shocked: her world seems to collapse around her.',
#  'genres': ['Drama'],
#  'imdb': {'id': 1465490, 'rating': 6.0, 'votes': 186},
#  'languages': ['Dutch'],
#  'lastupdated': '2015-08-18 01:07:03.657000000',
#  'num_mflix_comments': 1,
#  'plot': 'Joy is an emotionally damaged young woman of eighteen, who was given '
#          'up at birth, to grow up in homes and with foster families. She lives '
#          'on the fringes of society, getting by on benefits ...',
#  'released': datetime.datetime(2010, 4, 8, 0, 0),
#  'runtime': 75,
#  'title': 'Joy',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 15, 19, 40, 37),
#               'viewer': {'numReviews': 1, 'rating': 2.0}},
#  'type': 'movie',
#  'writers': ['Helena van der Meulen'],
#  'year': 2010}
# {'_id': ObjectId('573a13a7f29313caabd1ac5a'),
#  'awards': {'nominations': 4, 'text': '2 wins & 4 nominations.', 'wins': 2},
#  'cast': ['Greg Kinnear', 'Willem Dafoe', 'Rita Wilson', 'Maria Bello'],
#  'countries': ['USA'],
#  'directors': ['Paul Schrader'],
#  'fullplot': 'In 1965, Bob Crane, who had achieved some earlier success as a '
#              'television supporting actor, was working as a successful morning '
#              'radio DJ at KNX Los Angeles. Despite enjoying his work, '
#              'photography (especially of the female form) and drumming, Crane '
#              'wanted to be a movie star. So it was with some reluctance that '
#              'he accepted the title starring role in a new television sitcom '
#              "called Hogan's Heroes (1965), a WWII POW comedy. To his "
#              'surprise, the show became a hit and catapulted him to television '
#              'stardom. The fame resulting from the show led to excesses and a '
#              'meeting with home video salesman and technician John Carpenter, '
#              'with who he would form a friendship based on their mutual '
#              'interests, namely excessive sex (for Crane, purely heterosexual '
#              'sex) and capturing nude females on celluloid. His fame allowed '
#              'Crane to have as much sex as he wanted, which was incongruent to '
#              'his somewhat wholesome television friendly image, and the way he '
#              'portrayed himself to almost everyone except Carpenter and his '
#              'extramarital sex partners. His sex addiction was somewhat known '
#              'but ignored by his high school sweetheart/first wife Anne Crane '
#              'nèe Terzian, but well known by his second wife, Patti Olson, '
#              "better known as Sigrid Valdis, his Hogan's Heroes co-star. "
#              "Especially after the end of Hogan's Heroes in 1971, this "
#              'incongruence and his friendship with Carpenter, with who he '
#              'would have a continuing love/hate relationship, would contribute '
#              'to both his professional and personal downfall.',
#  'genres': ['Biography', 'Crime', 'Drama'],
#  'imdb': {'id': 298744, 'rating': 6.6, 'votes': 11116},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:17:36.060000000',
#  'metacritic': 66,
#  'num_mflix_comments': 0,
#  'plot': 'A story about "Hogan\'s Heroes" star Bob Crane and his friendship '
#          'with John Carpenter.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMyMjYwMjEwOV5BMl5BanBnXkFtZTYwMDQ4MzI3._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2002, 11, 1, 0, 0),
#  'runtime': 105,
#  'title': 'Auto Focus',
#  'tomatoes': {'boxOffice': '$1.8M',
#               'consensus': 'Kinnear and Dafoe help make this downward spiral '
#                            "of one man's life a compelling watch.",
#               'critic': {'meter': 72, 'numReviews': 158, 'rating': 6.7},
#               'dvd': datetime.datetime(2003, 3, 18, 0, 0),
#               'fresh': 114,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': 'Sony Pictures Classics',
#               'rotten': 44,
#               'viewer': {'meter': 60, 'numReviews': 5910, 'rating': 3.2},
#               'website': 'http://www.sonyclassics.com/autofocus'},
#  'type': 'movie',
#  'writers': ['Robert Graysmith (book)', 'Michael Gerbosi'],
#  'year': 2002}
# {'_id': ObjectId('573a13b2f29313caabd38ad0'),
#  'awards': {'nominations': 10,
#             'text': 'Nominated for 1 Oscar. Another 4 wins & 10 nominations.',
#             'wins': 5},
#  'cast': ['Freddie Highmore',
#           'Keri Russell',
#           'Jonathan Rhys Meyers',
#           'Terrence Howard'],
#  'countries': ['USA'],
#  'directors': ['Kirsten Sheridan'],
#  'fullplot': 'This is a story of a music prodigy. Lyla is a renowned and '
#              'beautiful cellist and Louis is a guitar player and vocalist at a '
#              'club. Lyla and Louis fall in love once they meet each other '
#              'following the music. Since they have different lives, they have '
#              'to separate without seeing each other again. However, Lyla has '
#              'had their baby - Evan, a prodigy born to music. Lyla has an '
#              "accident and bears the baby but Lyla's father gives the baby to "
#              'an orphanage without telling her, for fear of affecting her '
#              'career. After that, both Louis and Lyla give up their music '
#              'careers. Eleven years later, poor little Evan believes that his '
#              'parents are waiting for him and goes to New York to find them. '
#              'In New York, his musical gift leads him to success but also '
#              'gives him some trouble. A monger uses Evan to make money and '
#              'prevents him from achieving success. He escapes and runs into a '
#              'church and people there are surprised by his gift and send him '
#              'to the best music school, Juilliard. There he receives an '
#              'education where his genius is recognized, and he creates his '
#              'composition - August Rhapsody in C major. At the same time, Lyla '
#              'and Louis both begin to play music again and Louis returns to '
#              'New York. Because of his perfect performance, Evan is granted an '
#              'opportunity to play his music in Central Park in front of '
#              'thousands of people. There are three composers featured, of '
#              'which he is the last; his mother is the cellist in the preceding '
#              'performance. As Evan is conducting the orchestra in his '
#              'rhapsody, Lyla and Louis come to the concert following the music '
#              'again. The family finally get together!',
#  'genres': ['Drama', 'Music'],
#  'imdb': {'id': 426931, 'rating': 7.5, 'votes': 82130},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:06:51.740000000',
#  'metacritic': 38,
#  'num_mflix_comments': 1,
#  'plot': 'A drama with fairy tale elements, where an orphaned musical prodigy '
#          'uses his gift as a clue to finding his birth parents.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDIwNjE3NjU2NV5BMl5BanBnXkFtZTcwNTQ2NjQzMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2007, 11, 21, 0, 0),
#  'runtime': 114,
#  'title': 'August Rush',
#  'tomatoes': {'boxOffice': '$31.5M',
#               'consensus': 'Though featuring a talented cast, August Rush '
#                            'cannot overcome the flimsy direction and schmaltzy '
#                            'plot.',
#               'critic': {'meter': 37, 'numReviews': 123, 'rating': 4.8},
#               'dvd': datetime.datetime(2008, 3, 11, 0, 0),
#               'fresh': 45,
#               'lastUpdated': datetime.datetime(2015, 8, 18, 18, 33, 27),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 78,
#               'viewer': {'meter': 82, 'numReviews': 228694, 'rating': 3.9},
#               'website': 'http://augustrushmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Nick Castle (screenplay)',
#              'James V. Hart (screenplay)',
#              'Paul Castro (story)',
#              'Nick Castle (story)'],
#  'year': 2007}
# {'_id': ObjectId('573a13a6f29313caabd168f7'),
#  'awards': {'nominations': 12,
#             'text': 'Nominated for 2 Golden Globes. Another 7 wins & 12 '
#                     'nominations.',
#             'wins': 9},
#  'cast': ['Kieran Culkin', 'Claire Danes', 'Jeff Goldblum', 'Jared Harris'],
#  'countries': ['USA'],
#  'directors': ['Burr Steers'],
#  'fullplot': 'Seventeen year old Jason Slocumb, Jr. - Igby to most that know '
#              'him - comes from east coast old money, the second son of '
#              'self-absorbed and controlling Mimi Slocumb and '
#              'medically-diagnosed schizophrenic Jason Slocum, Sr., the latter '
#              'who has for several years been institutionalized in a Maryland '
#              "psychiatric facility. While Igby's economics-studying "
#              'Columbia-attending older brother Ollie Slocum has embraced and '
#              'aspires to continue their wealthy life, Igby has rebelled '
#              'against it, considering his brother a fascist (although he could '
#              "soften that label to Republican). Because of Jason's situation, "
#              'Mimi has largely left the role of male role model for Ollie and '
#              "Igby to their godfather, D.H. Banes. Igby's rebellion has led to "
#              'him being kicked out of one prep school after another, the '
#              'latest, a military academy, from which Igby escapes before he '
#              'can graduate. As such, Mimi and D.H. arrange for Igby to live in '
#              'New York with Ollie for the summer while working for D.H. '
#              'renovating some of his properties, before Mimi arranges for yet '
#              'another strict school for the fall so that Igby can at least '
#              'graduate. Igby is largely able to hide out for most of the '
#              "summer with the help of Rachel, D.H.'s younger heroin addict "
#              'mistress, and Sookie, a slightly older waitress with who he '
#              'falls in love. An issue with Sookie and the aftermath of a joint '
#              'mission with Ollie leads to Igby having a clearer picture of '
#              'what his immediate future will look like.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 280760, 'rating': 7.0, 'votes': 28178},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:47:48.850000000',
#  'metacritic': 72,
#  'num_mflix_comments': 0,
#  'plot': "A young man's peculiar upbringing renders him unable to competently "
#          'cope with the struggle of growing up.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNTk2NjY0NF5BMl5BanBnXkFtZTcwMjQ3MTI0NA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2002, 10, 4, 0, 0),
#  'runtime': 98,
#  'title': 'Igby Goes Down',
#  'tomatoes': {'boxOffice': '$4.6M',
#               'consensus': 'In the vein of The Catcher in the Rye, Igby Goes '
#                            'Down is scathingly witty and sharply observant.',
#               'critic': {'meter': 76, 'numReviews': 128, 'rating': 6.9},
#               'dvd': datetime.datetime(2003, 2, 4, 0, 0),
#               'fresh': 97,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 31, 43),
#               'production': 'United Artists Pictures',
#               'rotten': 31,
#               'viewer': {'meter': 80, 'numReviews': 44122, 'rating': 3.4},
#               'website': 'http://www.igbygoesdown.com/'},
#  'type': 'movie',
#  'writers': ['Burr Steers'],
#  'year': 2002}
# {'_id': ObjectId('573a1394f29313caabce08ab'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Mel Blanc'],
#  'countries': ['USA'],
#  'directors': ['Chuck Jones'],
#  'fullplot': '"What\'s Opera, Doc?" lampoons classic opera by using its '
#              "elements to set up the latest chapter in Elmer Fudd's hapless "
#              'pursuit of Bugs Bunny. We open with a silhouette of a mighty '
#              "Viking arousing ferocious lightning storms ... only to find it's "
#              'Elmer -- this time as the demigod Siegfried. Elmer admonishes '
#              'the audience (in classical verse) to "be vewwy quiet, I\'m '
#              'hunting wabbits!" It\'s not long before Elmer comes upon Bugs\' '
#              'hole and sings out "Kill the wabbit!" not realizing that the '
#              'hare has already climbed out and is viewing Elmer spearing '
#              'fruitlessly in said hole. Bugs joins in the fun, querying his '
#              'tagline in operatic verse and leaving Elmer in his dust (but not '
#              'before "Siegfried" shows us an example of supposed "mighty '
#              'powers" from his spear and magic helmet). Elmer goes after the '
#              'wascally wabbit, but his pursuit is ended when he sets his eyes '
#              'on the stunningly and awesomely beautiful Valkyrie Brunhilde '
#              '(Bugs in disguise). After a "hard-to-get" pursuit" (brought on '
#              'by Elmer\'s eternally-misguided hormones) "Siegfried" and '
#              '"Valkyrie" join in magnificent duet with "Return My Love." '
#              "However, Bugs' scheme is exposed when his headdress falls off, "
#              'enraging Elmer. The pseudo-Viking commands fierce lightning, '
#              'rain, hail and wind storms (not to mention smog) to "kill the '
#              'wabbit!" It works, but upon seeing the bunny\'s corpse, a '
#              'woefully remorseful Elmer is reduced to tears as he somberly '
#              'carries the "dead" Bugs into the distance. But has Bugs really '
#              'been struck dead?',
#  'genres': ['Animation', 'Short', 'Comedy'],
#  'imdb': {'id': 51189, 'rating': 8.3, 'votes': 7408},
#  'languages': ['English'],
#  'lastupdated': '2015-07-22 00:20:05.953000000',
#  'num_mflix_comments': 0,
#  'plot': "Elmer Fudd is again hunting rabbits - only this time it's an opera. "
#          "Wagner's Siegfried with Elmer as the titular hero and Bugs as "
#          'Brunnhilde. They sing, they dance, they eat the scenery.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTI5MjY1NTgtNDVhNy00MWQ5LTg4NzItMzQ2ZWIwMDEwMGZlXkEyXkFqcGdeQXVyNjg3MDM4Mzc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1957, 7, 6, 0, 0),
#  'runtime': 7,
#  'title': "What's Opera, Doc?",
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 23, 18, 36, 29),
#               'viewer': {'meter': 91, 'numReviews': 233, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Michael Maltese (story)'],
#  'year': 1957}
# {'_id': ObjectId('573a13d3f29313caabd96c9b'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Nichola Burley',
#           'Martin McCann',
#           'Charlene McKenna',
#           'Ciarèn McMenamin'],
#  'countries': ['UK', 'Ireland'],
#  'directors': ['Kieron J. Walsh'],
#  'fullplot': "Jump follows the lives of four twenty-something's whose lives "
#              "collide one fateful New Year's Eve in a night of fast talk, wild "
#              'coincidence and intrigue. The unseen yet crucial occurrence of '
#              'this tale is the strange disappearance of Eddie Kelly, which '
#              "hangs over the city like a dark cloud. Kelly's 'disappearance' "
#              "at the hands of crime boss Frank Feeney's men links our four "
#              'main characters, triggering a sequence of events which '
#              'ultimately has life changing consequences for each of them. '
#              "Feeney's daughter Greta is severely depressed and is intent on "
#              'taking her own life. Pearse is on a mission to get answers about '
#              'his missing brother Eddie and will stop at nothing until he gets '
#              'to the truth. Johnny, a small time crook who works for Feeney, '
#              'and Marie, a frustrated shop assistant, are both looking for a '
#              'fresh start. Greta and Pearse meet each other in extraordinary '
#              'circumstances on a bridge overlooking the city. Greta is there '
#              'to Jump and Pearse has been beaten and dangled off the bridge by '
#              "Feeney's henchmen for asking difficult questions about his "
#              "brother's disappearance. In their short, magnetic time together "
#              'they become kindred spirits on the cusp of love before fate and '
#              'circumstance take over. A wayward corpse and the busy intrigue '
#              "of New Year's Eve all compose the jigsaw puzzle of this out of "
#              "sequence, multi-stranded story. And as the night's events "
#              'expertly fall into place, Jump weaves an existential portrait of '
#              "our characters' lives as their hopes, fears and secrets are "
#              'revealed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 1927067, 'rating': 6.4, 'votes': 231},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:22:29.540000000',
#  'num_mflix_comments': 1,
#  'plot': 'Crime boss daughter Greta is rescued from suicide by stranger Pearse '
#          "on New Year's Eve, a night that will change both their lives "
#          'forever.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTUzMDg4NjYwMF5BMl5BanBnXkFtZTcwNjI2OTM0OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 6, 8, 0, 0),
#  'runtime': 81,
#  'title': 'Jump',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 21, 18, 2, 40),
#               'production': 'Breaking Glass Pictures',
#               'viewer': {'meter': 53, 'numReviews': 24, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Steve Brookes (screenplay)', 'Kieron J. Walsh (screenplay)'],
#  'year': 2012}
# {'_id': ObjectId('573a13bef29313caabd5aeae'),
#  'awards': {'nominations': 122,
#             'text': 'Won 1 Oscar. Another 95 wins & 122 nominations.',
#             'wins': 96},
#  'cast': ['Bradley Cooper',
#           'Jennifer Lawrence',
#           'Robert De Niro',
#           'Jacki Weaver'],
#  'countries': ['USA'],
#  'directors': ['David O. Russell'],
#  'fullplot': 'Against medical advice and without the knowledge of her husband '
#              'Pat Solatano Sr., caring Dolores Solatano discharges her adult '
#              'son, Pat Solatano Jr., from a Maryland mental health institution '
#              'after his minimum eight month court ordered stint. The condition '
#              'of the release includes Pat Jr. moving back in with his parents '
#              "in their Philadelphia home. Although Pat Jr.'s "
#              'institutionalization was due to him beating up the lover of his '
#              'wife Nikki, he was diagnosed with bipolar disorder. Nikki has '
#              'since left him and has received a restraining order against him. '
#              "Although he is on medication (which he doesn't take because of "
#              'the way it makes him feel) and has mandatory therapy sessions, '
#              'Pat Jr. feels like he can manage on the outside solely by '
#              'healthy living and looking for the "silver linings" in his life. '
#              'His goals are to get his old job back as a substitute teacher, '
#              'but more importantly reunite with Nikki. He finds there are '
#              "certain instances where he doesn't cope well, however no less so "
#              'than some others who have never been institutionalized, such as '
#              'his Philadelphia Eagles obsessed OCD father who has resorted to '
#              'being a bookie to earn a living, his best friend Ronnie who '
#              'quietly seethes over the control wielded by his wife Veronica, '
#              "and Veronica's widowed sister, Tiffany Maxwell, a recovering sex "
#              'addict. In their fragile mental states, Pat Jr. and Tiffany '
#              'embark on a love/hate friendship based primarily on what help '
#              'the other can provide in achieving their individual goals. But '
#              'they may reevaluate their goals as their relationship '
#              'progresses.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 1045658, 'rating': 7.8, 'votes': 482610},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:00:39.960000000',
#  'metacritic': 81,
#  'num_mflix_comments': 0,
#  'plot': 'After a stint in a mental institution, former teacher Pat Solitano '
#          'moves back in with his parents and tries to reconcile with his '
#          'ex-wife. Things get more challenging when Pat meets Tiffany, a '
#          'mysterious girl with problems of her own.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM2MTI5NzA3MF5BMl5BanBnXkFtZTcwODExNTc0OA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2012, 12, 25, 0, 0),
#  'runtime': 122,
#  'title': 'Silver Linings Playbook',
#  'tomatoes': {'boxOffice': '$132.1M',
#               'consensus': 'Silver Linings Playbook walks a tricky thematic '
#                            "tightrope, but David O. Russell's sensitive "
#                            'direction and some sharp work from a talented cast '
#                            'gives it true balance.',
#               'critic': {'meter': 92, 'numReviews': 228, 'rating': 8.2},
#               'dvd': datetime.datetime(2013, 4, 30, 0, 0),
#               'fresh': 209,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 11, 52),
#               'production': 'The Weinstein Company',
#               'rotten': 19,
#               'viewer': {'meter': 86, 'numReviews': 255855, 'rating': 4.1},
#               'website': 'http://silverliningsplaybookmovie.com/'},
#  'type': 'movie',
#  'writers': ['David O. Russell (screenplay)', 'Matthew Quick (novel)'],
#  'year': 2012}
# {'_id': ObjectId('573a13b2f29313caabd399c7'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Thomas Campbell', 'Shepard Fairey', 'Jo Jackson', 'Chris Johanson'],
#  'countries': ['USA'],
#  'directors': ['Aaron Rose', 'Joshua Leonard'],
#  'fullplot': 'The greatest cultural accomplishments in history have never been '
#              'the result of the brainstorms of marketing men, corporate focus '
#              'groups, or any homogenized methods; they have always happened '
#              'organically. More often than not, these manifestations have been '
#              'the result of a few like-minded people coming together to create '
#              'something new and original for no other purposethan a common '
#              'love of doing it. In the 1990s, a loose-knit group of American '
#              'artists and creators, many just out of their teens, began their '
#              'careers in just such a way. Influenced by the popular '
#              'underground youth subcultures of the day, such as skateboarding, '
#              'graffiti, street fashion and independent music, artists like '
#              'Shepard Fairey, Mark Gonzales, Spike Jonze, Margaret Kilgallen, '
# ...
#              'best friend Todd (Zachary Booth) either. Todd has betrayed their '
#              'blue-collar roots by accepting a scholarship to college. But '
#              "Brian has a secret -- he's a talented artist. In the basement of "
#              "the bagel shop beneath his parent's apartment, he creates "
#              'impressionistic charcoal and watercolor images of the stifling '
#              'city that surrounds him. When he puts on his headphones and '
#              "paints, shouting matches between Brian's longshoreman father "
#              'Paddy (Stephen Lang) and world-weary mother (Karen Allen) fade '
#              "into the distance. But even his private world can't block out "
#              'the brutal beatings a drunken Paddy inflicts on Danny. Though '
#              'Paddy has never been physically abusive to Brian, every time he '
#              "sees his brother's suffering, his heart breaks a little more. "
#              'Besides his art, Brian finds respite in working for Whitey '
#              '(Peter Riegert), a kindly curmudgeon who runs the failing '
#              "Lafayette movie theater in Bay Ridge. Brian's been helping "
#              'Whitey pay his debts to local mobster Jimmy Cheeks (Ken '
#              'Jennings) by bringing in rock groups to play gigs at the '
#              'theater. With money problems mounting, Whitey decides to call in '
#              'a lifelong favor from an old friend, now the tour manager of the '
#              'Rolling Stones. The Stones will stop to play the Lafayette for '
#              'one hour only on their way to Madison Square Garden...a plan '
#              'Whitey hopes will solve his loan shark problems forever. The '
#              'small Brooklyn neighborhood buzzes with anticipation of the '
#              "Stones' arrival, which gives Brian the courage to talk to pretty "
#              'Shauna Friel (Leslie Murphy), the girl he was too shy to '
#              'approach in high school. Shauna, a travel agent, is awaiting '
#              'transfer to a glamorous new job in Los Angeles, and dreams of '
#              "traveling the world before she's 25. She and one of Brian's "
#              'other friends, the college-bound Todd, begin to plant new seeds '
#              "of hope in Brian's doubtful mind. Perhaps his art could be a "
#              'ticket for him out of his dead end life and into a future of '
#              'possibilities. When one excessively violent beating from Paddy '
#              "convinces Danny he can't stay at home anymore, he tries to "
#              'enlist Brian in one last scheme - to rob the Lafayette on the '
#              'night of the Rolling Stones concert. Danny sees this as their '
#              'only chance to get enough money to skip town and start them both '
#              'off in a new life, somewhere far away from Brooklyn. As the '
#              'theater fills with revelers, Brian is torn between his love and '
#              'loyalty to Danny and his real fondness for Whitey. In the twists '
#              'and turns that follow, both brothers must reexamine their '
#              'dreams, and make decisions that will change their lives forever.',
#  'genres': ['Drama'],
#  'imdb': {'id': 1550524, 'rating': 6.8, 'votes': 1544},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 13:00:23.613000000',
#  'metacritic': 51,
#  'num_mflix_comments': 0,
#  'plot': 'Brooklyn, 1975: two brothers looking for a way out of their '
#          'working-class neighborhood make a pact to rob a local theater on the '
#          'night of a Rolling Stones concert.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIyODA3NDUzOV5BMl5BanBnXkFtZTcwOTgzNDA2NA@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2011, 3, 25, 0, 0),
#  'runtime': 109,
#  'title': 'White Irish Drinkers',
#  'tomatoes': {'critic': {'meter': 44, 'numReviews': 34, 'rating': 4.9},
#               'dvd': datetime.datetime(2011, 7, 12, 0, 0),
#               'fresh': 15,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 19, 12, 40),
#               'production': 'Screen Media Films',
#               'rotten': 19,
#               'viewer': {'meter': 71, 'numReviews': 2622, 'rating': 3.7},
#               'website': 'http://www.whiteirishdrinkersthemovie.com/'},
#  'type': 'movie',
#  'writers': ['John Gray'],
#  'year': 2010}
# {'_id': ObjectId('573a139af29313caabcf0858'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 1 Primetime Emmy. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Nathaniel Parker', 'Jonathan Pryce', 'Leonard Nimoy', 'Sheryl Lee'],
#  'countries': ['USA', 'Italy', 'Germany'],
#  'directors': ['Robert Markowitz'],
#  'fullplot': 'The tribes of Israel need to defeat the superior might of the '
#              'Philistines: "Now appoint a king to lead us, such as all the '
#              'other nations have." (I Samuel, 8:5). And so the prophet Samuel '
#              'gives the Hebrews their first king, Saul, a simple farmer, who '
#              "with God's help becomes a brave and mighty warlord who leads the "
#              'united tribes of Israel against their enemies. Saul, however, '
#              'has incessant doubts about his mission. Not trustful enough of '
#              'divine wisdom, he acts of his own accord and thus sins against '
#              'the Lord. The influential prophet Samuel turns away from Saul in '
#              "order to select a new king according to God's will: David. He is "
#              'still a young boy, tending sheep in the fields, when, secretly '
#              'Samuel oints him as the next king of the Israelites. When David '
#              '- as courageous as he is intelligent - emerges victorious from '
#              "his encounter with Goliath, the Philistines' most powerful "
#              'warrior, he becomes a hero. His fame arouses the jealousy of '
#              'King Saul, who senses that David is going to dispute his right '
#              'to be king - and tries to kill him. David flees from Saul, and '
#              'finds many supporters and loyal companions who believe that he '
#              'is destined to be king. In exile, David waits for his time to '
#              'come, since he does not want to take the place of Saul by '
#              'violence. He is young and in the prime of his strength, while '
#              'King Saul is a broken man. When Saul falls upon his sword after '
#              "losing a battle, David's hour is at hand. The new King David "
#              'conquers Jerusalem. The magnificent city is to become the royal '
#              'residence for the glorious hero, who now plans to leave the '
#              'business of war to others in future and to become a King of '
#              'Peace. However, this temperamental man, with so many years of '
#              'battle behind him and still in the bloom of youth, is not '
#              'predestined for a quiet, orderly life at all. Very soon he '
#              'plunges into an illicit love affair with Bathsheba, a married '
#              "woman - an affair that threatens to become the king's undoing "
#              'when it turns out that she is expecting his child. To conceal '
#              "his adulterous fatherhood, the king sends Bathsheba's husband "
#              'Uriah - one of his best and most loyal soldiers - to his death, '
#              'and then marries her. The prophet and royal adviser Nathan '
#              'announces to David that his act will result in divine '
#              'punishment: the Lord will not countenance such an outrage. '
#              "Violence and evil will continue in David's own family and bring "
#              'disaster upon the heads of the numerous sons born to David from '
#              'his wives and concubines. Then the child of David and Bathsheba '
#              'dies. She gives him another son, Solomon, but very soon David '
#              'suffers another sharp blow of fate: his grown-up son Absalom '
#              "kills one of his brothers for the latter's rape of his sister. "
#              'David is far too mild in response to this: not only does he fail '
#              'to bring the incestuous seducer to justice, he also leaves the '
#              'fratricide unpunished. The king does not realise that he is '
#              'gradually losing control over his family, and that his hold on '
#              'the people is also growing weaker. For David is obsessed with '
#              'his plan of building the finest and largest temple in the world '
#              'in Jerusalem. He demands immense sums from the populace for this '
#              'project, even though God has commanded him to leave the '
#              "completion of the building to his successors. David's ambitious "
#              'son Absalom thus finds it very easy to drum up support for a '
#              'conspiracy against his father. After a fierce battle, '
#              "culminating in Absalom's death, David makes it back to "
#              'Jerusalem.',
#  'genres': ['Adventure', 'Biography', 'Drama'],
#  'imdb': {'id': 118933, 'rating': 7.0, 'votes': 514},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:41:12.103000000',
#  'num_mflix_comments': 0,
#  'plot': 'The tribes of Israel need to defeat the superior might of the '
#          'Philistines: "Now appoint a king to lead us, such as all the other '
#          'nations have." (I Samuel, 8:5). And so the prophet Samuel ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2NkZDkzY2UtYmU5Yi00ZWI1LTk3ZDMtMzM5NGU4YmFhNGQ2XkEyXkFqcGdeQXVyNzMwOTY2NTI@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1997, 4, 6, 0, 0),
#  'runtime': 190,
#  'title': 'David',
#  'tomatoes': {'dvd': datetime.datetime(2002, 2, 4, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 19, 39, 36),
#               'production': 'Beta Films',
#               'viewer': {'meter': 80, 'numReviews': 582, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Larry Gross (teleplay)'],
#  'year': 1997}
# {'_id': ObjectId('573a13dff29313caabdb959c'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Matt Bomer', 'Stana Katic', 'John Noble', 'Molly C. Quinn'],
#  'countries': ['USA'],
#  'directors': ['James Tucker'],
#  'fullplot': 'Offering herself as a hostage, Lois Lane is caught in an aerial '
#              'confrontation between her terrorist captors and the '
#              'unpredictable Supergirl before Superman arrives to save the day. '
#              "Soon after, knowing Superman's civilian identity, Lois attempts "
#              'to get Clark Kent to make their relationship public despite his '
#              'fear of the consequences, but their argument is halted by a '
#              'Daily Planet staff meeting before Kent leaves when they are '
#              'being alerted to a meteor. Intercepting it, Superman learns the '
#              'meteor to be a robot and that he promptly defeats before '
#              'activating its beacon and taking it to the Fortress of Solitude. '
#              'With help from a fear-filled Supergirl, Superman learns the '
#              'robot is actually a drone controlled by a being named Brainiac, '
#              'a cyborg who was originally a Coluan scientist who subjected '
#              'himself to extensive cybernetic and genetic enhancements. As '
#              'Supergirl reveals from her experience with the monster, Brainiac '
#              "seized and miniaturized Krypton's capital city of Kandor prior "
#              "to the planet's destruction with her father and mother "
#              'attempting to track him down before they mysteriously lost '
#              'contact with Krypton. Fearing more drones would come, Superman '
#              'goes flying all through the galaxy in an attempt to track down '
#              'Brainiac before finding his drones attacking a planet. Though he '
#              'attempted to stop them, Superman witnesses Brainiac capture the '
#              "planet's capital like he did with Kandor before firing a Solar "
#              'Aggressor missile to have the planet be consumed by the '
#              'exploding sun. The explosion knocks Superman unconscious and he '
#              "is brought upon Brainiac's ship, coming to in the examination "
#              'room and fighting his way through the vessel before he discovers '
#              'a room full of bottled cities prior to being attacked by '
#              'Brainiac. At this point, confirming that he spared Krypton '
#              'because of its eventual destruction, Brainiac reveals that he '
#              'has been collecting information of all the planets he visited '
#              "before destroying them. Using Superman's spacecraft, Brainiac "
#              'decides to chart a course to Earth while sending Superman into '
#              'Kandor. Inside Kandor, his strength waning due to the artificial '
#              'red sun, Superman meets his uncle Zor-El and aunt Alura. After '
#              'spending time with them, Superman formulates a plan and escapes '
#              'Kandor using the subjugator robots. From there, Superman '
#              "disables Brainiac's ship and spirits Kandor to Earth. At that "
#              'time, Lois learns from Supergirl of why Superman left and alerts '
#              'the Pentagon for a possible invasion by Brainiac as he '
#              'eventually repaired his ship and arrives to Metropolis. Despite '
#              'everyone, including Supergirl, doing their best to fend his '
#              'drones off, Metropolis is encased in a bottle and both Superman '
#              'and Supergirl are captured. Having hooked Superman up to his '
#              'ship, revealing that Earth offers nothing to him, Brainiac '
#              'tortures Superman to obtain Kandor before destroying the planet. '
#              'However, telling his captor what Earth means to him, Superman '
#              'breaks free and then frees Supergirl and convinces her to stop '
#              "the Solar-Aggressor from hitting the sun. Remembering Zor-El's "
#              "words about Brainiac's ideals, Superman knocks him out of the "
#              'ship and they crash into a swamp. As he fights Braniac, Superman '
#              'forces the cyborg to experience the chaos of life itself outside '
#              'of his safe, artificial environments he created. Eventually, the '
#              'combined mental and physical strain reaches its toll on Brainiac '
#              'as he combusts and is reduced to ash and molten machinery. After '
#              'restoring Metropolis, taking Kandor to another planet to restore '
#              'it to its normal size to establish a Kryptonian colony, Superman '
#              'makes his love life with Lois as Kent public with a marriage '
#              'proposal. However, placed in the Fortress of Solitude, '
#              "Brainiac's remains are still active.",
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 2617456, 'rating': 6.6, 'votes': 6421},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:27:43.340000000',
#  'num_mflix_comments': 0,
#  'plot': 'Superman and Supergirl take on the cybernetic Brainiac, who boasts '
#          'that he possesses "the knowledge and strength of 10,000 worlds."',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTkzMjczODQzMV5BMl5BanBnXkFtZTcwOTIyOTQ0OQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 5, 23, 0, 0),
#  'runtime': 75,
#  'title': 'Superman: Unbound',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 4, 18, 27, 40),
#               'viewer': {'numReviews': 5, 'rating': 2.4}},
#  'type': 'movie',
#  'writers': ['Bob Goodman',
#              'Geoff Johns (graphic novel: "Superman: Brainiac")',
#              'Gary Frank (graphic novel: "Superman: Brainiac")',
#              'Jerry Siegel (creator)',
#              'Joe Shuster (creator)',
#              'Jerry Ordway (creator)',
#              'Tom Grummet (creator)'],
#  'year': 2013}

# %%
from os import wait
#2. Write a text search query to find movies where the word "war" appears in the title or plot, sorted by IMDb rating (Return only the top 5 results).
war_movies = collection.find({"$text": {"$search": "war"}})
for movie in war_movies:
    pprint.pprint(movie)
# Out:
# Streaming output truncated to the last 5000 lines.
#              'him, and by association Nora and Frank, rich and famous. Nora '
#              'literally shatters Tommy to his awakening, which ultimately '
#              "leads to both the family's rise and downfall as people initially "
#              "try to emulate Tommy's path then rebel against it.",
#  'genres': ['Musical'],
#  'imdb': {'id': 73812, 'rating': 6.6, 'votes': 14413},
#  'languages': ['English'],
#  'lastupdated': '2015-08-29 01:03:03',
#  'num_mflix_comments': 1,
#  'plot': 'A psychosomatically deaf, dumb and blind boy becomes a master '
#          'pinball player and the object of a religious cult because of that.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjlhZWMyNjItNWU5OS00NGQzLWI4YWYtYThjYjk3OTlmZDA5XkEyXkFqcGdeQXVyMzMyODMwMTI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1975, 3, 26, 0, 0),
#  'runtime': 111,
#  'title': 'Tommy',
#  'tomatoes': {'critic': {'meter': 76, 'numReviews': 25, 'rating': 6.8},
#               'dvd': datetime.datetime(1999, 9, 21, 0, 0),
#               'fresh': 19,
#               'lastUpdated': datetime.datetime(2015, 8, 19, 19, 16, 51),
#               'production': 'Sony Pictures',
#               'rotten': 6,
#               'viewer': {'meter': 72, 'numReviews': 30053, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Ken Russell (screenplay)',
#              'Pete Townshend (rock opera)',
#              'John Entwistle (additional material)',
#              'Keith Moon (additional material)'],
#  'year': 1975}
# {'_id': ObjectId('573a13caf29313caabd7dacf'),
#  'awards': {'nominations': 21, 'text': '8 wins & 21 nominations.', 'wins': 8},
#  'cast': ['Carlos Areces',
#           'Antonio de la Torre',
#           'Carolina Bang',
#           'Manuel Tallafè'],
#  'countries': ['Spain', 'France'],
#  'directors': ['èlex de la Iglesia'],
#  'fullplot': '1937, Spain is in the midst of the brutal Spanish Civil War. A '
#              '"Happy" circus clown is interrupted mid-performance and forcibly '
#              'recruited by a militia. Still in his costume, he is handed a '
#              'machete and led into battle against National soldiers, where he '
#              'single handedly massacres an entire platoon. Fast forward to '
#              '1973, the tail end of the Franco regime. Javier, the son of the '
#              "clown, dreams of following in his father's career footsteps, but "
#              "has seen too much tragedy in his life-he's simply not funny and "
#              'is only equipped to play the role of the Sad Clown. He finds '
#              'work in a circus where he befriends an outlandish cast of '
#              'characters, but as the Sad Clown he must take the abuse of the '
#              'brutish Happy Clown Sergio, who humiliates Javier daily in the '
#              'name of entertainment. It is here that he meets Natalia, a '
#              'gorgeous acrobat, and abused wife of Sergio. Javier falls deeply '
#              'in love with Natalia and tries to rescue her from her cruel and '
#              "violent husband, unleashing Sergio's jealousy. But Natalia is "
#              'torn between her affection towards Javier and her lust for '
#              'Sergio.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 1572491, 'rating': 6.5, 'votes': 9423},
#  'languages': ['Spanish'],
#  'lastupdated': '2015-09-13 00:16:04.653000000',
#  'metacritic': 70,
#  'num_mflix_comments': 1,
#  'plot': 'A young trapeze artist must decide between her lust for Sergio, the '
#          'Happy Clown, or her affection for Javier, the Sad Clown, both of '
#          'whom are deeply disturbed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZmY5MTI3ZGUtNzEzZi00ZGZmLWIzNjgtZWZjMDVmZDZhMTI5XkEyXkFqcGdeQXVyMjM3MDI4NDU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 12, 17, 0, 0),
#  'runtime': 107,
#  'title': 'The Last Circus',
#  'tomatoes': {'boxOffice': '$40.0k',
#               'consensus': 'The Last Circus is an uneven but winningly insane '
#                            'blend of hard violence, sex, black humor, and '
#                            'social satire.',
#               'critic': {'meter': 77, 'numReviews': 30, 'rating': 6.7},
#               'dvd': datetime.datetime(2011, 10, 18, 0, 0),
#               'fresh': 23,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 42, 39),
#               'production': 'Magnolia Pictures',
#               'rotten': 7,
#               'viewer': {'meter': 64, 'numReviews': 5725, 'rating': 3.5},
#               'website': 'http://www.thelastcircusmovie.com/'},
#  'type': 'movie',
#  'writers': ['èlex de la Iglesia'],
#  'year': 2010}
# {'_id': ObjectId('573a13bef29313caabd5cb7b'),
#  'awards': {'nominations': 4, 'text': '1 win & 4 nominations.', 'wins': 1},
#  'cast': ['Jackie Chan', 'Naoto Takenaka', 'Daniel Wu', 'Jinglei Xu'],
#  'countries': ['Hong Kong'],
#  'directors': ['Tung-Shing Yee'],
#  'fullplot': 'In China, the poor worker Tietou repairs tractors and misses his '
#              'sweetheart Xiu Xiu, back in Japan, she having never sent any '
#              'news to her family or him. While illegally emigrating to Japan, '
#              'Tietou loses his Chinese documents and so cannot return to his '
#              'country. He is welcomed by his countrymen who lodge and work in '
#              'Shinjuku where they also help him to find illegal work. While '
#              'running from a police raid through the sewage system where '
#              'Chinese are illegally working, Tietou saves Inspector Kitano '
#              'from drowning in the dirty water. Later, after an incident with '
#              'his cousin, Joe, and a Taiwan gang, Tietou saves the powerful '
#              'Yakuza boss Toshinari Eguchi. He is the husband of Xiu Xiu, who '
#              'is now called Yuko and are parents of a little daughter. The '
#              'mobster offers a dirty job to Tietou; in retribution, he '
#              'promises to deliver the quarter dominated by the Taiwan gang to '
#              'him. Tietou becomes the boss of the Chinese illegal immigrants. '
#              'But his peaceful methods make him unpopular and Tietou starts to '
#              'lose control over his men which escalates into a giant gang war.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 1075419, 'rating': 7.1, 'votes': 8686},
#  'languages': ['Mandarin',
#                'Japanese',
#                'Cantonese',
#                'English',
#                'Min Nan',
#                'Hokkien'],
#  'lastupdated': '2015-08-26 01:06:21.557000000',
#  'metacritic': 63,
#  'num_mflix_comments': 1,
#  'plot': 'A simple Chinese immigrant wages a perilous war against one of the '
#          'most powerful criminal organizations on the planet.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDExNjUxMjQyNl5BMl5BanBnXkFtZTcwMTU2MDQxMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2009, 4, 2, 0, 0),
#  'runtime': 119,
#  'title': 'Shinjuku Incident',
#  'tomatoes': {'critic': {'meter': 60, 'numReviews': 5, 'rating': 6.6},
#               'dvd': datetime.datetime(2010, 6, 8, 0, 0),
#               'fresh': 3,
#               'lastUpdated': datetime.datetime(2015, 8, 25, 18, 56, 19),
#               'production': 'Columbia Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 67, 'numReviews': 10733, 'rating': 3.4},
#               'website': 'http://shinjukuincident.emp.hk/en_main.html'},
#  'type': 'movie',
#  'writers': ['Tung-Shing Yee', 'Tin Nam Chun'],
#  'year': 2009}
# {'_id': ObjectId('573a13aff29313caabd2f26f'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Katariina Unt', 'Evald Aavik', 'Ivo Uukkivi', 'Jan Uuspèld'],
#  'countries': ['Estonia', 'Finland'],
#  'directors': ['Sulev Keedus'],
#  'fullplot': 'Autumn 1944, Estonia. Tens of thousands of people leave their '
#              'homeland in fear of approaching frontline. Some seashore '
#              'villages remain completely empty. A young woman with huge grey '
#              'eyes gets off the boat. Eetla leaves the last boat, thus giving '
#              'up her last chance to escape. Defying the cold wind and rain of '
#              'September, she returns to the lighthouse which is unexpected to '
#              "her father Gottfrid, the lighthouse keeper, and herself. Eetla's "
#              'return becomes her self-encounter and self-recognition. Why is '
#              'Eetla terrified of reality? For fear of tomorrow, anxiety for '
#              'the unpredictable tomorrow. Eetla seeks refuge in her dreams, '
#              'either dreamt or not dreamt ones, recounting them to her father '
#              'or to a young doctor, a war refugee Kasper, or herself. It does '
#              'not matter to whom. Reciting keeps alive the moment in between '
#              'what has passed and what will come, in between yesterday and '
#              'nescience. Like a prayer driven by fear to lose her balance. The '
#              'balance between being awake and asleep. This fear to yield is '
#              'Eetla\'s fear. "Somnambulance" is a psychological drama about '
#              'the fear of losing balance.',
#  'genres': ['Drama'],
#  'imdb': {'id': 385243, 'rating': 6.7, 'votes': 206},
#  'languages': ['Estonian', 'Russian'],
#  'lastupdated': '2015-08-15 01:00:48.363000000',
#  'num_mflix_comments': 0,
#  'plot': 'Autumn 1944, Estonia. Tens of thousands of people leave their '
#          'homeland in fear of approaching frontline. Some seashore villages '
#          'remain completely empty. A young woman with huge grey eyes ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU4MzE0MjIxN15BMl5BanBnXkFtZTcwMzMwMDM1MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2003, 9, 18, 0, 0),
#  'runtime': 129,
#  'title': 'Somnambulance',
#  'type': 'movie',
#  'writers': ['Sulev Keedus', 'Madis Kèiv'],
#  'year': 2003}
# {'_id': ObjectId('573a1396f29313caabce3acc'),
#  'awards': {'nominations': 2,
#             'text': 'Nominated for 2 Oscars. Another 7 wins & 2 nominations.',
#             'wins': 9},
#  'cast': ["Peter O'Toole", 'Petula Clark', 'Michael Redgrave', 'George Baker'],
#  'countries': ['USA'],
#  'directors': ['Herbert Ross'],
#  'fullplot': 'Arthur Chipping is an academic teaching at Brookfield Boys '
#              "School outside of London in the 1920's. Although he does what he "
#              "considers best for his students, they don't much like him, "
#              'nicknaming him "Ditchy", short for "dull as ditch water". His '
#              'life changes when he meets Katherine Bridges, a music hall '
#              'actress and a woman with a questionable past. She affectionately '
#              'calls him Mr. Chips. Despite their differences, they fall in '
#              'love. He in particular realizes that in striking a relationship, '
#              "they will have many obstacles to overcome. He doesn't "
#              'particularly like the world in which she is involved, including '
#              "her friends and her profession, and she doesn't exactly fit the "
#              "mold of a teacher's wife. Still, they decide to get married. She "
#              'forgoes her career to be Mrs. Chips, living on campus as the '
#              "housewife of a teacher at a proper boy's school. It is a world "
#              'in which she will have to learn the rules, or at least bend them '
#              'to her sensibilities, although she vows never to embarrass him. '
#              "Katherine's arrival at Brookfield may change Chips' standing at "
#              "the school. Further changes ensue for the Chips' and Brookfield "
#              'with the onset of World War II.',
#  'genres': ['Drama', 'Musical', 'Romance'],
#  'imdb': {'id': 64382, 'rating': 7.0, 'votes': 2234},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 01:05:56.833000000',
#  'num_mflix_comments': 0,
#  'plot': 'A shy, withdrawn English schoolteacher falls for a flashy showgirl.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTNhYzk5MzItZjI4Ni00ZTU5LWJmMTMtYTkzNDgxYjEzYzAxXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'G',
#  'released': datetime.datetime(1969, 12, 9, 0, 0),
#  'runtime': 155,
#  'title': 'Goodbye, Mr. Chips',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 5, 'rating': 7.0},
#               'dvd': datetime.datetime(2009, 1, 27, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 15, 8),
#               'production': 'MGM',
#               'rotten': 0,
#               'viewer': {'meter': 73, 'numReviews': 605, 'rating': 3.7}},
#  'type': 'movie',
#  'writers': ['James Hilton (novel)', 'Terence Rattigan (screenplay)'],
#  'year': 1969}
# {'_id': ObjectId('573a1394f29313caabce0951'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Kerwin Mathews', 'Kathryn Grant', 'Richard Eyer', 'Torin Thatcher'],
#  'countries': ['USA'],
#  'directors': ['Nathan Juran'],
#  'fullplot': 'While sailing with Princess Parisa to Baghdad to their wedding, '
#              'Sinbad finds the Colossa Island and anchors his vessel to get '
#              'supplies for the starving crew. Sinbad and his men help the '
#              'magician Sokurah to escape from a Cyclops that attacks them, and '
#              'Sokurah uses a magic lamp with a boy jinni to help them; '
#              'however, their boat sinks and he loses the lamp. Sokurah offers '
#              'a small fortune to Sinbad to return to Colossa, but he does not '
#              'accept and heads to Baghdad. The citizens and the Caliph of '
#              'Baghdad are celebrating the peace with Chandra, and they offer a '
#              'feast to the Sultan of Chandra. Sakurah requests a ship and crew '
#              'to return to Colossa but the Caliph refuses to jeopardize his '
#              'countrymen. However, the treacherous magician shrinks the '
#              'princess and when the desperate Sinbad seeks him out, he tells '
#              'that he needs to return to Colossa to get the ingredient '
#              'necessary for the magic potion. But Sinbad has only his friend '
#              'Harufa to travel with him, and he decides to enlist a doubtful '
#              'crew in the prison of Baghdad, in the beginning of his dangerous '
#              'voyage to Colossa to save the princess and avoid the eminent war '
#              'between Chandra and Baghdad.',
#  'genres': ['Family', 'Fantasy', 'Action'],
#  'imdb': {'id': 51337, 'rating': 7.2, 'votes': 7648},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:13:30.407000000',
#  'num_mflix_comments': 1,
#  'plot': 'When a princess is shrunken by an evil wizard, Sinbad must undertake '
#          'a quest to an island of monsters to cure her and prevent a war.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA0MzUzMjQ5MF5BMl5BanBnXkFtZTgwMDAxNzYzNTE@._V1._CR53,81,1259,1903_SX178_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1958, 12, 23, 0, 0),
#  'runtime': 88,
#  'title': 'The 7th Voyage of Sinbad',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 14, 'rating': 7.6},
#               'dvd': datetime.datetime(2000, 11, 7, 0, 0),
#               'fresh': 14,
#               'lastUpdated': datetime.datetime(2015, 8, 24, 19, 12, 13),
#               'production': 'Sony Pictures Home Entertainment',
#               'rotten': 0,
#               'viewer': {'meter': 77, 'numReviews': 8631, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Ken Kolb'],
#  'year': 1958}
# {'_id': ObjectId('573a1394f29313caabcdfbd0'),
#  'awards': {'nominations': 6,
#             'text': 'Nominated for 4 Oscars. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Glenn Ford', 'Anne Francis', 'Louis Calhern', 'Margaret Hayes'],
#  'countries': ['USA'],
#  'directors': ['Richard Brooks'],
#  'fullplot': 'War veteran Rick Dadier is one of three new teachers hired at '
#              'North Manual High School, an inner city boys school. This is his '
#              'first teaching assignment, which he needs to support himself and '
#              "his insecure pregnant wife, Anne. Despite Principle Warnecke's "
#              'assertions to the contrary, Dadier quickly learns that the '
#              'rumors of student discipline problems at the school are indeed '
#              'true. The established teachers at the school try to counsel the '
#              'newcomers, all inexperienced in such situations, as how best to '
#              'handle the rowdy students. Regardless, Dadier tries to exert '
#              'discipline in his class, which provokes a violent response. '
#              'Dadier believes the student leaders against him are Artie West, '
#              'but more specifically Gregory Miller, who he thinks uses the '
#              'fact of being black as a means of racial provocation. Dadier has '
#              'to decide either to leave and teach at a "real" school, or stay '
#              'and figure out how to get through to his students. If he decides '
#              'to stay, he has to figure out who the real disruptive influences '
#              'are, especially as they have resorted to attacks of a personal '
#              'nature that affect especially Anne.',
#  'genres': ['Drama'],
#  'imdb': {'id': 47885, 'rating': 7.4, 'votes': 5978},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:44:26.053000000',
#  'num_mflix_comments': 0,
#  'plot': 'A new English teacher at a violent, unruly inner-city school is '
#          'determined to do his job, despite resistance from both students and '
#          'faculty.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDRhOTM5ZDgtNWQ3ZS00NWI4LTkxM2ItOWZkNTIxMTFlM2NlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1955, 3, 25, 0, 0),
#  'runtime': 101,
#  'title': 'Blackboard Jungle',
#  'tomatoes': {'critic': {'meter': 76, 'numReviews': 21, 'rating': 7.1},
#               'dvd': datetime.datetime(2005, 5, 10, 0, 0),
#               'fresh': 16,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 5, 49),
#               'production': 'MGM Home Entertainment',
#               'rotten': 5,
#               'viewer': {'meter': 77, 'numReviews': 3633, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Richard Brooks (screenplay)', 'Evan Hunter (novel)'],
#  'year': 1955}
# {'_id': ObjectId('573a13aaf29313caabd21d5c'),
#  'awards': {'nominations': 2, 'text': '2 wins & 2 nominations.', 'wins': 2},
#  'cast': ['Clayton Watson', 'Akio ètsuka', 'Pamela Adlon', 'Hedy Burress'],
#  'countries': ['USA', 'Japan'],
#  'directors': ['Peter Chung',
#                'Andrew R. Jones',
#                'Yoshiaki Kawajiri',
#                'Takeshi Koike',
#                'Mahiro Maeda',
#                'Kèji Morimoto',
#                'Shinichirè Watanabe'],
#  'fullplot': 'Anthology of nine short anime (Japanese animation) films tied in '
#              'to the 1999 blockbuster "The Matrix" and its sequels. "Final '
#              'Flight of the Osiris": The crew of the hovercraft Osiris attempt '
#              'to warn their city of an imminent attack. "The Second '
#              'Renaissance, Parts 1 & 2": The story behind the war between man '
#              'and the machines, how mankind scorched the sky, and the creation '
#              'of the Matrix. "Kid\'s Story": A teenager is contacted by Neo, '
#              'and manages to escape the Matrix. "Program": Two warriors battle '
#              'in a samurai training simulation when one decides to betray his '
#              'crewmates and re-enter the Matrix. "World Record": A champion '
#              'sprinter manages to break free of the Matrix by sheer physical '
#              'effort during a record attempt. "Beyond": A young girl searching '
#              'for her cat discovers a haunted house caused by a glitch in the '
#              'system. "A Detective Story": Private investigator Ash tracks a '
#              'hacker named Trinity through the looking glass. "Matriculated": '
#              'A group of humans capture a machine scout and insert it into a '
#              "'human matrix'.",
#  'genres': ['Animation', 'Action', 'Adventure'],
#  'imdb': {'id': 328832, 'rating': 7.4, 'votes': 57929},
#  'languages': ['English', 'Japanese'],
#  'lastupdated': '2015-09-17 02:11:51.513000000',
#  'num_mflix_comments': 0,
#  'plot': 'The Animatrix is a collection of several animated short films, '
#          'detailing the backstory of the "Matrix" universe, and the original '
#          'war between man and machines which led to the creation of the '
#          'Matrix.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDEwMGYxNjEtNTE3ZC00Zjg3LThlODMtODVhNzBiMTQ3NGI5XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2003, 6, 3, 0, 0),
#  'runtime': 102,
#  'title': 'The Animatrix',
#  'tomatoes': {'critic': {'meter': 88, 'numReviews': 17, 'rating': 6.7},
#               'dvd': datetime.datetime(2003, 6, 3, 0, 0),
#               'fresh': 15,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 44),
#               'production': 'Warner Home Video',
#               'rotten': 2,
#               'viewer': {'meter': 78, 'numReviews': 120577, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Andy Wachowski (screenplay)',
#              'Lana Wachowski (screenplay)',
#              'Andy Wachowski',
#              'Lana Wachowski',
#              'Yoshiaki Kawajiri',
#              'Kèji Morimoto',
#              'Shinichirè Watanabe',
#              'Peter Chung'],
#  'year': 2003}
# {'_id': ObjectId('573a1394f29313caabcde7cc'),
#  'awards': {'nominations': 2,
#             'text': 'Nominated for 1 Oscar. Another 3 wins & 2 nominations.',
#             'wins': 4},
#  'cast': ['Marlon Brando', 'Teresa Wright', 'Everett Sloane', 'Jack Webb'],
#  'countries': ['USA'],
#  'directors': ['Fred Zinnemann'],
#  'fullplot': 'Ex-GI Ken who as a result of a war wound is paralyzed below the '
#              'waist. In the hospital back home, he passes through an initial '
#              'period of depression with the help of a sympathetic Dr. Brock '
#              "and his faithful fiancèe Ellen. Ken's bitter isolation is also "
#              'overcome with the help of his fellow patients, especially the '
#              'intelligent young cynic Norm, the witty Leo and serious young '
#              'Angel. Soon Ken throws himself into the work rehabilitation and '
#              'after a long period of physical therapy even suspects he may '
#              'regain the use of his limbs. With the approval and help of the '
#              'doctor, he and Ellen marry, but on their wedding night both have '
#              "misgivings about the marriage: the full realization of Ellen's "
#              'new responsibilities frighten her and makes her more uncertain '
#              'than ever, and Ken reverts to self-pity. There is a violent '
#              'argument, and he goes back to the hospital. But his blazing '
#              'anger finds no sympathy from his buddies, and after a surprising '
#              'conversation with Dr. Brock, Ken realizes that he must return to '
#              'his wife, with whom he must try to build his new life, in spite '
#              'of all the attendant difficulties.',
#  'genres': ['Drama'],
#  'imdb': {'id': 42727, 'rating': 7.2, 'votes': 3082},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-09-02 00:13:03.710000000',
#  'num_mflix_comments': 0,
#  'plot': 'Paralized war vet tries to adjust to the world without the use of '
#          'his limbs.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGM1NDI3MGUtMWMxYS00OTQ4LWFiNWMtMTgxY2E4MTUzYTQ4XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 9, 1, 0, 0),
#  'runtime': 85,
#  'title': 'The Men',
#  'tomatoes': {'critic': {'meter': 70, 'numReviews': 10, 'rating': 7.0},
#               'dvd': datetime.datetime(2003, 12, 16, 0, 0),
#               'fresh': 7,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 21, 33, 47),
#               'production': 'Columbia Pictures',
#               'rotten': 3,
#               'viewer': {'meter': 75, 'numReviews': 1405, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Carl Foreman (story)', 'Carl Foreman (screenplay)'],
#  'year': 1950}
# {'_id': ObjectId('573a13abf29313caabd24610'),
#  'awards': {'nominations': 2, 'text': '5 wins & 2 nominations.', 'wins': 5},
#  'cast': ['Bora Todorovic',
#           'Branislav Lecic',
#           'Natasa Ninkovic',
#           'Dragan Jovanovic'],
#  'countries': ['Serbia and Montenegro'],
#  'directors': ['Dusan Kovacevic'],
#  'fullplot': 'Till recently an University professor, a bohemian writer, a '
#              "member of Belgrade's intellectual circles and a passionate "
#              "opponent of the Milosevic's regime, TEJA is today a manager of a "
#              'big publishing house. One day a strange visitor comes uninvited '
#              'to his office, carrying a big suitcase. That man is LUKA, a '
#              'former agent of the Serbian Security Service, now a taxi driver. '
#              'Suddenly a surprising confrontation of these two men begins, '
#              'which is full of incredible twists. As we get to know LUKA, we '
#              'find that his mission for the last ten years was to daily shadow '
#              'TEJA, to write reports on his behavior and acts, to watch on him '
#              'even in the most intimate moments of his life. Gradually the '
#              'last ten years of their lives begin to appear, the lives of '
#              'these two men with quite different destinies. We see before us '
#              'the chronicle of an age from the most incredible situations, '
#              'often touching, sometimes irresistibly funny, to the most tragic '
#              'events and the darkest war stories in the history of one '
#              "nation's struggle in the end of the 20th century.",
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 339535, 'rating': 8.3, 'votes': 3780},
#  'languages': ['Serbian'],
#  'lastupdated': '2015-08-24 00:33:25.243000000',
#  'num_mflix_comments': 0,
#  'plot': 'Till recently an University professor, a bohemian writer, a member '
#          "of Belgrade's intellectual circles and a passionate opponent of the "
#          "Milosevic's regime, TEJA is today a manager of a big ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2ODE3MzMwOV5BMl5BanBnXkFtZTcwMzY2NDQyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2003, 5, 21, 0, 0),
#  'runtime': 104,
#  'title': 'The Professional',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 55, 22),
#               'viewer': {'numReviews': 241, 'rating': 4.4}},
#  'type': 'movie',
#  'writers': ['Dusan Kovacevic (play)', 'Dusan Kovacevic (screenplay)'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0f4a'),
#  'awards': {'nominations': 4, 'text': '12 wins & 4 nominations.', 'wins': 12},
#  'cast': ['Elina Hurme', 'Tiina Weckstrèm', 'Elena Leeve', 'Elsa Saisio'],
#  'countries': ['Finland', 'Sweden'],
#  'directors': ['Pirjo Honkasalo'],
#  'fullplot': 'The twin sisters Helena and Irene are born in Helsinki during '
#              'World War II. A few months later their mother, Sirkka, leaves '
#              'the girls in the care of their grandmother, an old communist, '
#              'and runs away with a German soldier. Their life under the '
#              'protection of their grandmother and the teachings of communism '
#              'ends first with the death of Stalin, then with that of their '
#              'grandmother. The girls are eight years old when they are put in '
#              'an orphanage. Their mother shows up at the orphanage in the '
#              'company of Ramon, a Spanish trapeze artist. They are on a talent '
#              'search for a German circus. Ramon trains the reluctant Irene '
#              'during circus tours in Central Europe. She becomes the trapeze '
#              'star of the circus. The hard work soon exhausts Irene and she '
#              'falls from height, as if on purpose. Helena has secretly learned '
#              'the art of fire-eating. Now she is burdened with both her mother '
#              'and her sister. The violent life, however, separates the three '
#              'from each other. In the present-day Helsinki the middle-aged '
#              'Helena has looked into her past, ceased to hate and now, for the '
#              'first time in her life, voluntarily accepts responsibility for '
#              'another human being.',
#  'genres': ['Drama'],
#  'imdb': {'id': 120872, 'rating': 6.8, 'votes': 249},
#  'languages': ['Finnish', 'German', 'Russian', 'Spanish'],
#  'lastupdated': '2015-07-27 00:20:20.043000000',
#  'num_mflix_comments': 0,
#  'plot': 'The twin sisters Helena and Irene are born in Helsinki during World '
#          'War II. A few months later their mother, Sirkka, leaves the girls in '
#          'the care of their grandmother, an old communist, and...',
#  'released': datetime.datetime(1998, 10, 30, 0, 0),
#  'runtime': 100,
#  'title': 'Fire-Eater',
#  'tomatoes': {'critic': {'meter': 27, 'numReviews': 33, 'rating': 5.0},
#               'dvd': datetime.datetime(1998, 7, 21, 0, 0),
#               'fresh': 9,
#               'lastUpdated': datetime.datetime(2015, 8, 25, 18, 18, 46),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 54, 'numReviews': 90337, 'rating': 3.2}},
#  'type': 'movie',
#  'writers': ['Pirkko Saisio'],
#  'year': 1998}
# {'_id': ObjectId('573a13f1f29313caabddc613'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Steven Waddington',
#           'Siennah Buck',
#           'Mike Colter',
#           'Christian Contreras'],
#  'fullplot': 'In the 28th Century, the prolonged war between humanity and the '
#              'fanatical alien alliance the Covenant has ended with a tenuous '
#              "treaty. Despite the ceasefire, Earth's outer colonies remain "
#              "vulnerable to the Covenant's covert intrusions. The ONI - Office "
#              'of Naval Intelligence has been tasked with counterintelligence '
#              'to beat the Covenant. In Planet Sedra, Commander Jameson Locke '
#              "and his team witness a Covenant's spacecraft and a Zealot Elite "
#              'warrior disembarks with a bomb. They unsuccessfully try to stop '
#              'the alien that explodes the bomb in a mall. They realize that it '
#              'is a biological attack with an element fatal to humans. Sedran '
#              'Commander Aiken captures the middleman Axl that tells that the '
#              'element is obtained from Alpha Halo, where the day longs 16 h '
#              'and the temperature in the sunlight reaches 482o C. Aiken, Locke '
#              'and his team head to Halo in the spacecraft Condor with pilot '
#              'Macer carrying a Havoc weapon to destroy the place. On the '
#              'arrival, they find two terrorists but are trapped in Halo by '
#              'weird worms that are attracted by technology. And in five hours '
#              'the sun will rise.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 3804114, 'rating': 5.7, 'votes': 2640},
#  'languages': ['English'],
#  'lastupdated': '2015-08-20 00:40:26.313000000',
#  'num_mflix_comments': 0,
#  'plot': 'While investigating terrorist activity on the distant colony world '
#          'of Sedra, Jameson Locke and his team are caught in a horrific '
#          'biological attack that exposes them to a much deeper danger.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2NTQwNzU2OV5BMl5BanBnXkFtZTgwNzkxOTQ0MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 11, 11, 0, 0),
#  'runtime': 30,
#  'title': 'Halo: Nightfall',
#  'type': 'series',
#  'year': '2014è'}
# {'_id': ObjectId('573a13e6f29313caabdc4b4a'),
#  'awards': {'nominations': 4, 'text': '3 wins & 4 nominations.', 'wins': 3},
#  'cast': ['Ronald Zehrfeld',
#           'Mohsin Ahmady',
#           'Saida Barmaki',
#           'Salam Yousefzai'],
#  'countries': ['Germany'],
#  'directors': ['Feo Aladag'],
#  'fullplot': 'Jesper is a soldier in the German army. Although his brother was '
#              'killed whilst serving in Afghanistan, he nevertheless reports '
#              'for a new tour of duty in this war zone. He and his unit are to '
#              'protect a remote village from the Taliban. One of the people '
#              'accompanying Jesper is a young interpreter, Tarik, whose job '
#              'includes mediating between soldiers and villagers. Both sides '
#              'have a hard time trying to overcome the differences in their '
#              'respective ways of life. Jesper must gain the trust of both '
#              'villagers and the allied Arbaki militia and his nerves are soon '
#              'on edge. He finds himself increasingly morally conflicted as a '
#              "result of his superiors' orders. His association with the "
#              "Germans means Tarik's life is constantly under threat, but when "
#              "Tarik begins to fear for his sister's safety, Jesper has to make "
#              'a decision. Feo Aladag uses this portrait of an ISAF soldier in '
#              'Afghanistan to explore questions of affinity and otherness, '
#              'trust and failure. How humane can your actions be if you are '
#              'bound by the workings of a strict military bureaucracy? What '
#              'remains of the ideals of human dignity when you are caught up in '
#              'a daily struggle for survival?',
#  'genres': ['Drama'],
#  'imdb': {'id': 3032028, 'rating': 6.3, 'votes': 313},
#  'languages': ['German', 'English', 'Pushto', 'Dari'],
#  'lastupdated': '2015-08-26 00:37:41.337000000',
#  'num_mflix_comments': 1,
#  'plot': 'Jesper is a soldier in the German army. Although his brother was '
#          'killed whilst serving in Afghanistan, he nevertheless reports for a '
#          'new tour of duty in this war zone. He and his unit are ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzM1MzEzNTkyMF5BMl5BanBnXkFtZTgwNDQ0NTM1MTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 3, 27, 0, 0),
#  'runtime': 98,
#  'title': 'Inbetween Worlds',
#  'tomatoes': {'dvd': datetime.datetime(2015, 11, 2, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 18, 49, 48),
#               'production': 'Vertical Entertainment',
#               'viewer': {'numReviews': 41, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Feo Aladag (screenplay)',
#              'Matthias Kock (screenplay)',
#              'Judith Kaufmann (screenplay)'],
#  'year': 2014}
# {'_id': ObjectId('573a13bdf29313caabd5950a'),
#  'awards': {'nominations': 11, 'text': '11 nominations.', 'wins': 0},
#  'cast': ['Logan Lerman',
#           'Brandon T. Jackson',
#           'Alexandra Daddario',
#           'Jake Abel'],
#  'countries': ['Canada', 'USA', 'UK'],
#  'directors': ['Chris Columbus'],
#  'fullplot': "When his lightning bolt is stolen, Zeus accuses Poseidon's son "
#              "Percy Jackson and gives Poseidon's son fourteen days to return "
#              'it, otherwise he will initiate a war amongst the gods. Meanwhile '
#              'the teenager, Percy, who is dyslexic and has ADHD is visiting '
#              'The Museum of Metropolitan of Art and is attacked by a Fury '
#              'disguised in his teacher. His physically handicapped best friend '
#              'Grover reveals that Percy is a demigod and that he is his '
#              'protector and his teacher Mr Brunner gives him a pen telling him '
#              "that it is a powerful weapon. They go to Percy's house and "
#              'together with his mother Sally they drive to the Camp '
#              'Half-Blood. However Sally is attacked by a Minotaur and vanishes '
#              'before Percy can help her. In the camp, Percy befriends the '
#              'gorgeous Annabeth; when they are attacked by Hades who wants the '
#              'lighting bolt for himself, Percy discovers that his mother is in '
#              'the Underworld with Hades. Percy decides to travel on a '
#              'dangerous quest to retrieve the lightning bolt and save his '
#              'mother. Grover and Annabeth join him and Luke gives a powerful '
#              'shield of his own to protect Percy. Will they be able to '
#              'succeed?',
#  'genres': ['Adventure', 'Family', 'Fantasy'],
#  'imdb': {'id': 814255, 'rating': 5.9, 'votes': 129728},
#  'languages': ['English', 'Greek', ' Ancient (to 1453)'],
#  'lastupdated': '2015-09-02 10:12:01.383000000',
#  'metacritic': 47,
#  'num_mflix_comments': 0,
#  'plot': "A teenager discovers he's the descendant of a Greek god and sets out "
#          'on an adventure to settle an on-going battle between the gods.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5NDlmZWUtMjIyMC00NzQ3LTg3OWYtMzRkY2FiNzQ0Njc4XkEyXkFqcGdeQXVyNDQ2MTMzODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2010, 2, 12, 0, 0),
#  'runtime': 118,
#  'title': 'Percy Jackson & the Olympians: The Lightning Thief',
#  'tomatoes': {'boxOffice': '$86.7M',
#               'consensus': 'Though it may seem like just another Harry Potter '
#                            'knockoff, Percy Jackson benefits from a strong '
#                            'supporting cast, a speedy plot, and plenty of fun '
#                            'with Greek mythology.',
#               'critic': {'meter': 49, 'numReviews': 143, 'rating': 5.3},
#               'dvd': datetime.datetime(2010, 6, 29, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 18, 57, 29),
#               'production': '20th Century Fox',
#               'rotten': 73,
#               'viewer': {'meter': 53, 'numReviews': 252943, 'rating': 3.3},
#               'website': 'http://www.percyjacksonthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Craig Titley (screenplay)', 'Rick Riordan (novel)'],
#  'year': 2010}
# {'_id': ObjectId('573a13b8f29313caabd4d944'),
#  'awards': {'nominations': 11, 'text': '11 nominations.', 'wins': 0},
#  'cast': ['Logan Lerman',
#           'Brandon T. Jackson',
#           'Alexandra Daddario',
#           'Jake Abel'],
#  'countries': ['Canada', 'USA', 'UK'],
#  'directors': ['Chris Columbus'],
#  'fullplot': "When his lightning bolt is stolen, Zeus accuses Poseidon's son "
#              "Percy Jackson and gives Poseidon's son fourteen days to return "
#              'it, otherwise he will initiate a war amongst the gods. Meanwhile '
#              'the teenager, Percy, who is dyslexic and has ADHD is visiting '
#              'The Museum of Metropolitan of Art and is attacked by a Fury '
#              'disguised in his teacher. His physically handicapped best friend '
#              'Grover reveals that Percy is a demigod and that he is his '
#              'protector and his teacher Mr Brunner gives him a pen telling him '
#              "that it is a powerful weapon. They go to Percy's house and "
#              'together with his mother Sally they drive to the Camp '
#              'Half-Blood. However Sally is attacked by a Minotaur and vanishes '
#              'before Percy can help her. In the camp, Percy befriends the '
#              'gorgeous Annabeth; when they are attacked by Hades who wants the '
#              'lighting bolt for himself, Percy discovers that his mother is in '
#              'the Underworld with Hades. Percy decides to travel on a '
#              'dangerous quest to retrieve the lightning bolt and save his '
#              'mother. Grover and Annabeth join him and Luke gives a powerful '
#              'shield of his own to protect Percy. Will they be able to '
#              'succeed?',
#  'genres': ['Adventure', 'Family', 'Fantasy'],
#  'imdb': {'id': 814255, 'rating': 5.9, 'votes': 129708},
#  'languages': ['English', 'Greek', ' Ancient (to 1453)'],
#  'lastupdated': '2015-09-02 00:06:37.553000000',
#  'metacritic': 47,
#  'num_mflix_comments': 0,
#  'plot': "A teenager discovers he's the descendant of a Greek god and sets out "
#          'on an adventure to settle an on-going battle between the gods.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ5NDlmZWUtMjIyMC00NzQ3LTg3OWYtMzRkY2FiNzQ0Njc4XkEyXkFqcGdeQXVyNDQ2MTMzODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2010, 2, 12, 0, 0),
#  'runtime': 118,
#  'title': 'Percy Jackson & the Olympians: The Lightning Thief',
#  'tomatoes': {'boxOffice': '$86.7M',
#               'consensus': 'Though it may seem like just another Harry Potter '
#                            'knockoff, Percy Jackson benefits from a strong '
#                            'supporting cast, a speedy plot, and plenty of fun '
#                            'with Greek mythology.',
#               'critic': {'meter': 49, 'numReviews': 143, 'rating': 5.3},
#               'dvd': datetime.datetime(2010, 6, 29, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 18, 57, 29),
#               'production': '20th Century Fox',
#               'rotten': 73,
#               'viewer': {'meter': 53, 'numReviews': 252943, 'rating': 3.3},
#               'website': 'http://www.percyjacksonthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Craig Titley (screenplay)', 'Rick Riordan (novel)'],
#  'year': 2010}
# {'_id': ObjectId('573a13aef29313caabd2d743'),
#  'awards': {'nominations': 24, 'text': '13 wins & 24 nominations.', 'wins': 13},
#  'cast': ['Saif Ali Khan', 'Rani Mukerji', 'Kiron Kher', 'Rati Agnihotri'],
#  'countries': ['India'],
#  'directors': ['Kunal Kohli'],
#  'fullplot': 'Karan Kapoor and Rhea Prakash meet for the first time in a '
#              'flight bound from Delhi to New York. They just cannot stand each '
#              "other: Rhea is disgusted by Karan's flirtatious mannerisms and "
#              "Karan is frustrated because of Rhea's overt seriousness. They "
#              'have a massive fallout and part ways, vowing never to see each '
#              "other's face again. Destiny brings them together again at Rhea's "
#              'marriage ceremony three years later and the mars vs. venus war '
#              'continues. Rhea gets married and leaves for USA. Four years '
#              'later, Karan has become a successful cartoonist and travels to '
#              'Paris to visit his father. Co-incidentally he meets Rhea again '
#              'and learns that her husband is no more. Karan tries earnestly to '
#              "bring happiness back in Rhea's life by promising her mother that "
#              'he will find a suitable groom for Rhea but the duo never '
#              'realizes that they are drawing closer to each other. Will love '
#              'happen? And if it does, will the star-struck couple ever admit '
#              'to it? Watch the breezy romantic musical comedy Hum Tum for the '
#              'answers.',
#  'genres': ['Drama', 'Romance', 'Comedy'],
#  'imdb': {'id': 378072, 'rating': 7.1, 'votes': 8471},
#  'languages': ['Hindi', 'English'],
#  'lastupdated': '2015-08-20 00:24:55.483000000',
#  'num_mflix_comments': 0,
#  'plot': 'Karan Kapoor and Rhea Prakash meet for the first time in a flight '
#          'bound from Delhi to New York. They just cannot stand each other: '
#          "Rhea is disgusted by Karan's flirtatious mannerisms and ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjhkMTdjMTEtZWFkOC00OWQ4LWI4ODYtYjFlYTVlOTk3OTU2XkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2004, 5, 28, 0, 0),
#  'runtime': 142,
#  'title': 'Hum Tum',
#  'type': 'movie',
#  'writers': ['Siddharth Anand (screenplay)', 'Kunal Kohli'],
#  'year': 2004}
# {'_id': ObjectId('573a13aaf29313caabd21193'),
#  'awards': {'nominations': 44,
#             'text': 'Nominated for 4 Oscars. Another 20 wins & 44 nominations.',
#             'wins': 24},
#  'cast': ['Ken Watanabe', 'Tom Cruise', 'William Atherton', 'Chad Lindberg'],
#  'countries': ['USA', 'New Zealand', 'Japan'],
#  'directors': ['Edward Zwick'],
#  'fullplot': 'In the 1870s, Captain Nathan Algren, a cynical veteran of the '
#              'American Civil war who will work for anyone, is hired by '
#              'Americans who want lucrative contracts with the Emperor of Japan '
#              'to train the peasant conscripts for the first standing imperial '
#              'army in modern warfare using firearms. The imperial Omura '
#              "cabinet's first priority is to repress a rebellion of "
#              'traditionalist Samurai -hereditary warriors- who remain devoted '
#              'to the sacred dynasty but reject the Westernizing policy and '
#              'even refuse firearms. Yet when his ill-prepared superior force '
#              'sets out too soon, their panic allows the sword-wielding samurai '
#              "to crush them. Badly wounded Algren's courageous stand makes the "
#              'samurai leader Katsumoto spare his life; once nursed to health '
#              'he learns to know and respect the old Japanese way, and '
#              "participates as advisor in Katsumoto's failed attempt to save "
#              'the Bushido tradition, but Omura gets repressive laws enacted- '
#              'he must now choose to honor his loyalty to one of the embittered '
#              'sides when the conflict returns to the battlefield...',
#  'genres': ['Action', 'Drama', 'History'],
#  'imdb': {'id': 325710, 'rating': 7.7, 'votes': 292651},
#  'languages': ['English', 'Japanese'],
#  'lastupdated': '2015-09-05 00:58:24.977000000',
#  'metacritic': 55,
#  'num_mflix_comments': 0,
#  'plot': 'An American military advisor embraces the Samurai culture he was '
#          'hired to destroy after he is captured in battle.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzkyNzQ1Mzc0NV5BMl5BanBnXkFtZTcwODg3MzUzMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 12, 5, 0, 0),
#  'runtime': 154,
#  'title': 'The Last Samurai',
#  'tomatoes': {'boxOffice': '$111.1M',
#               'consensus': 'With high production values and thrilling battle '
#                            'scenes, The Last Samurai is a satisfying epic.',
#               'critic': {'meter': 65, 'numReviews': 216, 'rating': 6.4},
#               'dvd': datetime.datetime(2004, 5, 4, 0, 0),
#               'fresh': 141,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 1, 30),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 75,
#               'viewer': {'meter': 83, 'numReviews': 390384, 'rating': 3.7},
#               'website': 'http://lastsamurai.warnerbros.com/html_index.php'},
#  'type': 'movie',
#  'writers': ['John Logan (story)',
#              'John Logan (screenplay)',
#              'Edward Zwick (screenplay)',
#              'Marshall Herskovitz (screenplay)'],
#  'year': 2003}
# {'_id': ObjectId('573a13baf29313caabd51c77'),
#  'awards': {'nominations': 4, 'text': '1 win & 4 nominations.', 'wins': 1},
#  'cast': ['Amy Poehler', 'Tina Fey', 'Greg Kinnear', 'Dax Shepard'],
#  'countries': ['USA'],
#  'directors': ['Michael McCullers'],
#  'fullplot': 'Successful and single businesswoman Kate Holbrook has long put '
#              "her career ahead of a personal life. Now 37, she's finally "
#              'determined to have a kid on her own. But her plan is thrown a '
#              'curve ball after she discovers she has only a million-to-one '
#              'chance of getting pregnant. Undaunted, the driven Kate allows '
#              'South Philly working girl Angie Ostrowiski to become her '
#              'unlikely surrogate. Simple enough ... After learning from the '
#              'steely head of their surrogacy center that Angie is pregnant, '
#              'Kate goes into precision nesting mode: reading childcare books, '
#              'baby-proofing the apartment and researching top pre-schools. But '
#              "the executive's well-organized strategy is turned upside down "
#              'when her Baby Mama shows up at her doorstep with no place to '
#              'live. An unstoppable force meets an immovable object as '
#              'structured Kate tries to turn vibrant Angie into the perfect '
#              'expectant mom. In a battle of wills, they will struggle their '
# ...
#              'first half of the 20th century. An outstanding student with a '
#              'magnetic personality, he dreams of becoming an actor. When his '
#              'homeland is invaded by the Nazis in 1939, he and his friends '
#              'secretly oppose the systematic persecution of their Polish '
#              'culture. But, with the death of his father and the lacerating '
#              "solitude which accompanies this loss, Karol's personal "
#              '"resistance" takes on a new form and he decides to follow a '
#              'priestly vocation. At the end of the war, Poland falls into the '
#              'grip of Soviet totalitarianism. The newly ordained Karol is '
#              'constantly surrounded by young people whom he teaches to '
#              'safeguard and defend human dignity. He could be considered a '
#              'serious threat to the regime, but the Communist authorities '
#              'merely see him as an innocuous intellectual and even encourage '
#              'his nomination for the position of bishop. Karol Wojtila is the '
#              'youngest bishop in the history of Poland. When he is appointed '
#              'Cardinal, Karol is more intransigent in the spiritual guidance '
#              'of his homeland, becoming a real and proper thorn in the side of '
#              'the Communist government. And the whole Catholic world begins to '
#              'wonder who he is. On the death of Pope John Paul I in 1978, the '
#              'cardinals of the Conclave decide that Woytjla is the right man '
#              'to lead replace him. Thus Karol leaves his beloved Poland to '
#              'become Pope John Paul II. His free, unconventional attitude '
#              'alarms several prelates, but immediately wins the hearts of the '
#              'people. In a age paralyzed by fear and ideology, the new Pope '
#              'shows everybody again the overwhelming fascination of '
#              'Christianity: this is the beginning of a deep change, which will '
#              'affect the whole world and the Church itself, as a sort of '
#              '"contagion". He miraculously survives an attempt on his life in '
#              '1981, and not even this event curbs his mission. Thanks to his '
#              'unshakable tenacity , Pope John Paul II helps to change the '
#              'course of history: the fall of the Berlin Wall in 1989 decrees '
#              'the collapse of Communism. But the Pope does not stop being the '
#              'voice of Christ, even among the injustices of the capitalistic '
#              'Western world, even among the provocations and challenges of '
#              'modern times . The Great Jubilee of 2000 is the most moving '
#              'evidence of his mission: 3 million young people in love with the '
#              "Pope gather in Rome, bringing with them the whole world's hopes. "
#              'This world has learned to look to him, now old and shaky, as a '
#              'ray of light in the heart of darkness.',
#  'genres': ['Biography', 'Drama'],
#  'imdb': {'id': 475999, 'rating': 7.1, 'votes': 949},
#  'languages': ['English'],
#  'lastupdated': '2015-08-12 01:01:08.487000000',
#  'num_mflix_comments': 0,
#  'plot': 'Following the premature death of his mother, Karol Wojtyla is '
#          'brought up by his father in the Polish city of Krakow during the '
#          'first half of the 20th century. An outstanding student with a ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MTQ1OTc4OF5BMl5BanBnXkFtZTcwMzc3MzI2Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2005, 12, 4, 0, 0),
#  'runtime': 201,
#  'title': 'Pope John Paul II',
#  'tomatoes': {'dvd': datetime.datetime(2008, 6, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 16, 18, 17, 39),
#               'viewer': {'meter': 100, 'numReviews': 85, 'rating': 5.0}},
#  'type': 'movie',
#  'writers': ['John Kent Harrison (teleplay)',
#              'Francesco Contaldo (earlier teleplay)',
#              'Salvatore Basile (additional material)',
#              'Francesco Arlanch (additional material)'],
#  'year': 2005}
# {'_id': ObjectId('573a139af29313caabcf0858'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 1 Primetime Emmy. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Nathaniel Parker', 'Jonathan Pryce', 'Leonard Nimoy', 'Sheryl Lee'],
#  'countries': ['USA', 'Italy', 'Germany'],
#  'directors': ['Robert Markowitz'],
#  'fullplot': 'The tribes of Israel need to defeat the superior might of the '
#              'Philistines: "Now appoint a king to lead us, such as all the '
#              'other nations have." (I Samuel, 8:5). And so the prophet Samuel '
#              'gives the Hebrews their first king, Saul, a simple farmer, who '
#              "with God's help becomes a brave and mighty warlord who leads the "
#              'united tribes of Israel against their enemies. Saul, however, '
#              'has incessant doubts about his mission. Not trustful enough of '
#              'divine wisdom, he acts of his own accord and thus sins against '
#              'the Lord. The influential prophet Samuel turns away from Saul in '
#              "order to select a new king according to God's will: David. He is "
#              'still a young boy, tending sheep in the fields, when, secretly '
#              'Samuel oints him as the next king of the Israelites. When David '
#              '- as courageous as he is intelligent - emerges victorious from '
#              "his encounter with Goliath, the Philistines' most powerful "
#              'warrior, he becomes a hero. His fame arouses the jealousy of '
#              'King Saul, who senses that David is going to dispute his right '
#              'to be king - and tries to kill him. David flees from Saul, and '
#              'finds many supporters and loyal companions who believe that he '
#              'is destined to be king. In exile, David waits for his time to '
#              'come, since he does not want to take the place of Saul by '
#              'violence. He is young and in the prime of his strength, while '
#              'King Saul is a broken man. When Saul falls upon his sword after '
#              "losing a battle, David's hour is at hand. The new King David "
#              'conquers Jerusalem. The magnificent city is to become the royal '
#              'residence for the glorious hero, who now plans to leave the '
#              'business of war to others in future and to become a King of '
#              'Peace. However, this temperamental man, with so many years of '
#              'battle behind him and still in the bloom of youth, is not '
#              'predestined for a quiet, orderly life at all. Very soon he '
#              'plunges into an illicit love affair with Bathsheba, a married '
#              "woman - an affair that threatens to become the king's undoing "
#              'when it turns out that she is expecting his child. To conceal '
#              "his adulterous fatherhood, the king sends Bathsheba's husband "
#              'Uriah - one of his best and most loyal soldiers - to his death, '
#              'and then marries her. The prophet and royal adviser Nathan '
#              'announces to David that his act will result in divine '
#              'punishment: the Lord will not countenance such an outrage. '
#              "Violence and evil will continue in David's own family and bring "
#              'disaster upon the heads of the numerous sons born to David from '
#              'his wives and concubines. Then the child of David and Bathsheba '
#              'dies. She gives him another son, Solomon, but very soon David '
#              'suffers another sharp blow of fate: his grown-up son Absalom '
#              "kills one of his brothers for the latter's rape of his sister. "
#              'David is far too mild in response to this: not only does he fail '
#              'to bring the incestuous seducer to justice, he also leaves the '
#              'fratricide unpunished. The king does not realise that he is '
#              'gradually losing control over his family, and that his hold on '
#              'the people is also growing weaker. For David is obsessed with '
#              'his plan of building the finest and largest temple in the world '
#              'in Jerusalem. He demands immense sums from the populace for this '
#              'project, even though God has commanded him to leave the '
#              "completion of the building to his successors. David's ambitious "
#              'son Absalom thus finds it very easy to drum up support for a '
#              'conspiracy against his father. After a fierce battle, '
#              "culminating in Absalom's death, David makes it back to "
#              'Jerusalem.',
#  'genres': ['Adventure', 'Biography', 'Drama'],
#  'imdb': {'id': 118933, 'rating': 7.0, 'votes': 514},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 00:41:12.103000000',
#  'num_mflix_comments': 0,
#  'plot': 'The tribes of Israel need to defeat the superior might of the '
#          'Philistines: "Now appoint a king to lead us, such as all the other '
#          'nations have." (I Samuel, 8:5). And so the prophet Samuel ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2NkZDkzY2UtYmU5Yi00ZWI1LTk3ZDMtMzM5NGU4YmFhNGQ2XkEyXkFqcGdeQXVyNzMwOTY2NTI@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1997, 4, 6, 0, 0),
#  'runtime': 190,
#  'title': 'David',
#  'tomatoes': {'dvd': datetime.datetime(2002, 2, 4, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 19, 39, 36),
#               'production': 'Beta Films',
#               'viewer': {'meter': 80, 'numReviews': 582, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Larry Gross (teleplay)'],
#  'year': 1997}
# {'_id': ObjectId('573a13aff29313caabd30526'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Sang-Woo Kwon', 'Jung-Jin Lee', 'Ga-in Han', 'Hyo-jun Park'],
#  'countries': ['South Korea'],
#  'directors': ['Ha Yoo'],
#  'fullplot': 'By "Fist of Fury", Kim Hyun-Soo (Sang-Woo Kwone) addicted to '
#              'Bruce Lee. Year 1978. Hyun-Soo moved to KangNam, Seoul. Hyun-Soo '
#              'transferred to JungMoon High, Maljuk Street, Kangnam, Seoul. He '
#              'goes schooling by No.78 Bus. First day a senior male took '
#              "Hyun-Soo's collar and made Hyun-Soo being punished inside "
#              'JungMoon playground because of forgetting collar Hyun-Soo made '
#              'friends with Kim Woo-Sik (Bruce Lee fan) and Hamburger. '
#              'Hamburger always bring adult magazines to school and was always '
#              'being found by the school soldiers. Hyun-Soo father had his own '
#              'TaeKwonDo Dojo - his wish is to see Hyun-Soo being the top 5 in '
#              'his JungMoon High class, and got himself promoted to University. '
#              'One day inside #78 bus, Hamburger and Hyun-Soo met Kang Eun-Ju '
#              '(EunYang Female High), a female Bruce Lee fan who looks like '
#              '"Olivia Hussey", whose music favorites are Agaetha (ABBA) and '
#              'Celsia Chan, Hyun-Soo began to fall in love with Eun-Ju. '
#              'Hyun-Soo and Woo-Sik became rivals of Cha Jung-Hoon (Triad Head, '
#              "JungMoon High) when Jung-Hoon took Eun-Ju's schoolbag inside #78 "
#              'Bus, and Woo-Sik settled everything. Woo-Sik tried flirting '
#              'Eun-Ju but she refused him because she loves Hyun-Soo. On a '
#              'Rainy day, Hyun-Soo talked with Eun-Ju in #78 Bus, knew that '
#              'Eun-Ju keep listening to a midnight radio program, and she had '
#              "even wrote postcards to that program but it didn't speak out her "
#              'postcard messages. Hyun-Soo lent Eun-Ju his black Umbrella and '
#              'ran to home. Eun-Ju ask Woo-Sik to return the umbrella to '
#              'Hyun-Soo, Hyun-Soo wrote postcard to the radio program and it '
#              'spoke the message at 2am when Eun-Ju was in #78 bus. Hyun-Soo '
#              'invited Eun-Ju to listen to his guitar playing. Eun-Ju asked '
#              "Hyun-Soo to return Woo-Sik's pen. She even wrote her reply to "
#              'the radio program. Woo-Sik and Hyun-Soo were being punished '
#              'inside a wardrobe, with the soldier telling them how many Viet '
#              'Congs he had ever killed in Vietnam War by himself without any '
#              "comrades to help. Hyun-Soo went to library and heard Eun-Ju's "
#              'postcard message in the radio program which both Eun-Ju and '
#              'Hyun-Soo always listened to. Eun-Ju regret asking Woo-Sik to '
#              "return umbrella and she promised Hyun-Soo that she won't ever "
#              "disappoint him anymore. Then, Hamburger became Jung-Hoon's gang "
#              "member. Woo-Sik tore Hamburger's adult photos, Jung-Hoon "
#              'challenged Woo-Sik to roof battle. Finally Woo-Sik was defeated '
#              'and was carried by Hyun-Soo. Woo-Sik even left JungMoon High '
#              'without contacting Hyun-Soo anymore. Eun-Ju was being rumored to '
#              'leave with Woo-Sik but later Hamburger found that she had not '
#              'left with Woo-Sik, but was being suspended one year for bad '
#              "results. One day, Hyun-Soo met Jung-Hoon's gang. they threatened "
#              "to remove Hyun-Soo's eyeballs from his eyes. Hyun-Soo decided to "
#              "train himself for any further struggle with Jung-Hoon's gang. On "
#              "the day of Hyun-Soo's battle, a classmate threw his milk to "
#              "Jung-Hoon. Jung-Hoon's gang ran into Hyun-Soo's class and ask "
#              'who did that. Hamburger tried pacifying Jung-Hoon but failed. '
#              'Hyun-Soo stood up and challenged Jung-Hoon at roof. Hyun-Soo '
#              'used his double-stick to hit Jung-Hoon when they went upstairs. '
#              'Finally, in great resistance, Hyun-Soo won the battle and went '
#              'downstairs. Soldiers stopped Hyun-Soo, but he escaped, destroyed '
#              '2 windows and spoke, "F**k all schools in Korea!" Hyun-Soo '
#              "father talked to Jung-Hoon's mother but she blame Hyun-Soo for "
#              "destroying her son's face. Hyun-Soo said sorry to father, father "
#              'asked Hyun-Soo if Bruce Lee had ever studied into University. '
#              'Hyun-Soo smiled, father knew no. Hyun-Soo studied in G.E.D. '
#              '(General Education Diploma) and met Hamburger when Hamburger '
#              'sold his adult magazines to classmates for 2 bucks. Hamburger '
#              'told Hyun-Soo that Eun-Ju also studied this GED center. Hyun-Soo '
#              'waited Eun-Ju but failed, got up to #78 Bus. Hyun-Soo missed '
#              'Eun-Ju until females said "Bye-bye, Eun-Ju!" Hyun-Soo turned his '
#              'head and saw Eun-Ju alone. Eun-Ju said that Korea weather is '
#              'colder than before, Hyun-Soo said yes. Eun-Ju got off in HanNam '
#              'station. Hamburger ask Hyun-Soo to watch Jackie Chan movie, '
#              '"Drunken Master" and even said Bruce Lee is already outdated. '
#              'Hyun-Soo kicked to revenge for Bruce Lee outside the cinema '
#              'door.',
#  'genres': ['Drama', 'History'],
#  'imdb': {'id': 390205, 'rating': 7.6, 'votes': 1873},
#  'languages': ['Korean'],
#  'lastupdated': '2015-06-27 00:02:15.123000000',
#  'num_mflix_comments': 0,
#  'plot': 'By "Fist of Fury", Kim Hyun-Soo (Sang-Woo Kwone) addicted to Bruce '
#          'Lee. Year 1978. Hyun-Soo moved to KangNam, Seoul. Hyun-Soo '
#          'transferred to JungMoon High, Maljuk Street, Kangnam, Seoul. He...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY4MjU2Ml5BMl5BanBnXkFtZTgwNjY5OTQ2MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2004, 1, 16, 0, 0),
#  'runtime': 116,
#  'title': 'The Spirit of Jeet Kune Do',
#  'type': 'movie',
#  'writers': ['Ha Yoo'],
#  'year': 2004}

# %% [markdown]
# Exercise 6: Combining Multiple Queries (Bonus Exercise)

# %%
#1. Write a query to find all movies where the genre is "Action" and the IMDb rating is greater than 8 (Sort the results by release year in descending order).
action_high_rated_movies = collection.find({"genres": "Action", "imdb.rating": {"$gt": 8}}).sort("year", -1)
for movie in action_high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13bef29313caabd5b166'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Vladimir Mashkov',
#           'Mikhail Porechenkov',
#           'Vladimir Menshov',
#           'Sergey Makovetskiy'],
#  'countries': ['Russia'],
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1048097, 'rating': 8.6, 'votes': 929},
#  'languages': ['Russian', 'Ukrainian'],
#  'lastupdated': '2015-04-08 00:08:01.207000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2007, 12, 2, 0, 0),
#  'runtime': 45,
#  'title': 'Liquidation',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 17, 10, 27),
#               'viewer': {'meter': 23, 'numReviews': 83, 'rating': 1.9}},
#  'type': 'series',
#  'year': '2007è'}
# {'_id': ObjectId('573a13b6f29313caabd48af3'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8525},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-17 00:55:25.017000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'tomatoes': {'dvd': datetime.datetime(2003, 12, 9, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 21, 18, 39, 56),
#               'viewer': {'meter': 93, 'numReviews': 1510, 'rating': 3.2}},
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a13bdf29313caabd586eb'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8880},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-09-05 08:36:26.777000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a1399f29313caabced750'),
#  'awards': {'nominations': 25,
#             'text': 'Won 1 Primetime Emmy. Another 16 wins & 25 nominations.',
#             'wins': 17},
#  'cast': ['Jerry Doyle', 'Mira Furlan', 'Richard Biggs', 'Bill Mumy'],
#  'countries': ['USA'],
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 105946, 'rating': 8.2, 'votes': 21109},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 07:39:16.083000000',
#  'num_mflix_comments': 0,
#  'plot': 'A space station in neutral territory is the focus of a unique five '
#          'year saga.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2Q3ZWM0YzgtMGU0Mi00OWM0LWIwNzctNmQ4NTUyYTk0ZWY2XkEyXkFqcGdeQXVyMzYyMzU2OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1994, 1, 26, 0, 0),
#  'runtime': 45,
#  'title': 'Babylon 5',
#  'tomatoes': {'dvd': datetime.datetime(2009, 9, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 18, 31, 13),
#               'viewer': {'numReviews': 5, 'rating': 0.0}},
#  'type': 'series',
#  'writers': ['J. Michael Straczynski'],
#  'year': '1994è1998'}
# {'_id': ObjectId('573a13c5f29313caabd70568'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Hugh Keays-Byrne'],
#  'countries': ['Australia', 'USA'],
#  'directors': ['George Miller'],
#  'fullplot': 'An apocalyptic story set in the furthest reaches of our planet, '
#              'in a stark desert landscape where humanity is broken, and almost '
#              'everyone is crazed fighting for the necessities of life. Within '
#              'this world exist two rebels on the run who just might be able to '
#              "restore order. There's Max, a man of action and a man of few "
#              'words, who seeks peace of mind following the loss of his wife '
#              'and child in the aftermath of the chaos. And Furiosa, a woman of '
#              'action and a woman who believes her path to survival may be '
#              'achieved if she can make it across the desert back to her '
#              'childhood homeland.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1392190, 'rating': 8.3, 'votes': 314071},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-10 17:05:45.723000000',
#  'metacritic': 89,
#  'num_mflix_comments': 1,
#  'plot': 'A woman rebels against a tyrannical ruler in post apocalyptic '
#          'Australia in search for her homeland with the help of a group of '
#          'female prisoners, a psychotic worshiper, and a drifter named Max.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2EwM2I5OWMtMGQyMi00Zjg1LWJkNTctZTdjYTA4OGUwZjMyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 5, 15, 0, 0),
#  'runtime': 120,
#  'title': 'Mad Max: Fury Road',
#  'tomatoes': {'boxOffice': '$153.1M',
#               'consensus': 'With exhilarating action and a surprising amount '
#                            'of narrative heft, Mad Max: Fury Road brings '
#                            "George Miller's post-apocalyptic franchise roaring "
#                            'vigorously back to life.',
#               'critic': {'meter': 97, 'numReviews': 301, 'rating': 8.7},
#               'dvd': datetime.datetime(2015, 9, 1, 0, 0),
#               'fresh': 292,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 9, 27),
#               'production': 'Warner Bros.',
#               'rotten': 9,
#               'viewer': {'meter': 88, 'numReviews': 103105, 'rating': 4.3},
#               'website': 'http://www.madmaxmovie.com/'},
#  'type': 'movie',
#  'writers': ['George Miller', 'Brendan McCarthy', 'Nick Lathouris'],
#  'year': 2015}
# {'_id': ObjectId('573a13daf29313caabdad25f'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['John G. Avildsen',
#           'Billy Blanks',
#           'Lauro Chartrand',
#           'Michael Chavez'],
#  'countries': ['USA', 'Canada', 'Japan', 'Panama'],
#  'directors': ['Kevin Derek'],
#  'fullplot': 'The life of the greatest karate master of a generation.',
#  'genres': ['Documentary', 'Action', 'History'],
#  'imdb': {'id': 2313306, 'rating': 9.3, 'votes': 41},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:43:31.983000000',
#  'num_mflix_comments': 0,
#  'plot': 'The life of the greatest karate master of a generation.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY3MjI0MjA1OF5BMl5BanBnXkFtZTgwMTI3Nzc2MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 20, 0, 0),
#  'runtime': 90,
#  'title': 'The Real Miyagi',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 6, 19, 58, 30),
#               'production': 'Breaking Glass Pictures',
#               'viewer': {'meter': 0, 'numReviews': 37, 'rating': 2.2},
#               'website': 'http://tennesseequeer.popslice.com'},
#  'type': 'movie',
#  'writers': ['Kevin Derek', 'Kevin Derek'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb72de'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Conrad Anker', 'Grace Chin', 'Jimmy Chin', 'Amee Hinkley'],
#  'countries': ['India', 'USA'],
#  'directors': ['Jimmy Chin', 'Elizabeth Chai Vasarhelyi'],
#  'fullplot': 'Three elite climbers struggle to find their way through '
#              'obsession and loss as they attempt to climb Mount Meru, one of '
#              'the most coveted prizes in the high stakes game of Himalayan big '
#              'wall climbing.',
#  'genres': ['Documentary', 'Action', 'Adventure'],
#  'imdb': {'id': 2545428, 'rating': 8.3, 'votes': 263},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:13:00.430000000',
#  'metacritic': 75,
#  'num_mflix_comments': 1,
#  'plot': 'Three elite climbers struggle to find their way through obsession '
#          'and loss as they attempt to climb Mount Meru, one of the most '
#          'coveted prizes in the high stakes game of Himalayan big wall '
#          'climbing.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MDM3NjY2Nl5BMl5BanBnXkFtZTgwNjkyNTIzNjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 8, 14, 0, 0),
#  'runtime': 87,
#  'title': 'Meru',
#  'tomatoes': {'boxOffice': '$0.7M',
#               'consensus': 'Gripping visually as well as narratively, Meru is '
#                            'the rare documentary that proves thought-provoking '
#                            'while offering thrilling wide-screen vistas.',
#               'critic': {'meter': 93, 'numReviews': 45, 'rating': 7.6},
#               'fresh': 42,
#               'lastUpdated': datetime.datetime(2015, 9, 3, 19, 0, 34),
#               'production': 'Music Box Films',
#               'rotten': 3,
#               'viewer': {'meter': 96, 'numReviews': 1509, 'rating': 4.5},
#               'website': 'http://www.merufilm.com/'},
#  'type': 'movie',
#  'year': 2015}
# {'_id': ObjectId('573a13ecf29313caabdd21a3'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['David Sandberg', 'Jorma Taccone', 'Steven Chew', 'Leopold Nilsson'],
#  'countries': ['Sweden'],
#  'directors': ['David Sandberg'],
#  'fullplot': 'During an unfortunate series of events a friend of Kung Fury is '
#              'assassinated by the most dangerous kung fu master criminal of '
#              'all time; Adolf Hitler, a.k.a Kung Fèhrer. Kung Fury decides to '
#              'travel back in time, to Nazi Germany, in order to kill Hitler '
#              'and end the Nazi empire once and for all.',
#  'genres': ['Short', 'Action', 'Comedy'],
#  'imdb': {'id': 3472226, 'rating': 8.3, 'votes': 24575},
#  'languages': ['English', 'Swedish', 'German'],
#  'lastupdated': '2015-09-10 17:20:55.477000000',
#  'num_mflix_comments': 2,
#  'plot': 'In 1985, Kung Fury, the toughest martial artist cop in Miami, goes '
#          'back in time to kill the worst criminal of all time - kung fuhrer '
#          'Hitler.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjQwMjU2ODU5NF5BMl5BanBnXkFtZTgwNTU1NjM4NTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 5, 28, 0, 0),
#  'runtime': 31,
#  'title': 'Kung Fury',
#  'type': 'movie',
#  'writers': ['David Sandberg'],
#  'year': 2015}
# {'_id': ObjectId('573a13d3f29313caabd947a8'),
#  'awards': {'nominations': 38,
#             'text': 'Nominated for 1 Oscar. Another 9 wins & 38 nominations.',
#             'wins': 10},
#  'cast': ['Hugh Jackman',
#           'James McAvoy',
#           'Michael Fassbender',
#           'Jennifer Lawrence'],
#  'countries': ['USA', 'UK', 'Canada'],
#  'directors': ['Bryan Singer'],
#  'fullplot': 'Sentinels, robots that were created for the purpose of hunting '
#              'down mutants were released in 1973. 50 years later the Sentinels '
#              'would also hunt humans who aid mutants. Charles Xavier and his '
#              'X-Men try their best to deal with the Sentinels but they are '
#              'able to adapt and deal with all mutant abilities. Charles '
#              'decides to go back in time and change things. He asks Kitty '
#              "Pryde who can send a person's consciousness into the person's "
#              'past to send him but she can only send someone back a few weeks '
#              'because if she sends someone back further it could harm them. So '
#              'Logan decides to go back himself because he might be able to '
#              "withstand it. So Charles tells him that it's Mystique who's "
#              'responsible because when she learned about the Sentinels she '
#              'sought out Bolivar Trask the man who created them and killed '
#              'him. She would be caught and studied and her ability to change '
#              'was somehow added to the Sentinels which is why they can adapt. '
#              'Logan must go to the younger Charles and ask him to help; '
#              'problem is that he was despondent at that time and without his '
#              'powers because he took a drug which allows him to walk but takes '
#              'away his powers. Logan is also told to find Magneto.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1877832, 'rating': 8.1, 'votes': 436254},
#  'languages': ['English', 'Vietnamese', 'French'],
#  'lastupdated': '2015-08-31 00:09:15.700000000',
#  'metacritic': 74,
#  'num_mflix_comments': 0,
#  'plot': 'The X-Men send Wolverine to the past in a desperate effort to change '
#          'history and prevent an event that results in doom for both humans '
#          'and mutants.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZGIzNWYzN2YtMjcwYS00YjQ3LWI2NjMtOTNiYTUyYjE2MGNkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'X-Men: Days of Future Past',
#  'tomatoes': {'boxOffice': '$233.9M',
#               'consensus': 'X-Men: Days of Future Past combines the best '
#                            'elements of the series to produce a satisfyingly '
#                            "fast-paced outing that ranks among the franchise's "
#                            'finest installments.',
#               'critic': {'meter': 91, 'numReviews': 270, 'rating': 7.6},
#               'dvd': datetime.datetime(2014, 10, 14, 0, 0),
#               'fresh': 245,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 6, 53),
#               'production': '20th Century Fox',
#               'rotten': 25,
#               'viewer': {'meter': 92, 'numReviews': 270716, 'rating': 4.3},
#               'website': 'http://www.x-menmovies.com/'},
#  'type': 'movie',
#  'writers': ['Simon Kinberg (screenplay)',
#              'Jane Goldman (story)',
#              'Simon Kinberg (story)',
#              'Matthew Vaughn (story)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d5f29313caabd9c312'),
#  'awards': {'nominations': 81,
#             'text': 'Nominated for 2 Oscars. Another 42 wins & 81 nominations.',
#             'wins': 44},
#  'cast': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel'],
#  'countries': ['USA', 'UK'],
#  'directors': ['James Gunn'],
#  'fullplot': 'After stealing a mysterious orb in the far reaches of outer '
#              'space, Peter Quill from Earth, is now the main target of a '
#              'manhunt led by the villain known as Ronan the Accuser. To help '
#              'fight Ronan and his team and save the galaxy from his power, '
#              'Quill creates a team of space heroes known as the "Guardians of '
#              'the Galaxy" to save the world.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 2015381, 'rating': 8.1, 'votes': 539583},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:00:43.957000000',
#  'metacritic': 76,
#  'num_mflix_comments': 0,
#  'plot': 'A group of intergalactic criminals are forced to work together to '
#          'stop a fanatical warrior from taking control of the universe.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 8, 1, 0, 0),
#  'runtime': 121,
#  'title': 'Guardians of the Galaxy',
#  'tomatoes': {'boxOffice': '$333.2M',
#               'consensus': 'Guardians of the Galaxy is just as irreverent as '
#                            'fans of the frequently zany Marvel comic would '
#                            'expect -- as well as funny, thrilling, full of '
#                            'heart, and packed with visual splendor.',
#               'critic': {'meter': 91, 'numReviews': 273, 'rating': 7.8},
#               'dvd': datetime.datetime(2014, 12, 9, 0, 0),
#               'fresh': 249,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 17),
#               'production': 'Walt Disney Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 92, 'numReviews': 241767, 'rating': 4.4},
#               'website': 'http://marvel.com/guardians'},
#  'type': 'movie',
#  'writers': ['James Gunn',
#              'Nicole Perlman',
#              'Dan Abnett (comic book)',
#              'Andy Lanning (comic book)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d9f29313caabda92ff'),
#  'awards': {'nominations': 80,
#             'text': 'Nominated for 2 Oscars. Another 43 wins & 80 nominations.',
#             'wins': 45},
#  'cast': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel'],
#  'countries': ['USA', 'UK'],
#  'directors': ['James Gunn'],
#  'fullplot': 'After stealing a mysterious orb in the far reaches of outer '
#              'space, Peter Quill from Earth, is now the main target of a '
#              'manhunt led by the villain known as Ronan the Accuser. To help '
#              'fight Ronan and his team and save the galaxy from his power, '
#              'Quill creates a team of space heroes known as the "Guardians of '
#              'the Galaxy" to save the world.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 2015381, 'rating': 8.1, 'votes': 548314},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 22:57:02.667000000',
#  'metacritic': 76,
#  'num_mflix_comments': 1,
#  'plot': 'A group of intergalactic criminals are forced to work together to '
#          'stop a fanatical warrior from taking control of the universe.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 8, 1, 0, 0),
#  'runtime': 121,
#  'title': 'Guardians of the Galaxy',
#  'tomatoes': {'boxOffice': '$333.2M',
#               'consensus': 'Guardians of the Galaxy is just as irreverent as '
#                            'fans of the frequently zany Marvel comic would '
#                            'expect -- as well as funny, thrilling, full of '
#                            'heart, and packed with visual splendor.',
#               'critic': {'meter': 91, 'numReviews': 273, 'rating': 7.8},
#               'dvd': datetime.datetime(2014, 12, 9, 0, 0),
#               'fresh': 249,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 17),
#               'production': 'Walt Disney Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 92, 'numReviews': 241767, 'rating': 4.4},
#               'website': 'http://marvel.com/guardians'},
#  'type': 'movie',
#  'writers': ['James Gunn',
#              'Nicole Perlman',
#              'Dan Abnett (comic book)',
#              'Andy Lanning (comic book)'],
#  'year': 2014}
# {'_id': ObjectId('573a13e0f29313caabdba169'),
#  'awards': {'nominations': 1, 'text': '6 wins & 1 nomination.', 'wins': 6},
#  'cast': ['Elina Abai Kyzy',
#           'Nasira Mambetova',
#           'Aziz Muradillayev',
#           'Adilet Usubaliyev'],
#  'countries': ['Kyrgyzstan'],
#  'directors': ['Sadyk Sher-Niyaz'],
#  'fullplot': 'The historical, epic drama, set in 19th century Central Asia, '
#              'tells the true story of Kurmanjan Datka, a strong willed woman, '
#              'who becomes the ruler of her country and saves the nation from '
#              'total destruction. As a young woman she is forced into an '
#              'arranged marriage but escapes, flees to the mountains and falls '
#              'in love with the local chief Alymbek, whom she marries. When he '
#              'is killed by political rivals, she becomes the "queen of the '
#              'mountains" and a key figure and negotiator in the national '
#              'struggle, when the Russians invade.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 2640460, 'rating': 8.6, 'votes': 3106},
#  'languages': ['English', 'Kirghiz', 'Russian'],
#  'lastupdated': '2015-08-25 01:09:37.977000000',
#  'num_mflix_comments': 0,
#  'plot': 'The relevant epic story of the strong-willed, courageous and '
#          'independent woman before her time, Kurmanjan, who is revered to this '
#          'day for her diplomacy for saving her nation from complete '
#          'destruction when the Russians invaded.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0ODAxNDQ0MV5BMl5BanBnXkFtZTgwNzY1MDUyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 1, 6, 0, 0),
#  'runtime': 135,
#  'title': 'Queen of the Mountains',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 18, 1, 44),
#               'viewer': {'meter': 50, 'numReviews': 17, 'rating': 3.4},
#               'website': 'http://www.kurmanjan.com/'},
#  'type': 'movie',
#  'writers': ['Sadyk Sher-Niyaz (screenplay)',
#              'Bakytbek Turdubaev',
#              'Bakyt Turdubayev (creator)'],
#  'year': 2014}
# {'_id': ObjectId('573a13eff29313caabdd7dbc'),
#  'awards': {'nominations': 8, 'text': '5 wins & 8 nominations.', 'wins': 5},
#  'cast': ['Serkan Keskin', 'Hazal Kaya', 'èner Erkan', 'Osman Sonant'],
#  'countries': ['Turkey'],
#  'directors': ['Onur ènlè'],
#  'fullplot': 'There is a murder while at prayer. Selman Bulut, the imam of '
#              'mosque, starts to investigate the murder and faces with people '
#              'in the neighborhood.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 3646462, 'rating': 8.1, 'votes': 3587},
#  'languages': ['Turkish'],
#  'lastupdated': '2015-08-23 01:17:38.520000000',
#  'num_mflix_comments': 1,
#  'plot': 'There is a murder while at prayer. Selman Bulut, the imam of mosque, '
#          'starts to investigate the murder and faces with people in the '
#          'neighborhood.',
#  'released': datetime.datetime(2014, 4, 18, 0, 0),
#  'runtime': 110,
#  'title': "Let's Sin",
#  'type': 'movie',
#  'writers': ['Onur ènlè'],
#  'year': 2014}
# {'_id': ObjectId('573a13d1f29313caabd8fefb'),
#  'awards': {'nominations': 0, 'text': '10 wins.', 'wins': 10},
#  'cast': ['Shaan Shahid', 'Hamza Abbasi', 'Shamoon Abbasi', 'Ayesha Khan'],
#  'countries': ['Pakistan'],
#  'directors': ['Bilal Lashari'],
#  'fullplot': 'The film is based on stylized depiction of actual life events '
#              'surrounding the war on terror in Pakistan including the attack '
#              'on a Police Academy at Lahore in 2009. Major Mujtaba is a former '
#              'army officer, who took an early retirement from the service. The '
#              'plot involves a counter-terrorism operation being conducted in '
#              'the Northwestern tribal region of Pakistan, led by Ehtesham and '
#              'coordinated by an intelligence officer played by Ayesha. '
#              'Ehtesham and the intelligence officer come to know of a major '
#              'terrorist attack that can only be countered with the help of '
#              'Major Mujtaba.',
#  'genres': ['Action', 'Drama', 'Thriller'],
#  'imdb': {'id': 1821700, 'rating': 8.5, 'votes': 26769},
#  'languages': ['English', 'Urdu'],
#  'lastupdated': '2015-09-17 04:44:15.710000000',
#  'num_mflix_comments': 1,
#  'plot': 'The efforts of the Pakistani security forces in their fight against '
#          'terrorism and how the lives of security officials are affected. A '
#          'retired security officer returns to save Pakistan from a major '
#          'terrorist attack.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI2NjM2MjYzMV5BMl5BanBnXkFtZTgwMjc0NTE1MDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 16, 0, 0),
#  'runtime': 130,
#  'title': 'Waar',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 3, 18, 58, 41),
#               'viewer': {'numReviews': 1, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Hassan Rana'],
#  'year': 2013}
# {'_id': ObjectId('573a13d4f29313caabd99c55'),
#  'awards': {'nominations': 50,
#             'text': 'Nominated for 2 Golden Globes. Another 8 wins & 50 '
#                     'nominations.',
#             'wins': 10},
#  'cast': ['Chris Hemsworth',
#           'Daniel Brèhl',
#           'Olivia Wilde',
#           'Alexandra Maria Lara'],
#  'countries': ['UK', 'Germany', 'USA'],
#  'directors': ['Ron Howard'],
#  'fullplot': 'Set against the sexy, glamorous golden age of Formula 1 racing '
#              'in the 1970s, the film is based on the true story of a great '
#              'sporting rivalry between handsome English playboy James Hunt '
#              '(Hemsworth), and his methodical, brilliant opponent, Austrian '
#              'driver Niki Lauda (Bruhl). The story follows their distinctly '
#              'different personal styles on and off the track, their loves and '
#              'the astonishing 1976 season in which both drivers were willing '
#              'to risk everything to become world champion in a sport with no '
#              'margin for error: if you make a mistake, you die.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 1979320, 'rating': 8.2, 'votes': 263143},
#  'languages': ['English', 'German', 'Italian', 'French', 'Spanish'],
#  'lastupdated': '2015-08-31 00:39:49.983000000',
#  'metacritic': 75,
#  'num_mflix_comments': 1,
#  'plot': 'The merciless 1970s rivalry between Formula One rivals James Hunt '
#          'and Niki Lauda.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOWEwODJmZDItYTNmZC00OGM4LThlNDktOTQzZjIzMGQxODA4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 9, 27, 0, 0),
#  'runtime': 123,
#  'title': 'Rush',
#  'tomatoes': {'boxOffice': '$26.9M',
#               'consensus': 'A sleek, slick, well-oiled machine, Rush is a '
#                            'finely crafted sports drama with exhilarating race '
#                            'sequences and strong performances from Chris '
#                            'Hemsworth and Daniel Brèhl.',
#               'critic': {'meter': 89, 'numReviews': 210, 'rating': 7.6},
#               'dvd': datetime.datetime(2014, 1, 28, 0, 0),
#               'fresh': 187,
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 2, 24),
#               'production': 'Universal Pictures',
#               'rotten': 23,
#               'viewer': {'meter': 88, 'numReviews': 77154, 'rating': 4.1},
#               'website': 'http://www.rushmovie.com/'},
#  'type': 'movie',
#  'writers': ['Peter Morgan'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda4bad'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Peter Weller', 'Ariel Winter', 'Michael Emerson', 'David Selby'],
#  'countries': ['USA'],
#  'directors': ['Jay Oliva'],
#  'fullplot': 'After a 10 year absence, the Dark Knight has returned to Gotham '
#              'to fight the Mutant threat. After defeating the mutants, he has '
#              'taken control of a gang loyal to him in order to make Gotham a '
#              'safer place. But, the Joker has decided to stop this, and fights '
#              'against Batman in a deadly duel. Meanwhile, the Man of Steel is '
#              'ordered to stop the Dark Knight because the government believes '
#              'that his ways are wrong. As Batman fights the Joker, the Man of '
#              'Steel prepares for his greatest fight.',
#  'genres': ['Animation', 'Action', 'Crime'],
#  'imdb': {'id': 2166834, 'rating': 8.4, 'votes': 22244},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:09:46.120000000',
#  'num_mflix_comments': 0,
#  'plot': 'The Batman has returned after a 10-year absence. The Gotham '
#          'authorities want to arrest him. An old foe wants a reunion. The Feds '
#          'want the Man of Tomorrow to put a stop to him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTEzMmE0ZDYtYWNmYi00ZWM4LWJjOTUtYTE0ZmQyYWM3ZjA0XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 1, 29, 0, 0),
#  'runtime': 76,
#  'title': 'Batman: The Dark Knight Returns, Part 2',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 27, 18, 50, 14),
#               'viewer': {'meter': 94, 'numReviews': 54, 'rating': 4.4},
#               'website': 'http://www.gowithleflo.com/'},
#  'type': 'movie',
#  'writers': ['Bob Kane (Batman characters)',
#              'Jerry Siegel (Superman characters)',
#              'Joe Shuster (Superman characters)',
#              'Frank Miller (comic book)',
#              'Klaus Janson (comic book)',
#              'Bob Goodman'],
#  'year': 2013}
# {'_id': ObjectId('573a13d8f29313caabda6b38'),
#  'awards': {'nominations': 10, 'text': '2 wins & 10 nominations.', 'wins': 2},
#  'cast': ['Kamal Haasan', 'Rahul Bose', 'Shekhar Kapur', 'Pooja Kumar'],
#  'countries': ['India'],
#  'directors': ['Kamal Haasan'],
#  'fullplot': 'Vishwanathan, a Kathak dance teacher in New York, is in a rather '
#              'happy marriage with Nirupama who is a nuclear oncologist. She '
#              'hires a detective to keep a watch on her husband, who apparently '
#              "ends up in a wrong place that reveals Vishwanathan's true "
#              'identity.',
#  'genres': ['Action', 'Adventure', 'Crime'],
#  'imdb': {'id': 2199711, 'rating': 8.8, 'votes': 33015},
#  'languages': ['Tamil', 'Hindi', 'Telugu', 'Arabic', 'Pushto'],
#  'lastupdated': '2015-08-24 00:59:33.400000000',
#  'num_mflix_comments': 0,
#  'plot': 'Vishwanathan, a Kathak dance teacher in New York, is in a rather '
#          'happy marriage with Nirupama who is a nuclear oncologist. She hires '
#          'a detective to keep a watch on her husband, who ...',
#  'released': datetime.datetime(2013, 1, 25, 0, 0),
#  'runtime': 148,
#  'title': 'Vishwaroopam',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 14, 18, 2, 3),
#               'production': 'Blue Sky Cinemas',
#               'viewer': {'meter': 82, 'numReviews': 559, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Kamal Haasan', 'Atul Tiwari (hindi dialogue)'],
#  'year': 2013}
# {'_id': ObjectId('573a13baf29313caabd506e4'),
#  'awards': {'nominations': 67,
#             'text': 'Nominated for 1 Oscar. Another 32 wins & 67 nominations.',
#             'wins': 33},
#  'cast': ['Robert Downey Jr.',
#           'Chris Evans',
#           'Mark Ruffalo',
#           'Chris Hemsworth'],
#  'countries': ['USA'],
#  'directors': ['Joss Whedon'],
#  'fullplot': 'Nick Fury is director of S.H.I.E.L.D, an international peace '
#              "keeping agency. The agency is a who's who of Marvel Super "
#              'Heroes, with Iron Man, The Incredible Hulk, Thor, Captain '
#              'America, Hawkeye and Black Widow. When global security is '
#              'threatened by Loki and his cohorts, Nick Fury and his team will '
#              'need all their powers to save the world from disaster.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 848228, 'rating': 8.1, 'votes': 877226},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-10 17:10:29.990000000',
#  'metacritic': 69,
#  'num_mflix_comments': 117,
#  'plot': "Earth's mightiest heroes must come together and learn to fight as a "
#          'team if they are to stop the mischievous Loki and his alien army '
#          'from enslaving humanity.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNjQyMjAtNTdiOS00NGYwLWFmNTAtNThmYjU5ZGI2YTI1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 5, 4, 0, 0),
#  'runtime': 143,
#  'title': 'The Avengers',
#  'tomatoes': {'boxOffice': '$623.3M',
#               'consensus': "Thanks to a script that ephasizes its heroes' "
#                            'humanity and a wealth of superpowered set pieces, '
#                            'The Avengers lives up to its hype and raises the '
#                            'bar for Marvel at the movies.',
#               'critic': {'meter': 92, 'numReviews': 315, 'rating': 8.0},
#               'dvd': datetime.datetime(2012, 9, 25, 0, 0),
#               'fresh': 289,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 31, 32),
#               'production': 'Walt Disney Pictures',
#               'rotten': 26,
#               'viewer': {'meter': 91, 'numReviews': 1124021, 'rating': 4.4},
#               'website': 'http://marvel.com/avengers_movie'},
#  'type': 'movie',
#  'writers': ['Joss Whedon (screenplay)',
#              'Zak Penn (story)',
#              'Joss Whedon (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13c4f29313caabd6cc80'),
#  'awards': {'nominations': 86,
#             'text': 'Nominated for 1 BAFTA Film Award. Another 45 wins & 86 '
#                     'nominations.',
#             'wins': 46},
#  'cast': ['Christian Bale', 'Gary Oldman', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Despite his tarnished reputation after the events of The Dark '
#              "Knight, in which he took the rap for Dent's crimes, Batman feels "
#              'compelled to intervene to assist the city and its police force '
#              "which is struggling to cope with Bane's plans to destroy the "
#              'city.',
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1345836, 'rating': 8.5, 'votes': 1004805},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:03:50.157000000',
#  'metacritic': 78,
#  'num_mflix_comments': 129,
#  'plot': "Eight years after the Joker's reign of anarchy, the Dark Knight is "
#          'forced to return from his imposed exile to save Gotham City from the '
#          'brutal guerrilla terrorist Bane with the help of the enigmatic '
#          'Catwoman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 7, 20, 0, 0),
#  'runtime': 165,
#  'title': 'The Dark Knight Rises',
#  'tomatoes': {'boxOffice': '$448.1M',
#               'consensus': 'The Dark Knight Rises is an ambitious, thoughtful, '
#                            'and potent action film that concludes Christopher '
#                            "Nolan's franchise in spectacular fashion.",
#               'critic': {'meter': 87, 'numReviews': 327, 'rating': 8.0},
#               'dvd': datetime.datetime(2012, 12, 3, 0, 0),
#               'fresh': 283,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 27, 41),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 44,
#               'viewer': {'meter': 90, 'numReviews': 1203596, 'rating': 4.3},
#               'website': 'http://www.thedarkknightrises.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2012}
# {'_id': ObjectId('573a13d4f29313caabd98387'),
#  'awards': {'nominations': 32, 'text': '10 wins & 32 nominations.', 'wins': 10},
#  'cast': ['Manoj Bajpayee',
#           'Richa Chadda',
#           'Nawazuddin Siddiqui',
#           'Tigmanshu Dhulia'],
#  'countries': ['India'],
#  'directors': ['Anurag Kashyap'],
#  'fullplot': 'Shahid Khan is exiled after impersonating the legendary Sultana '
#              'Daku in order to rob British trains. Now outcast, Shahid becomes '
#              "a worker at Ramadhir Singh's colliery, only to spur a revenge "
#              'battle that passes on to generations. At the turn of the decade, '
#              "Shahid's son, the philandering Sardar Khan vows to get his "
#              "father's honor back, becoming the most feared man of Wasseypur.",
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 1954470, 'rating': 8.4, 'votes': 35127},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-19 00:19:48.483000000',
#  'metacritic': 89,
#  'num_mflix_comments': 0,
#  'plot': 'A clash between Sultan (a Qureishi dacoit chief) and Shahid Khan (a '
#          'Pathan who impersonates him) leads to the expulsion of Khan from '
#          'Wasseypur, and ignites a deadly blood feud spanning three '
#          'generations.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc5NjY4MjUwNF5BMl5BanBnXkFtZTgwODM3NzM5MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 8, 2, 0, 0),
#  'runtime': 320,
#  'title': 'Gangs of Wasseypur',
#  'tomatoes': {'critic': {'meter': 95, 'numReviews': 19, 'rating': 8.5},
#               'fresh': 18,
#               'lastUpdated': datetime.datetime(2015, 8, 24, 18, 16, 31),
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 1471, 'rating': 4.3},
#               'website': 'http://www.wasseypurworld.com/'},
#  'type': 'movie',
#  'writers': ['Akhilesh Jaiswal',
#              'Anurag Kashyap',
#              'Sachin K. Ladia',
#              'Zeishan Quadri'],
#  'year': 2012}
# {'_id': ObjectId('573a13aef29313caabd2c99e'),
#  'awards': {'nominations': 32,
#             'text': 'Nominated for 1 Golden Globe. Another 23 wins & 32 '
#                     'nominations.',
#             'wins': 24},
#  'cast': ['James Badge Dale',
#           'Joseph Mazzello',
#           'Jon Seda',
#           'Sebastian Bertoli'],
#  'countries': ['USA'],
#  'fullplot': 'The Pacific follows the lives of a U.S Marine Corps squad during '
#              'the campaign within the Pacific against the Japanese Empire '
#              'during WW2. Made by the creators of Band of Brothers, it follows '
#              'a similar line of thought to outline the hardships of the common '
#              'man during war. the Pacific is in parts a fast paced war series '
#              'that can be enjoyed by action lovers whilst containing a more '
#              'sensitive side when projecting the relationships (brotherhood) '
#              'of Marines on the battlefield. where the Pacific takes a new '
#              'direction from its "older brother" is in its depiction of the '
#              'lives of soldiers who were picked to return home to increase the '
#              'sales of war bonds, in doing this it also depicts the life cycle '
#              'of returned soldiers from initial joy to the eventual feeling of '
#              'regret and to a certain extent shame felt by soldiers wanting to '
#              'return to the war in service of either their comrades or nation.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 374463, 'rating': 8.3, 'votes': 60257},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 11:04:50.053000000',
#  'num_mflix_comments': 0,
#  'plot': "The intertwined stories of three Marines during America's battle "
#          'with the Japanese in the Pacific during World War II.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmEwNmI1MjItNjNjYy00NDE5LWJiNTYtM2QxMTI5ZjllZTBhL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2010, 3, 14, 0, 0),
#  'runtime': 52,
#  'title': 'The Pacific',
#  'type': 'series',
#  'year': 2010}
# {'_id': ObjectId('573a13c5f29313caabd6ee61'),
#  'awards': {'nominations': 172,
#             'text': 'Won 4 Oscars. Another 158 wins & 172 nominations.',
#             'wins': 162},
#  'cast': ['Leonardo DiCaprio',
#           'Joseph Gordon-Levitt',
#           'Ellen Page',
#           'Tom Hardy'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Dom Cobb is a skilled thief, the absolute best in the dangerous '
#              'art of extraction, stealing valuable secrets from deep within '
#              'the subconscious during the dream state, when the mind is at its '
#              "most vulnerable. Cobb's rare ability has made him a coveted "
#              'player in this treacherous new world of corporate espionage, but '
#              'it has also made him an international fugitive and cost him '
#              'everything he has ever loved. Now Cobb is being offered a chance '
#              'at redemption. One last job could give him his life back but '
#              'only if he can accomplish the impossible-inception. Instead of '
#              'the perfect heist, Cobb and his team of specialists have to pull '
#              'off the reverse: their task is not to steal an idea but to plant '
#              'one. If they succeed, it could be the perfect crime. But no '
#              'amount of careful planning or expertise can prepare the team for '
#              'the dangerous enemy that seems to predict their every move. An '
#              'enemy that only Cobb could have seen coming.',
#  'genres': ['Action', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1375666, 'rating': 8.8, 'votes': 1294646},
#  'languages': ['English', 'Japanese', 'French'],
#  'lastupdated': '2015-09-12 00:29:01.430000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A thief who steals corporate secrets through use of dream-sharing '
#          'technology is given the inverse task of planting an idea into the '
#          'mind of a CEO.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2010, 7, 16, 0, 0),
#  'runtime': 148,
#  'title': 'Inception',
#  'tomatoes': {'boxOffice': '$292.6M',
#               'consensus': 'Smart, innovative, and thrilling, Inception is '
#                            'that rare summer blockbuster that succeeds '
#                            'viscerally as well as intellectually.',
#               'critic': {'meter': 86, 'numReviews': 326, 'rating': 8.1},
#               'dvd': datetime.datetime(2010, 12, 7, 0, 0),
#               'fresh': 281,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 13, 32),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 91, 'numReviews': 561365, 'rating': 4.2},
#               'website': 'http://inceptionmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Christopher Nolan'],
#  'year': 2010}
# {'_id': ObjectId('573a13baf29313caabd512e1'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Kotono Mitsuishi',
#           'Megumi Ogata',
#           'Megumi Hayashibara',
#           'Yèko Miyamura'],
#  'countries': ['Japan'],
#  'directors': ['Masayuki', 'Kazuya Tsurumaki', 'Hideaki Anno'],
#  'fullplot': 'Under constant attack by Angels, NERV introduces two new pilots: '
#              'the mysterious Makinami Mari Illustrous and the intense Asuka '
#              'Langley Shikinami. Parallel to the incursion, Gendo Ikari and '
#              'SEELE proceed the secret project that involves both Rei and '
#              'Shinji.',
#  'genres': ['Animation', 'Action', 'Drama'],
#  'imdb': {'id': 860906, 'rating': 8.1, 'votes': 9697},
#  'languages': ['Japanese', 'German'],
#  'lastupdated': '2015-09-07 00:18:49.480000000',
#  'num_mflix_comments': 0,
#  'plot': 'Under constant attack by Angels, NERV introduces two new pilots: the '
#          'mysterious Makinami Mari Illustrous and the intense Asuka Langley '
#          'Shikinami. Parallel to the incursion, Gendo Ikari and ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc1NTk5OTQwOV5BMl5BanBnXkFtZTgwMzg4MjU2MzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-14',
#  'released': datetime.datetime(2009, 6, 27, 0, 0),
#  'runtime': 112,
#  'title': 'Evangelion: 2.0 You Can (Not) Advance',
#  'tomatoes': {'critic': {'meter': 75, 'numReviews': 8, 'rating': 6.1},
#               'dvd': datetime.datetime(2011, 3, 29, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 15, 23),
#               'production': 'Eleven Arts',
#               'rotten': 2,
#               'viewer': {'meter': 90, 'numReviews': 2983, 'rating': 4.3},
#               'website': 'http://www.funimation.com/evangelion'},
#  'type': 'movie',
#  'writers': ['Hideaki Anno (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13b5f29313caabd42722'),
#  'awards': {'nominations': 106,
#             'text': 'Won 2 Oscars. Another 142 wins & 106 nominations.',
#             'wins': 144},
#  'cast': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Batman raises the stakes in his war on crime. With the help of '
#              'Lieutenant Jim Gordon and District Attorney Harvey Dent, Batman '
#              'sets out to dismantle the remaining criminal organizations that '
#              'plague the city streets. The partnership proves to be effective, '
#              'but they soon find themselves prey to a reign of chaos unleashed '
#              'by a rising criminal mastermind known to the terrified citizens '
#              'of Gotham as The Joker.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 468569, 'rating': 9.0, 'votes': 1495351},
#  'languages': ['English', 'Mandarin'],
#  'lastupdated': '2015-09-10 17:05:27.667000000',
#  'metacritic': 82,
#  'num_mflix_comments': 136,
#  'plot': 'When the menace known as the Joker wreaks havoc and chaos on the '
#          'people of Gotham, the caped crusader must come to terms with one of '
#          'the greatest psychological tests of his ability to fight injustice.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2008, 7, 18, 0, 0),
#  'runtime': 152,
#  'title': 'The Dark Knight',
#  'tomatoes': {'boxOffice': '$533.3M',
#               'consensus': 'Dark, complex and unforgettable, The Dark Knight '
#                            'succeeds not just as an entertaining comic book '
#                            'film, but as a richly thrilling crime saga.',
#               'critic': {'meter': 94, 'numReviews': 314, 'rating': 8.6},
#               'dvd': datetime.datetime(2008, 12, 9, 0, 0),
#               'fresh': 295,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 30),
#               'production': 'Warner Bros. Pictures/Legendary',
#               'rotten': 19,
#               'viewer': {'meter': 94, 'numReviews': 1818515, 'rating': 4.4},
#               'website': 'http://thedarkknight.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2008}
# {'_id': ObjectId('573a13c1f29313caabd652bb'),
# ...
#          'Princess Leia from the evil Darth Vader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzVlY2MwMjktM2E4OS00Y2Y3LWE3ZjctYzhkZGM3YzA1ZWM2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1977, 5, 25, 0, 0),
#  'runtime': 121,
#  'title': 'Star Wars: Episode IV - A New Hope',
#  'tomatoes': {'consensus': 'A legendarily expansive and ambitious start to the '
#                            'sci-fi saga, George Lucas opened our eyes to the '
#                            'possiblites of blockbuster filmmaking and things '
#                            'have never been the same.',
#               'critic': {'meter': 94, 'numReviews': 82, 'rating': 8.5},
#               'dvd': datetime.datetime(2004, 9, 21, 0, 0),
#               'fresh': 77,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 4, 3),
#               'production': '20th Century Fox',
#               'rotten': 5,
#               'viewer': {'meter': 96, 'numReviews': 848179, 'rating': 4.1},
#               'website': 'http://www.starwars.com/episode-iv/'},
#  'type': 'movie',
#  'writers': ['George Lucas'],
#  'year': 1977}
# {'_id': ObjectId('573a1396f29313caabce5a56'),
#  'awards': {'nominations': 0, 'text': '7 wins.', 'wins': 7},
#  'cast': ['Shashi Kapoor', 'Amitabh Bachchan', 'Neetu Singh', 'Nirupa Roy'],
#  'countries': ['India'],
#  'directors': ['Yash Chopra'],
#  'fullplot': 'The movie tells the story of two brothers, Vijay and Ravi Verma, '
#              'who follow different career paths: Vijay is a smuggler and Ravi '
#              'the policeman who is asked to hunt Vijay down. Vijay Verma '
#              '(Amitabh Bachchan) and Ravi Verma (Shashi Kapoor) are the sons '
#              'of a trade unionist, Anand Verma(Satyen Kappu), who was defeated '
#              'and disgraced by the management of his firm using his family as '
#              'bait. Unable to bear the public disgrace father deserts the '
#              'family, and the sons are raised by their mother(Nirupa Roy)who '
#              'brings them to Bombay City, who suffers the trials and '
#              'tribulations of a poor single mother. Vijay Verma, the elder '
#              "brother, grows up with an acute awareness of his father's "
#              "humiliation and is victimized for his father's supposed "
#              'misdeeds. In the process of fighting for his rights Vijay, who '
#              'starts out as a boot polisher and becomes a dockyard worker in '
#              'his youth, becomes a smuggler and a leading figure of the '
#              'underworld.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 72860, 'rating': 8.1, 'votes': 4753},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-09-17 04:37:47.103000000',
#  'num_mflix_comments': 0,
#  'plot': 'As a youth, Vijay struggles as a dockworker. Eventually, he becomes '
#          'a leading figure of the underworld, while younger brother, Ravi, is '
#          'an educated, upright policeman. But in the end, it all comes down '
#          'to, who does mother love more?',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTYyOTA3NV5BMl5BanBnXkFtZTcwMDMyNjEzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1979, 5, 1, 0, 0),
#  'runtime': 174,
#  'title': 'Deewaar',
#  'tomatoes': {'dvd': datetime.datetime(2004, 3, 30, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 17, 6, 19),
#               'viewer': {'meter': 85, 'numReviews': 1174, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Javed Akhtar (dialogue)',
#              'Javed Akhtar (screenplay)',
#              'Javed Akhtar (story)',
#              'Salim Khan (dialogue)',
#              'Salim Khan (screenplay)',
#              'Salim Khan (story)'],
#  'year': 1975}
# {'_id': ObjectId('573a1397f29313caabce5d93'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini', 'Amitabh Bachchan'],
#  'countries': ['India'],
#  'directors': ['Ramesh Sippy'],
#  'fullplot': 'Sholay means embers in Hindi. In this particular movie, a Police '
#              "Officer, who's family was killed by a bandit named Gabbar Singh, "
#              'decides to fight fire with fire and recruits two convicts, Jai '
#              'and Veeru to capture Gabbar. He approaches them in jail, puts '
#              'the proposal in front of them, and they agree to bring in Gabbar '
#              'Singh alive - for a hefty price. After their discharge from '
#              'jail, they travel by train to the village where the Police '
#              'Officer lives - now with only his widowed daughter-in-law. The '
#              'three band together to fight one of the most elusive and dreaded '
#              'bandits of all time. Will the two ex-cons be able to bring '
#              'Gabbar alive to the Police Officer?',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 73707, 'rating': 8.6, 'votes': 22725},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-15 00:20:17.553000000',
#  'num_mflix_comments': 0,
#  'plot': 'After his family is murdered by a notorious and ruthless bandit, a '
#          'former police officer enlists the services of two outlaws to capture '
#          'him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOGZiM2IwODktNTdiMC00MGU1LWEyZTYtOTk4NTkwYmJkNmI1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1975, 8, 15, 0, 0),
#  'runtime': 162,
#  'title': 'Sholay',
#  'type': 'movie',
#  'writers': ['Javed Akhtar', 'Salim Khan'],
#  'year': 1975}
# {'_id': ObjectId('573a1396f29313caabce4122'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amza Pellea', 'Ion Besoiu', 'Olga Tudorache', 'Irina Gardescu'],
#  'countries': ['Romania', 'France', 'Italy'],
#  'directors': ['Sergiu Nicolaescu'],
#  'fullplot': 'An epic fresco depicting the reign (1593-1601) of Mihai Pètrascu '
#              '(better known as "Mihai Viteazul" / "Michael the Brave"), the '
#              'famous prince who united the three provinces: Transalpine '
#              'Vallachia, Transylvania and Moldavia, into the country of '
#              'Romania, at the end of the 16th century (1599-1601) against the '
#              'opposition of the Ottoman and Austrian Empires, this movie '
#              'features large scale battle scenes mixed with political '
#              'intrigues, murderous treachery, and family drama.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 66078, 'rating': 8.3, 'votes': 5354},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-09-10 17:55:03.667000000',
#  'num_mflix_comments': 0,
#  'plot': 'At the end of the 16th century Wallachian ruler Prince Michael the '
#          'Brave overcame the adversity of the Ottoman and Austrian Empires to '
#          'unite Wallachia, Moldavia and Transylvania into one country.',
#  'runtime': 203,
#  'title': 'Michael the Brave',
#  'tomatoes': {'critic': {'meter': 89, 'numReviews': 9, 'rating': 6.6},
#               'dvd': datetime.datetime(2004, 4, 27, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 17, 38),
#               'production': 'Paramount Home Video',
#               'rotten': 1,
#               'viewer': {'meter': 64, 'numReviews': 1511, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Titus Popovici'],
#  'year': 1970}
# {'_id': ObjectId('573a13acf29313caabd27be4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amza Pellea', 'Ion Besoiu', 'Olga Tudorache', 'Irina Gardescu'],
#  'countries': ['Romania', 'France', 'Italy'],
#  'directors': ['Sergiu Nicolaescu'],
#  'fullplot': 'An epic fresco depicting the reign (1593-1601) of Mihai Pètrascu '
#              '(better known as "Mihai Viteazul" / "Michael the Brave"), the '
#              'famous prince who united the three provinces: Transalpine '
#              'Vallachia, Transylvania and Moldavia, into the country of '
#              'Romania, at the end of the 16th century (1599-1601) against the '
#              'opposition of the Ottoman and Austrian Empires, this movie '
#              'features large scale battle scenes mixed with political '
#              'intrigues, murderous treachery, and family drama.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 66078, 'rating': 8.3, 'votes': 5347},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-08-31 06:29:18.687000000',
#  'num_mflix_comments': 1,
#  'plot': 'At the end of the 16th century Wallachian ruler Prince Michael the '
#          'Brave overcame the adversity of the Ottoman and Austrian Empires to '
#          'unite Wallachia, Moldavia and Transylvania into one country.',
#  'runtime': 203,
#  'title': 'Michael the Brave',
#  'type': 'movie',
#  'writers': ['Titus Popovici'],
#  'year': 1970}
# {'_id': ObjectId('573a1396f29313caabce3dcf'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 2 Oscars. Another 6 wins & 3 nominations.',
#             'wins': 8},
#  'cast': ['William Holden', 'Ernest Borgnine', 'Robert Ryan', "Edmond O'Brien"],
#  'countries': ['USA'],
#  'directors': ['Sam Peckinpah'],
#  'fullplot': "In the Wild Bunch the movie opens with a group of aging outlaw's "
#              'final score, a bank robbery. The event concludes with a violent '
#              'and overtly bloody shootout that would generally mark the finale '
#              'of a movie. This is correct in that it marks the finale of an '
#              'era, for the characters and the world they live in. They simply '
#              'can no longer keep up, the times are changing, technology '
#              "advancing, and they're style of life is getting left behind in "
#              'the dust that they spent so long galloping through. They abandon '
#              'their careers for the simpler life of retirement. They enjoy '
#              'this time, they live their fantasies. During this time the law '
#              'is always on their tracks, bounty hunters. The further into '
#              'their fantasy they get, the closer their demise seems to get. '
#              'When one of their own is captured they are faced with the choice '
#              'of escape or what is certainly a suicide mission to attempt and '
#              'free their fallen behind comrade. For them it is not a choice. '
#              'They all die in what can only be described as a nauseatingly '
#              'gore filled bloodbath of a battle. They might have succeeded in '
#              'removing themselves from the wild west however they could not be '
#              'separated what is inherently their nature. The west was only '
#              'wild because the wild bunch were present, they influenced their '
#              'surroundings, not the other way around. It is only after the '
#              'final shoot out that the bounty hunters catch up with them, now '
#              'only bullet riddled corpses. They never got caught, they could '
#              'never get caught because they were already trapped in their own '
#              'personalities. They turned themselves in to their instincts. The '
#              'vacation, the fantasy, was bound to end and they knew it.',
#  'genres': ['Action', 'Adventure', 'Western'],
#  'imdb': {'id': 65214, 'rating': 8.1, 'votes': 59133},
#  'languages': ['English', 'Spanish', 'German'],
#  'lastupdated': '2015-08-20 00:39:59.720000000',
#  'num_mflix_comments': 1,
#  'plot': 'An aging group of outlaws look for one last big score as the '
#          '"traditional" American West is disappearing around them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUyYTZmOWItMDJhMi00N2IxLWIyNDMtNjUxM2ZiYmU5YWU1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1969, 6, 18, 0, 0),
#  'runtime': 145,
#  'title': 'The Wild Bunch',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 48, 'rating': 8.8},
#               'dvd': datetime.datetime(1997, 8, 27, 0, 0),
#               'fresh': 47,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 32, 47),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 33369, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Walon Green (screenplay)',
#              'Sam Peckinpah (screenplay)',
#              'Walon Green (story)',
#              'Roy N. Sickner (story)'],
#  'year': 1969}
# {'_id': ObjectId('573a139cf29313caabcf835c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Kazimir Vitkus',
#           'Regimantas Adomaitis',
#           "Bruno O'Ya",
#           'Juozas Budraitis'],
#  'countries': ['Soviet Union'],
#  'directors': ['Vytautas Zalakevicius'],
#  'fullplot': 'The film is set in Lithuania after the Second World War. It '
#              'shows dramatic events in a small Lithuanian farming community, '
#              'where people are split between the Soviets and the "brothers in '
#              'the woods", who are fighting to defend their land from the '
#              'Soviets after the end of the Second World War.',
#  'genres': ['Action', 'Drama', 'History'],
#  'imdb': {'id': 151750, 'rating': 8.1, 'votes': 421},
#  'languages': ['Lithuanian'],
#  'lastupdated': '2015-08-22 00:15:54.687000000',
#  'num_mflix_comments': 0,
#  'plot': 'The film is set in Lithuania after the Second World War. It shows '
#          'dramatic events in a small Lithuanian farming community, where '
#          'people are split between the Soviets and the "brothers in ...',
#  'released': datetime.datetime(1966, 9, 5, 0, 0),
#  'runtime': 100,
#  'title': 'Niekas nenorejo mirti',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 25, 18, 49, 16),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Vytautas Zalakevicius'],
#  'year': 1966}
# {'_id': ObjectId('573a1395f29313caabce2498'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Clint Eastwood',
#           'Marianne Koch',
#           'Gian Maria Volontè',
#           'Wolfgang Lukschy'],
#  'countries': ['Italy', 'Spain', 'West Germany'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'An anonymous, but deadly man rides into a town torn by war '
#              "between two factions, the Baxters and the Rojo's. Instead of "
#              'fleeing or dying, as most other would do, the man schemes to '
#              'play the two sides off each other, getting rich in the bargain.',
#  'genres': ['Action', 'Drama', 'Western'],
#  'imdb': {'id': 58461, 'rating': 8.1, 'votes': 126585},
#  'languages': ['Italian', 'Spanish', 'English'],
#  'lastupdated': '2015-09-02 00:17:22.303000000',
#  'num_mflix_comments': 0,
#  'plot': 'A wandering gunfighter plays two rival families against each other '
#          'in a town torn apart by greed, pride, and revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjA1MGVlMGItNzgxMC00OWY4LWI4YjEtNTNmYWIzMGUxOGQzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1967, 1, 18, 0, 0),
#  'runtime': 99,
#  'title': 'A Fistful of Dollars',
#  'tomatoes': {'consensus': "With Akira Kurosawa's Yojimbo as his template, "
#                            "Sergio Leone's A Fistful of Dollars helped define "
#                            'a new era for the Western and usher in its most '
#                            'iconic star, Clint Eastwood.',
#               'critic': {'meter': 98, 'numReviews': 43, 'rating': 8.1},
#               'dvd': datetime.datetime(2001, 6, 19, 0, 0),
#               'fresh': 42,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 1, 55),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 85171, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Adriano Bolzoni (story)',
#              'Vèctor Andrès Catena (story)',
#              'Sergio Leone (story)',
#              'Vèctor Andrès Catena (screenplay)',
#              'Jaime Comas Gil (screenplay)',
#              'Sergio Leone (screenplay)'],
#  'year': 1964}

# %%
#2. Write a query to find all movies where the directors contain "Christopher Nolan" and the IMDb rating is greater than 8 (Return only the top 3 movies sorted by rating).
nolan_movies = collection.find({"directors": "Christopher Nolan", "imdb.rating": {"$gt": 8}}).limit(3).sort("imdb.rating", -1)
for movie in nolan_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13b5f29313caabd42722'),
#  'awards': {'nominations': 106,
#             'text': 'Won 2 Oscars. Another 142 wins & 106 nominations.',
#             'wins': 144},
#  'cast': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Batman raises the stakes in his war on crime. With the help of '
#              'Lieutenant Jim Gordon and District Attorney Harvey Dent, Batman '
#              'sets out to dismantle the remaining criminal organizations that '
#              'plague the city streets. The partnership proves to be effective, '
#              'but they soon find themselves prey to a reign of chaos unleashed '
#              'by a rising criminal mastermind known to the terrified citizens '
#              'of Gotham as The Joker.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 468569, 'rating': 9.0, 'votes': 1495351},
#  'languages': ['English', 'Mandarin'],
#  'lastupdated': '2015-09-10 17:05:27.667000000',
#  'metacritic': 82,
#  'num_mflix_comments': 136,
#  'plot': 'When the menace known as the Joker wreaks havoc and chaos on the '
#          'people of Gotham, the caped crusader must come to terms with one of '
#          'the greatest psychological tests of his ability to fight injustice.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2008, 7, 18, 0, 0),
#  'runtime': 152,
#  'title': 'The Dark Knight',
#  'tomatoes': {'boxOffice': '$533.3M',
#               'consensus': 'Dark, complex and unforgettable, The Dark Knight '
#                            'succeeds not just as an entertaining comic book '
#                            'film, but as a richly thrilling crime saga.',
#               'critic': {'meter': 94, 'numReviews': 314, 'rating': 8.6},
#               'dvd': datetime.datetime(2008, 12, 9, 0, 0),
#               'fresh': 295,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 30),
#               'production': 'Warner Bros. Pictures/Legendary',
#               'rotten': 19,
#               'viewer': {'meter': 94, 'numReviews': 1818515, 'rating': 4.4},
#               'website': 'http://thedarkknight.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2008}
# {'_id': ObjectId('573a13c5f29313caabd6ee61'),
#  'awards': {'nominations': 172,
#             'text': 'Won 4 Oscars. Another 158 wins & 172 nominations.',
#             'wins': 162},
#  'cast': ['Leonardo DiCaprio',
#           'Joseph Gordon-Levitt',
#           'Ellen Page',
#           'Tom Hardy'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Dom Cobb is a skilled thief, the absolute best in the dangerous '
#              'art of extraction, stealing valuable secrets from deep within '
#              'the subconscious during the dream state, when the mind is at its '
#              "most vulnerable. Cobb's rare ability has made him a coveted "
#              'player in this treacherous new world of corporate espionage, but '
#              'it has also made him an international fugitive and cost him '
#              'everything he has ever loved. Now Cobb is being offered a chance '
#              'at redemption. One last job could give him his life back but '
#              'only if he can accomplish the impossible-inception. Instead of '
#              'the perfect heist, Cobb and his team of specialists have to pull '
#              'off the reverse: their task is not to steal an idea but to plant '
#              'one. If they succeed, it could be the perfect crime. But no '
#              'amount of careful planning or expertise can prepare the team for '
#              'the dangerous enemy that seems to predict their every move. An '
#              'enemy that only Cobb could have seen coming.',
#  'genres': ['Action', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1375666, 'rating': 8.8, 'votes': 1294646},
#  'languages': ['English', 'Japanese', 'French'],
#  'lastupdated': '2015-09-12 00:29:01.430000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A thief who steals corporate secrets through use of dream-sharing '
#          'technology is given the inverse task of planting an idea into the '
#          'mind of a CEO.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2010, 7, 16, 0, 0),
#  'runtime': 148,
#  'title': 'Inception',
#  'tomatoes': {'boxOffice': '$292.6M',
#               'consensus': 'Smart, innovative, and thrilling, Inception is '
#                            'that rare summer blockbuster that succeeds '
#                            'viscerally as well as intellectually.',
#               'critic': {'meter': 86, 'numReviews': 326, 'rating': 8.1},
#               'dvd': datetime.datetime(2010, 12, 7, 0, 0),
#               'fresh': 281,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 13, 32),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 91, 'numReviews': 561365, 'rating': 4.2},
#               'website': 'http://inceptionmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Christopher Nolan'],
#  'year': 2010}
# {'_id': ObjectId('573a13b9f29313caabd4ddff'),
#  'awards': {'nominations': 100,
#             'text': 'Won 1 Oscar. Another 44 wins & 100 nominations.',
#             'wins': 45},
#  'cast': ['Ellen Burstyn',
#           'Matthew McConaughey',
#           'Mackenzie Foy',
#           'John Lithgow'],
#  'countries': ['USA', 'UK', 'Canada'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'In the near future, Earth has been devastated by drought and '
#              'famine, causing a scarcity in food and extreme changes in '
#              'climate. When humanity is facing extinction, a mysterious rip in '
#              'the space-time continuum is discovered, giving mankind the '
#              'opportunity to widen its lifespan. A group of explorers must '
#              'travel beyond our solar system in search of a planet that can '
#              'sustain life. The crew of the Endurance are required to think '
#              'bigger and go further than any human in history as they embark '
#              'on an interstellar voyage into the unknown. Coop, the pilot of '
#              'the Endurance, must decide between seeing his children again and '
#              'the future of the human race.',
#  'genres': ['Adventure', 'Drama', 'Sci-Fi'],
#  'imdb': {'id': 816692, 'rating': 8.7, 'votes': 699518},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:04:49.173000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A team of explorers travel through a wormhole in space in an attempt '
#          "to ensure humanity's survival.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 11, 7, 0, 0),
#  'runtime': 169,
#  'title': 'Interstellar',
#  'tomatoes': {'consensus': 'Interstellar represents more of the thrilling, '
#                            'thought-provoking, and visually resplendent '
#                            'filmmaking moviegoers have come to expect from '
#                            'writer-director Christopher Nolan, even if its '
#                            'intellectual reach somewhat exceeds its grasp.',
#               'critic': {'meter': 72, 'numReviews': 293, 'rating': 7.0},
#               'dvd': datetime.datetime(2015, 3, 31, 0, 0),
#               'fresh': 210,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 8, 37),
#               'production': 'Paramount Pictures',
#               'rotten': 83,
#               'viewer': {'meter': 85, 'numReviews': 163082, 'rating': 4.1},
#               'website': 'http://www.InterstellarMovie.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan', 'Christopher Nolan'],
#  'year': 2014}
